# %% [markdown]
# #Neural Networks in the Wild - Handwriting Recognition
#
# By John Liu
#
# ##Introduction
#
# This ipython notebook investigates the topic of handwriting recognition. It begins with a short OpenCV tutorial on character segmentation. Using the NIST SD-19 dataset, various linear and ensemble estimators from scikit-learn are investigated for character recognition. These are compared to several neural network models implemented in pylearn2 (without YAML).

# %% [markdown]
# ## Character Segmentation

# %% [markdown]
# Character segmentation consists of several preprocessing steps after which contour detection and bounding rectangles are extracted. Typical preprocessing consists of:
#
# * threshold pixels
# * apply smoothing filter
# * morphological filtering

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ###Load image

# %%
img = "Plate.jpg"   # License plate
#img = "Food.jpg"   # motto

dir = os.curdir

path = os.path.join(dir,img)
raw_image = cv2.imread(path,0)

cv2.imshow("original",raw_image)
plt.subplot(2,3,1)
plt.title("Original")
plt.imshow(raw_image,'gray')
plt.xticks([]),plt.yticks([]);

# %% [markdown]
# ### Apply Smoothing with Kernel

# %%
sm_image = cv2.blur(raw_image,(8,8))

cv2.imshow("smoothed",sm_image)

plt.subplot(2,3,2)
plt.title("Smoothed")
plt.imshow(sm_image,'gray')
plt.xticks([]),plt.yticks([]);

# %% [markdown]
# ### Thresholding

# %%
#cv2.imshow("smoothed",sm_image)
ret,bw_image = cv2.threshold(sm_image,160,255,cv2.THRESH_BINARY_INV)

cv2.imshow("thresholded",bw_image)
plt.subplot(2,3,3)
plt.title("Thresholded")
plt.imshow(bw_image,'gray')
plt.xticks([]),plt.yticks([]);

# %% [markdown]
# ### Open (Erode and Dilate) image to remove Noise
#
# Can combine erosion and dilation with one command
# mo_image = cv2.morphologyEx(sm_image,cv2.MORPH_OPEN,kernel)
#
# ###Erode

# %%
kernel = np.ones((4,4),np.uint8)
er_image = cv2.erode(bw_image,kernel)

cv2.imshow("eroded",er_image)
plt.subplot(2,3,4)
plt.title("Eroded")
plt.imshow(er_image,'gray')
plt.xticks([]),plt.yticks([]);

# %% [markdown]
# ###Then dilate

# %%
kernel = np.ones((2,2),np.uint8)
di_image = cv2.dilate(er_image,kernel)

cv2.imshow("dilated",di_image)
plt.title("Dilated")
plt.subplot(2,3,5)
plt.imshow(di_image,'gray')
plt.xticks([]),plt.yticks([]);

# %% [markdown]
# ###Find Contours

# %%
mo_image = di_image.copy()
contour0 = cv2.findContours(mo_image.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
contours = [cv2.approxPolyDP(cnt,3,True) for cnt in contour0[0]]

# %% [markdown]
# ### Extract Bounding Rectangles

# %%
maxArea = 0
rect=[]
for ctr in contours:
    maxArea = max(maxArea,cv2.contourArea(ctr))

if img == "Food.jpg":
    areaRatio = 0.05
elif img == "Plate.jpg":
    areaRatio = 0.5
    
for ctr in contours:    
    if cv2.contourArea(ctr) > maxArea * areaRatio: 
        rect.append(cv2.boundingRect(cv2.approxPolyDP(ctr,1,True)))
    
symbols=[]
for i in rect:
    x = i[0]
    y = i[1]
    w = i[2]
    h = i[3]
    p1 = (x,y)
    p2 = (x+w,y+h)
    cv2.rectangle(mo_image,p1,p2,255,2)
    image = cv2.resize(mo_image[y:y+h,x:x+w],(32,32))
    symbols.append(image.reshape(1024,).astype("uint8"))

testset_data = np.array(symbols)

cv2.imshow("segmented",mo_image)
plt.subplot(2,3,6)
plt.title("Segmented")
plt.imshow(mo_image,'gray')
plt.xticks([]),plt.yticks([]);
#plt.show()

# %%
# garbage collection
cv2.destroyAllWindows()
plt.close()

# %%
# show glyphs
for i in range(len(symbols)):
    cv2.imshow("sym",symbols[i])
    cv2.waitKey(0)

cv2.destroyAllWindows()
plt.close()

# %% [markdown]
# # SD-19 Dataset preprocessing

# %% [markdown]
# ### Cut slice of SD19 dataset

# %%
import numpy as np
import cv2
import os


dir = os.curdir
path = os.path.join(dir,"sd19/sd19-binary.txt")
f = open(path,"r")

target=[]
data=[]
for i in range(100000):
    line = f.readline()
    target.append(line[0])
    image = np.array([((int(line[2+j])+1)%2) for j in range(16384)]).astype("uint8")
    r_image = cv2.resize(image.reshape((128,128)),(32,32)).reshape(1024,)
    data.append(r_image)
dataset = pd.DataFrame(data)
dataset['target']=target
dataset.to_csv(os.path.join(dir,"sd19.csv"),index=False,header=None)

# %% [markdown]
# ###Make a modified set for pylearn2

# %%
# preprocess dataset to reorder columns to place label in first column for pylearn2
import os
import pandas as pd
dir = os.curdir
path = os.path.join(dir,"sd19.csv") 
df = pd.read_csv(path,header=None)

cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]
symbol_map = dict([(chr(x), x) for x in range(48,58) + range (65,91) + range(97,123)])
df[1024]=[symbol_map[i] for i in df[1024]]
df.to_csv("sd19n.csv",index=False,header=None)

# %% [markdown]
# ###Load Slice of SD19 (100k samples of 62 classes in [[0-9][A-Z][a-z]]

# %%
import os
import pandas as pd
dir = os.curdir
path = os.path.join(dir,"sd19.csv") 
df = pd.read_csv(path,header=None)

# %% [markdown]
# #Classification

# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn import linear_model,svm
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,AdaBoostClassifier
import numpy as np

# %%
symbol_map = dict([(chr(x), x) for x in range(48,58) + range (65,91) + range(97,123)])
(trainX, testX, trainY, testY) = train_test_split(df.ix[:,0:1023] ,df.ix[:,1024].replace(symbol_map) , test_size = 0.3)

# %% [markdown]
# ##Logistic Regression (SoftMax, MaxEnt, Logit)

# %%
modelSG = linear_model.SGDClassifier(loss='log',penalty='l2',alpha=0.001,n_iter=1,shuffle=False,n_jobs=-1,random_state=33)
modelSG.fit(trainX,trainY)

# %%
pred = modelSG.predict(testX)
print accuracy_score(testY,pred)
#print classification_report(testY,pred)
#print confusion_matrix(testY,pred)

# %% [markdown]
# ## SVM with Radial Basis Function

# %%
#modelSVC = svm.SVC(kernel='linear',random_state=33)
modelSVC = svm.SVC(kernel='rbf',gamma=0,tol=0.01,verbose=False,max_iter=-1,random_state=33)
modelSVC.fit(trainX,trainY)

# %%
pred = modelSVC.predict(testX)
print accuracy_score(testY,pred)

# %% [markdown]
# ## Ensemble: Random Forest

# %%
modelRF = RandomForestClassifier(n_estimators=10,criterion='gini',max_depth=None,n_jobs=-1,verbose=0,random_state=33)
modelRF.fit(trainX,trainY)

# %%
pred = modelRF.predict(testX)
print accuracy_score(testY,pred)

# %% [markdown]
# ## Emsemble: Extra Trees

# %%
modelET = ExtraTreesClassifier(n_estimators=10,max_depth=None,random_state=33)
modelET.fit(trainX,trainY)

# %%
pred = modelET.predict(testX)
print accuracy_score(testY,pred)

# %%
print classification_report(testY,pred)

# %% [markdown]
# #Neural Networks using pylearn2

# %%
import os
import numpy as np

from pylearn2.train import Train
from pylearn2.models import softmax_regression, mlp
from pylearn2.training_algorithms import bgd, sgd
from pylearn2.termination_criteria import MonitorBased
from pylearn2.termination_criteria import EpochCounter
from pylearn2.train_extensions import best_params
from pylearn2.utils import serial
from pylearn2.costs.mlp.dropout import Dropout
from pylearn2.datasets.dense_design_matrix import DenseDesignMatrix
from pylearn2.datasets import csv_dataset
from theano import function
from theano import tensor as T
import theano
# Out:
# Using gpu device 0: GeForce GTX 285

# %%
# load datasets
train = csv_dataset.CSVDataset("sd19n.csv",one_hot=True,expect_labels=True,expect_headers=False,delimiter=',',end_fraction=0.7)
valid = csv_dataset.CSVDataset("valid.csv",one_hot=True,expect_labels=True,expect_headers=False,delimiter=',')
test = csv_dataset.CSVDataset("test.csv",one_hot=True,expect_labels=True,expect_headers=False,delimiter=',')

# %% [markdown]
# ##2-layer SoftMax with sigmoid hidden_layer = 400

# %%
# Simple ANN

h0 = mlp.Sigmoid(layer_name="h0",dim=400, sparse_init=20)
y0 = mlp.Softmax(n_classes=62,layer_name="y0",sparse_init=20)
layers = [h0, y0]

nn = mlp.MLP(layers,nvis=1024)
algo = sgd.SGD(learning_rate=0.05,batch_size=100,monitoring_dataset=valid,termination_criterion=EpochCounter(100))
algo.setup(nn,train)

save_best = best_params.MonitorBasedSaveBest(channel_name="y0_misclass",save_path='best_params.pkl')
while True:
    algo.train(dataset=train)
    nn.monitor.report_epoch()
    nn.monitor()
    save_best.on_monitor(nn,train,algo)
    if not algo.continue_learning(nn):
        break
# Out:
# Parameter and initial learning rate summary:
# 	h0_W: 0.0500000007451
# 	h0_b: 0.0500000007451
# 	softmax_b: 0.0500000007451
# 	softmax_W: 0.0500000007451
# Compiling sgd_update...
# Compiling sgd_update done. Time elapsed: 0.712864 seconds
# compiling begin_record_entry...
# compiling begin_record_entry done. Time elapsed: 0.203689 seconds
# Monitored channels:
# 	h0_col_norms_max
# 	h0_col_norms_mean
# 	h0_col_norms_min
# 	h0_max_x_max_u
# 	h0_max_x_mean_u
# 	h0_max_x_min_u
# 	h0_mean_x_max_u
# 	h0_mean_x_mean_u
# 	h0_mean_x_min_u
# 	h0_min_x_max_u
# 	h0_min_x_mean_u
# 	h0_min_x_min_u
# 	h0_range_x_max_u
# 	h0_range_x_mean_u
# 	h0_range_x_min_u
# 	h0_row_norms_max
# 	h0_row_norms_mean
# 	h0_row_norms_min
# 	learning_rate
# 	objective
# 	y0_col_norms_max
# 	y0_col_norms_mean
# 	y0_col_norms_min
# 	y0_max_max_class
# 	y0_mean_max_class
# 	y0_min_max_class
# 	y0_misclass
# 	y0_nll
# 	y0_row_norms_max
# 	y0_row_norms_mean
# 	y0_row_norms_min
# Compiling accum...
# graph size: 129
# Compiling accum done. Time elapsed: 2.226191 seconds
# Monitoring step:
# 	Epochs seen: 1
# 	Batches seen: 700
# 	Examples seen: 70000
# 	h0_col_norms_max: 6.62223243713
# 	h0_col_norms_mean: 4.40561056137
# 	h0_col_norms_min: 2.15925884247
# 	h0_max_x_max_u: 0.994832336903
# 	h0_max_x_mean_u: 0.773628413677
# 	h0_max_x_min_u: 0.466156810522
# 	h0_mean_x_max_u: 0.791491866112
# 	h0_mean_x_mean_u: 0.489813506603
# 	h0_mean_x_min_u: 0.141065835953
# 	h0_min_x_max_u: 0.510287463665
# 	h0_min_x_mean_u: 0.200387015939
# 	h0_min_x_min_u: 0.00231564999558
# 	h0_range_x_max_u: 0.94592833519
# 	h0_range_x_mean_u: 0.573241472244
# 	h0_range_x_min_u: 0.139246091247
# 	h0_row_norms_max: 5.20215463638
# 	h0_row_norms_mean: 2.65205788612
# 	h0_row_norms_min: 0.174363389611
# 	learning_rate: 0.0500000119209
# 	objective: 2.20403504372
# 	y0_col_norms_max: 5.84725999832
# 	y0_col_norms_mean: 4.57080125809
# 	y0_col_norms_min: 3.36918139458
# 	y0_max_max_class: 0.744379162788
# 	y0_mean_max_class: 0.302113473415
# 	y0_min_max_class: 0.0844793692231
# 	y0_misclass: 0.507400095463
# 	y0_nll: 2.20403504372
# 	y0_row_norms_max: 4.29236221313
# 	y0_row_norms_mean: 1.60388922691
# 	y0_row_norms_min: 0.115337915719
# Monitoring step:
# 	Epochs seen: 2
# 	Batches seen: 1400
# 	Examples seen: 140000
# 	h0_col_norms_max: 6.63448810577
# 	h0_col_norms_mean: 4.41455793381
# 	h0_col_norms_min: 2.18262910843
# 	h0_max_x_max_u: 0.995666921139
# 	h0_max_x_mean_u: 0.787425100803
# 	h0_max_x_min_u: 0.469174355268
# 	h0_mean_x_max_u: 0.803972244263
# 	h0_mean_x_mean_u: 0.486526817083
# 	h0_mean_x_min_u: 0.147970214486
# 	h0_min_x_max_u: 0.506252706051
# 	h0_min_x_mean_u: 0.183038309216
# 	h0_min_x_min_u: 0.00206025294028
# 	h0_range_x_max_u: 0.947999417782
# 	h0_range_x_mean_u: 0.604386925697
# 	h0_range_x_min_u: 0.169660776854
# 	h0_row_norms_max: 5.20219421387
# 	h0_row_norms_mean: 2.65817427635
# 	h0_row_norms_min: 0.174628093839
# 	learning_rate: 0.0500000119209
# 	objective: 1.87127387524
# 	y0_col_norms_max: 5.95069313049
# 	y0_col_norms_mean: 4.63881015778
# 	y0_col_norms_min: 3.381919384
# 	y0_max_max_class: 0.864980101585
# 	y0_mean_max_class: 0.406625062227
# 	y0_min_max_class: 0.0955109745264
# 	y0_misclass: 0.445099949837
# 	y0_nll: 1.87127387524
# 	y0_row_norms_max: 4.38969755173
# 	y0_row_norms_mean: 1.635810256
# 	y0_row_norms_min: 0.13857267797
# Monitoring step:
# 	Epochs seen: 3
# 	Batches seen: 2100
# 	Examples seen: 210000
# 	h0_col_norms_max: 6.64429283142
# 	h0_col_norms_mean: 4.42228269577
# 	h0_col_norms_min: 2.19937181473
# 	h0_max_x_max_u: 0.996295034885
# 	h0_max_x_mean_u: 0.795059382915
# 	h0_max_x_min_u: 0.465353280306
# 	h0_mean_x_max_u: 0.8141528368
# 	h0_mean_x_mean_u: 0.4834189713
# 	h0_mean_x_min_u: 0.154219284654
# 	h0_min_x_max_u: 0.507283687592
# 	h0_min_x_mean_u: 0.171783462167
# 	h0_min_x_min_u: 0.00185268488713
# 	h0_range_x_max_u: 0.950304627419
# 	h0_range_x_mean_u: 0.62327593565
# 	h0_range_x_min_u: 0.1859382689
# 	h0_row_norms_max: 5.20221185684
# 	h0_row_norms_mean: 2.6633746624
# 	h0_row_norms_min: 0.175013631582
# 	learning_rate: 0.0500000119209
# 	objective: 1.70566153526
# 	y0_col_norms_max: 6.03246641159
# 	y0_col_norms_mean: 4.69692516327
# 	y0_col_norms_min: 3.40691304207
# 	y0_max_max_class: 0.918448030949
# 	y0_mean_max_class: 0.455260843039
# 	y0_min_max_class: 0.108851611614
# 	y0_misclass: 0.413700044155
# 	y0_nll: 1.70566153526
# 	y0_row_norms_max: 4.45790433884
# 	y0_row_norms_mean: 1.66249203682
# 	y0_row_norms_min: 0.153957426548
# Monitoring step:
# 	Epochs seen: 4
# 	Batches seen: 2800
# 	Examples seen: 280000
# 	h0_col_norms_max: 6.65278339386
# 	h0_col_norms_mean: 4.42923974991
# 	h0_col_norms_min: 2.21292948723
# 	h0_max_x_max_u: 0.996745347977
# 	h0_max_x_mean_u: 0.799894869328
# 	h0_max_x_min_u: 0.458695024252
# 	h0_mean_x_max_u: 0.819609045982
# 	h0_mean_x_mean_u: 0.480537742376
# 	h0_mean_x_min_u: 0.148774906993
# 	h0_min_x_max_u: 0.507587313652
# 	h0_min_x_mean_u: 0.163513720036
# 	h0_min_x_min_u: 0.00157627428416
# 	h0_range_x_max_u: 0.952858626842
# 	h0_range_x_mean_u: 0.636381268501
# 	h0_range_x_min_u: 0.196476593614
# 	h0_row_norms_max: 5.202231884
# 	h0_row_norms_mean: 2.66800141335
# 	h0_row_norms_min: 0.17547956109
# 	learning_rate: 0.0500000119209
# 	objective: 1.59202492237
# 	y0_col_norms_max: 6.10221529007
# 	y0_col_norms_mean: 4.74834918976
# 	y0_col_norms_min: 3.44287776947
# 	y0_max_max_class: 0.941616952419
# 	y0_mean_max_class: 0.486510664225
# 	y0_min_max_class: 0.11673681438
# 	y0_misclass: 0.389799982309
# 	y0_nll: 1.59202492237
# 	y0_row_norms_max: 4.51092767715
# 	y0_row_norms_mean: 1.68571543694
# 	y0_row_norms_min: 0.167313084006
# Monitoring step:
# 	Epochs seen: 5
# 	Batches seen: 3500
# 	Examples seen: 350000
# 	h0_col_norms_max: 6.66079139709
# 	h0_col_norms_mean: 4.43565559387
# 	h0_col_norms_min: 2.22408509254
# 	h0_max_x_max_u: 0.997120857239
# 	h0_max_x_mean_u: 0.803540825844
# 	h0_max_x_min_u: 0.451751619577
# 	h0_mean_x_max_u: 0.82432538271
# 	h0_mean_x_mean_u: 0.478153049946
# 	h0_mean_x_min_u: 0.140025734901
# 	h0_min_x_max_u: 0.509347975254
# 	h0_min_x_mean_u: 0.157138243318
# 	h0_min_x_min_u: 0.0013140719384
# 	h0_range_x_max_u: 0.955510497093
# 	h0_range_x_mean_u: 0.646402597427
# 	h0_range_x_min_u: 0.203802421689
# 	h0_row_norms_max: 5.20224571228
# 	h0_row_norms_mean: 2.6722433567
# 	h0_row_norms_min: 0.17602185905
# 	learning_rate: 0.0500000119209
# 	objective: 1.5235350132
# 	y0_col_norms_max: 6.16281890869
# 	y0_col_norms_mean: 4.7950758934
# 	y0_col_norms_min: 3.48763298988
# 	y0_max_max_class: 0.949516773224
# 	y0_mean_max_class: 0.508854746819
# 	y0_min_max_class: 0.123911134899
# 	y0_misclass: 0.378100007772
# 	y0_nll: 1.5235350132
# 	y0_row_norms_max: 4.55660676956
# 	y0_row_norms_mean: 1.70656466484
# 	y0_row_norms_min: 0.179220244288
# Monitoring step:
# 	Epochs seen: 6
# 	Batches seen: 4200
# 	Examples seen: 420000
# 	h0_col_norms_max: 6.66823339462
# 	h0_col_norms_mean: 4.44173383713
# 	h0_col_norms_min: 2.2340927124
# 	h0_max_x_max_u: 0.997445940971
# 	h0_max_x_mean_u: 0.806476414204
# 	h0_max_x_min_u: 0.446831017733
# 	h0_mean_x_max_u: 0.828756392002
# 	h0_mean_x_mean_u: 0.476129770279
# 	h0_mean_x_min_u: 0.13113039732
# 	h0_min_x_max_u: 0.509918034077
# 	h0_min_x_mean_u: 0.151902675629
# 	h0_min_x_min_u: 0.00106787146069
# 	h0_range_x_max_u: 0.958526134491
# 	h0_range_x_mean_u: 0.654573738575
# 	h0_range_x_min_u: 0.209043726325
# 	h0_row_norms_max: 5.20224618912
# 	h0_row_norms_mean: 2.67622303963
# 	h0_row_norms_min: 0.176637366414
# 	learning_rate: 0.0500000119209
# 	objective: 1.4625711441
# 	y0_col_norms_max: 6.21542835236
# 	y0_col_norms_mean: 4.83856630325
# 	y0_col_norms_min: 3.53846383095
# 	y0_max_max_class: 0.95685583353
# 	y0_mean_max_class: 0.527127385139
# 	y0_min_max_class: 0.128297656775
# 	y0_misclass: 0.363900005817
# 	y0_nll: 1.4625711441
# 	y0_row_norms_max: 4.59782743454
# 	y0_row_norms_mean: 1.72576880455
# 	y0_row_norms_min: 0.189433589578
# Monitoring step:
# 	Epochs seen: 7
# 	Batches seen: 4900
# 	Examples seen: 490000
# 	h0_col_norms_max: 6.6794052124
# 	h0_col_norms_mean: 4.44753456116
# 	h0_col_norms_min: 2.24267625809
# 	h0_max_x_max_u: 0.99773734808
# 	h0_max_x_mean_u: 0.809045732021
# 	h0_max_x_min_u: 0.441881299019
# 	h0_mean_x_max_u: 0.83359849453
# 	h0_mean_x_mean_u: 0.474414229393
# 	h0_mean_x_min_u: 0.124588772655
# 	h0_min_x_max_u: 0.510221719742
# 	h0_min_x_mean_u: 0.147498562932
# 	h0_min_x_min_u: 0.000884967797901
# 	h0_range_x_max_u: 0.961267232895
# 	h0_range_x_mean_u: 0.66154718399
# 	h0_range_x_min_u: 0.213020846248
# 	h0_row_norms_max: 5.20224428177
# 	h0_row_norms_mean: 2.67999148369
# 	h0_row_norms_min: 0.177306070924
# 	learning_rate: 0.0500000119209
# 	objective: 1.41581869125
# 	y0_col_norms_max: 6.26039600372
# 	y0_col_norms_mean: 4.87938070297
# 	y0_col_norms_min: 3.59382772446
# 	y0_max_max_class: 0.964738547802
# 	y0_mean_max_class: 0.539901852608
# 	y0_min_max_class: 0.134270653129
# 	y0_misclass: 0.357699930668
# 	y0_nll: 1.41581869125
# 	y0_row_norms_max: 4.63795137405
# 	y0_row_norms_mean: 1.74363517761
# 	y0_row_norms_min: 0.200221031904
# Monitoring step:
# 	Epochs seen: 8
# 	Batches seen: 5600
# 	Examples seen: 560000
# 	h0_col_norms_max: 6.69384050369
# 	h0_col_norms_mean: 4.45309209824
# 	h0_col_norms_min: 2.25059723854
# 	h0_max_x_max_u: 0.998003542423
# 	h0_max_x_mean_u: 0.811205983162
# 	h0_max_x_min_u: 0.439148873091
# 	h0_mean_x_max_u: 0.838918805122
# 	h0_mean_x_mean_u: 0.472998946905
# 	h0_mean_x_min_u: 0.117048718035
# 	h0_min_x_max_u: 0.512851297855
# 	h0_min_x_mean_u: 0.143852114677
# 	h0_min_x_min_u: 0.000720317184459
# 	h0_range_x_max_u: 0.963753461838
# 	h0_range_x_mean_u: 0.667353749275
# 	h0_range_x_min_u: 0.216138854623
# 	h0_row_norms_max: 5.20224189758
# 	h0_row_norms_mean: 2.68358469009
# 	h0_row_norms_min: 0.178024157882
# 	learning_rate: 0.0500000119209
# 	objective: 1.38399362564
# 	y0_col_norms_max: 6.30077934265
# 	y0_col_norms_mean: 4.9178647995
# 	y0_col_norms_min: 3.64990735054
# 	y0_max_max_class: 0.965671777725
# 	y0_mean_max_class: 0.550554215908
# 	y0_min_max_class: 0.138375326991
# 	y0_misclass: 0.351800024509
# 	y0_nll: 1.38399362564
# 	y0_row_norms_max: 4.67548418045
# 	y0_row_norms_mean: 1.76030647755
# 	y0_row_norms_min: 0.209328874946
# Monitoring step:
# 	Epochs seen: 9
# 	Batches seen: 6300
# 	Examples seen: 630000
# 	h0_col_norms_max: 6.70861148834
# 	h0_col_norms_mean: 4.45854377747
# 	h0_col_norms_min: 2.25826644897
# 	h0_max_x_max_u: 0.998206436634
# 	h0_max_x_mean_u: 0.81305283308
# 	h0_max_x_min_u: 0.4346126616
# 	h0_mean_x_max_u: 0.842338383198
# 	h0_mean_x_mean_u: 0.471628248692
# 	h0_mean_x_min_u: 0.111188881099
# 	h0_min_x_max_u: 0.513985455036
# 	h0_min_x_mean_u: 0.140619814396
# 	h0_min_x_min_u: 0.000583507877309
# 	h0_range_x_max_u: 0.966105401516
# 	h0_range_x_mean_u: 0.672433316708
# 	h0_range_x_min_u: 0.219027504325
# 	h0_row_norms_max: 5.20223093033
# 	h0_row_norms_mean: 2.68707942963
# 	h0_row_norms_min: 0.178808107972
# 	learning_rate: 0.0500000119209
# 	objective: 1.33984303474
# 	y0_col_norms_max: 6.33778238297
# 	y0_col_norms_mean: 4.95452737808
# 	y0_col_norms_min: 3.70574617386
# 	y0_max_max_class: 0.968366026878
# 	y0_mean_max_class: 0.55523955822
# 	y0_min_max_class: 0.136936560273
# 	y0_misclass: 0.339799940586
# 	y0_nll: 1.33984303474
# 	y0_row_norms_max: 4.71129322052
# 	y0_row_norms_mean: 1.77601265907
# 	y0_row_norms_min: 0.217719465494
# Monitoring step:
# 	Epochs seen: 10
# 	Batches seen: 7000
# 	Examples seen: 700000
# 	h0_col_norms_max: 6.72448968887
# 	h0_col_norms_mean: 4.46383571625
# 	h0_col_norms_min: 2.26501059532
# 	h0_max_x_max_u: 0.998390376568
# 	h0_max_x_mean_u: 0.815066158772
# 	h0_max_x_min_u: 0.432361871004
# 	h0_mean_x_max_u: 0.846026778221
# 	h0_mean_x_mean_u: 0.470656633377
# 	h0_mean_x_min_u: 0.105556704104
# 	h0_min_x_max_u: 0.515233635902
# 	h0_min_x_mean_u: 0.137727931142
# 	h0_min_x_min_u: 0.000468239421025
# 	h0_range_x_max_u: 0.968147039413
# 	h0_range_x_mean_u: 0.677338242531
# 	h0_range_x_min_u: 0.221574157476
# 	h0_row_norms_max: 5.20221614838
# 	h0_row_norms_mean: 2.69045162201
# 	h0_row_norms_min: 0.179624974728
# 	learning_rate: 0.0500000119209
# 	objective: 1.31606268883
# 	y0_col_norms_max: 6.37159442902
# 	y0_col_norms_mean: 4.98984718323
# 	y0_col_norms_min: 3.76045227051
# 	y0_max_max_class: 0.971903800964
# 	y0_mean_max_class: 0.57097029686
# 	y0_min_max_class: 0.147340774536
# 	y0_misclass: 0.337199985981
# 	y0_nll: 1.31606268883
# 	y0_row_norms_max: 4.74666023254
# 	y0_row_norms_mean: 1.79108703136
# 	y0_row_norms_min: 0.225445300341
# Monitoring step:
# 	Epochs seen: 11
# 	Batches seen: 7700
# 	Examples seen: 770000
# 	h0_col_norms_max: 6.7408452034
# 	h0_col_norms_mean: 4.46899318695
# 	h0_col_norms_min: 2.27154135704
# 	h0_max_x_max_u: 0.998568415642
# 	h0_max_x_mean_u: 0.816579818726
# 	h0_max_x_min_u: 0.429501146078
# 	h0_mean_x_max_u: 0.849537372589
# 	h0_mean_x_mean_u: 0.469631940126
# 	h0_mean_x_min_u: 0.101053163409
# 	h0_min_x_max_u: 0.516999900341
# 	h0_min_x_mean_u: 0.135200619698
# 	h0_min_x_min_u: 0.000383128062822
# 	h0_range_x_max_u: 0.970270514488
# 	h0_range_x_mean_u: 0.681379497051
# 	h0_range_x_min_u: 0.223657250404
# 	h0_row_norms_max: 5.20221185684
# 	h0_row_norms_mean: 2.69372677803
# 	h0_row_norms_min: 0.180470913649
# 	learning_rate: 0.0500000119209
# 	objective: 1.28500556946
# 	y0_col_norms_max: 6.4018239975
# 	y0_col_norms_mean: 5.02340173721
# 	y0_col_norms_min: 3.804874897
# 	y0_max_max_class: 0.973361730576
# 	y0_mean_max_class: 0.574674725533
# 	y0_min_max_class: 0.142294645309
# 	y0_misclass: 0.328799962997
# 	y0_nll: 1.28500556946
# 	y0_row_norms_max: 4.78043079376
# 	y0_row_norms_mean: 1.80530524254
# 	y0_row_norms_min: 0.233073458076
# Monitoring step:
# 	Epochs seen: 12
# 	Batches seen: 8400
# 	Examples seen: 840000
# 	h0_col_norms_max: 6.75757980347
# 	h0_col_norms_mean: 4.47409534454
# 	h0_col_norms_min: 2.27797865868
# 	h0_max_x_max_u: 0.998730421066
# 	h0_max_x_mean_u: 0.817869961262
# 	h0_max_x_min_u: 0.426013767719
# 	h0_mean_x_max_u: 0.853850603104
# 	h0_mean_x_mean_u: 0.468634516001
# 	h0_mean_x_min_u: 0.0969389304519
# 	h0_min_x_max_u: 0.519997060299
# 	h0_min_x_mean_u: 0.132917687297
# 	h0_min_x_min_u: 0.000322314881487
# 	h0_range_x_max_u: 0.972432911396
# 	h0_range_x_mean_u: 0.68495196104
# 	h0_range_x_min_u: 0.22548083961
# 	h0_row_norms_max: 5.2021985054
# 	h0_row_norms_mean: 2.69695162773
# 	h0_row_norms_min: 0.181377917528
# 	learning_rate: 0.0500000119209
# 	objective: 1.26203131676
# 	y0_col_norms_max: 6.43002080917
# 	y0_col_norms_mean: 5.05582380295
# 	y0_col_norms_min: 3.81722426414
# 	y0_max_max_class: 0.976741373539
# 	y0_mean_max_class: 0.581924557686
# 	y0_min_max_class: 0.148444414139
# 	y0_misclass: 0.324400037527
# 	y0_nll: 1.26203131676
# 	y0_row_norms_max: 4.81545066833
# 	y0_row_norms_mean: 1.81894230843
# 	y0_row_norms_min: 0.24026222527
# Monitoring step:
# 	Epochs seen: 13
# 	Batches seen: 9100
# 	Examples seen: 910000
# 	h0_col_norms_max: 6.77466773987
# 	h0_col_norms_mean: 4.47909069061
# 	h0_col_norms_min: 2.28371620178
# 	h0_max_x_max_u: 0.998887658119
# 	h0_max_x_mean_u: 0.819325268269
# 	h0_max_x_min_u: 0.423741787672
# 	h0_mean_x_max_u: 0.856598556042
# 	h0_mean_x_mean_u: 0.467905014753
# 	h0_mean_x_min_u: 0.0931221917272
# 	h0_min_x_max_u: 0.522430002689
# 	h0_min_x_mean_u: 0.130819246173
# 	h0_min_x_min_u: 0.000266046292381
# 	h0_range_x_max_u: 0.974562942982
# 	h0_range_x_mean_u: 0.688505887985
# 	h0_range_x_min_u: 0.22715947032
# 	h0_row_norms_max: 5.20219421387
# 	h0_row_norms_mean: 2.70009064674
# 	h0_row_norms_min: 0.182323172688
# 	learning_rate: 0.0500000119209
# 	objective: 1.2424082756
# 	y0_col_norms_max: 6.456553936
# 	y0_col_norms_mean: 5.08709430695
# 	y0_col_norms_min: 3.8306491375
# 	y0_max_max_class: 0.977570772171
# 	y0_mean_max_class: 0.586564898491
# 	y0_min_max_class: 0.150400772691
# 	y0_misclass: 0.321399986744
# 	y0_nll: 1.2424082756
# 	y0_row_norms_max: 4.84730768204
# 	y0_row_norms_mean: 1.83208072186
# 	y0_row_norms_min: 0.246381744742
# Monitoring step:
# 	Epochs seen: 14
# 	Batches seen: 9800
# 	Examples seen: 980000
# 	h0_col_norms_max: 6.79269886017
# 	h0_col_norms_mean: 4.4840388298
# 	h0_col_norms_min: 2.28983020782
# 	h0_max_x_max_u: 0.999053955078
# 	h0_max_x_mean_u: 0.820511519909
# 	h0_max_x_min_u: 0.421757638454
# 	h0_mean_x_max_u: 0.859741568565
# 	h0_mean_x_mean_u: 0.467141151428
# 	h0_mean_x_min_u: 0.0896450579166
# 	h0_min_x_max_u: 0.52326208353
# 	h0_min_x_mean_u: 0.128943428397
# 	h0_min_x_min_u: 0.000223875220399
# 	h0_range_x_max_u: 0.97622013092
# 	h0_range_x_mean_u: 0.691567957401
# 	h0_range_x_min_u: 0.22879371047
# 	h0_row_norms_max: 5.20217990875
# 	h0_row_norms_mean: 2.70319056511
# 	h0_row_norms_min: 0.183306246996
# 	learning_rate: 0.0500000119209
# 	objective: 1.2216565609
# 	y0_col_norms_max: 6.48116779327
# 	y0_col_norms_mean: 5.11745023727
# 	y0_col_norms_min: 3.84416747093
# 	y0_max_max_class: 0.980677187443
# 	y0_mean_max_class: 0.592677235603
# 	y0_min_max_class: 0.15485009551
# 	y0_misclass: 0.314800024033
# 	y0_nll: 1.2216565609
# 	y0_row_norms_max: 4.88023614883
# 	y0_row_norms_mean: 1.84468281269
# 	y0_row_norms_min: 0.252523988485
# Monitoring step:
# 	Epochs seen: 15
# 	Batches seen: 10500
# 	Examples seen: 1050000
# 	h0_col_norms_max: 6.81065416336
# 	h0_col_norms_mean: 4.48889780045
# 	h0_col_norms_min: 2.29540896416
# 	h0_max_x_max_u: 0.999188601971
# 	h0_max_x_mean_u: 0.821852147579
# 	h0_max_x_min_u: 0.420483976603
# 	h0_mean_x_max_u: 0.862642109394
# 	h0_mean_x_mean_u: 0.466561377048
# 	h0_mean_x_min_u: 0.0866305157542
# 	h0_min_x_max_u: 0.524886846542
# 	h0_min_x_mean_u: 0.127180784941
# 	h0_min_x_min_u: 0.000190438950085
# 	h0_range_x_max_u: 0.977758765221
# 	h0_range_x_mean_u: 0.694671273232
# 	h0_range_x_min_u: 0.230048239231
# 	h0_row_norms_max: 5.2021651268
# 	h0_row_norms_mean: 2.70621848106
# 	h0_row_norms_min: 0.184323385358
# 	learning_rate: 0.0500000119209
# 	objective: 1.19846343994
# 	y0_col_norms_max: 6.5076341629
# 	y0_col_norms_mean: 5.14670848846
# 	y0_col_norms_min: 3.85844755173
# 	y0_max_max_class: 0.979167103767
# 	y0_mean_max_class: 0.598063468933
# 	y0_min_max_class: 0.152615398169
# 	y0_misclass: 0.311699897051
# 	y0_nll: 1.19846343994
# 	y0_row_norms_max: 4.91201066971
# 	y0_row_norms_mean: 1.85689854622
# 	y0_row_norms_min: 0.258969902992
# Monitoring step:
# 	Epochs seen: 16
# 	Batches seen: 11200
# 	Examples seen: 1120000
# 	h0_col_norms_max: 6.82944965363
# 	h0_col_norms_mean: 4.4937877655
# 	h0_col_norms_min: 2.30139732361
# 	h0_max_x_max_u: 0.999313414097
# 	h0_max_x_mean_u: 0.822805821896
# 	h0_max_x_min_u: 0.418263286352
# 	h0_mean_x_max_u: 0.865755796432
# 	h0_mean_x_mean_u: 0.46578502655
# 	h0_mean_x_min_u: 0.0836576968431
# 	h0_min_x_max_u: 0.526851594448
# 	h0_min_x_mean_u: 0.125527009368
# 	h0_min_x_min_u: 0.00016164011322
# 	h0_range_x_max_u: 0.979079008102
# 	h0_range_x_mean_u: 0.697279155254
# 	h0_range_x_min_u: 0.231275498867
# 	h0_row_norms_max: 5.20215082169
# 	h0_row_norms_mean: 2.70924592018
# 	h0_row_norms_min: 0.185351461172
# 	learning_rate: 0.0500000119209
# 	objective: 1.18514811993
# 	y0_col_norms_max: 6.57440567017
# 	y0_col_norms_mean: 5.17549419403
# 	y0_col_norms_min: 3.87228131294
# 	y0_max_max_class: 0.977351784706
# 	y0_mean_max_class: 0.597420275211
# 	y0_min_max_class: 0.153941765428
# 	y0_misclass: 0.308799952269
# 	y0_nll: 1.18514811993
# 	y0_row_norms_max: 4.94306945801
# 	y0_row_norms_mean: 1.86872172356
# 	y0_row_norms_min: 0.2636757195
# Monitoring step:
# 	Epochs seen: 17
# 	Batches seen: 11900
# 	Examples seen: 1190000
# 	h0_col_norms_max: 6.84746313095
# 	h0_col_norms_mean: 4.49858140945
# 	h0_col_norms_min: 2.3067688942
# 	h0_max_x_max_u: 0.999422609806
# 	h0_max_x_mean_u: 0.824011027813
# 	h0_max_x_min_u: 0.41715708375
# 	h0_mean_x_max_u: 0.867499351501
# 	h0_mean_x_mean_u: 0.465320646763
# 	h0_mean_x_min_u: 0.0816204547882
# 	h0_min_x_max_u: 0.526755809784
# 	h0_min_x_mean_u: 0.123974978924
# 	h0_min_x_min_u: 0.000137838389492
# 	h0_range_x_max_u: 0.980443835258
# 	h0_range_x_mean_u: 0.700036168098
# 	h0_range_x_min_u: 0.232643291354
# 	h0_row_norms_max: 5.20214557648
# 	h0_row_norms_mean: 2.71221065521
# 	h0_row_norms_min: 0.186432510614
# 	learning_rate: 0.0500000119209
# 	objective: 1.1730068922
# 	y0_col_norms_max: 6.63610649109
# 	y0_col_norms_mean: 5.20338630676
# 	y0_col_norms_min: 3.8883497715
# 	y0_max_max_class: 0.979398190975
# 	y0_mean_max_class: 0.598551928997
# 	y0_min_max_class: 0.153540179133
# 	y0_misclass: 0.307200014591
# 	y0_nll: 1.1730068922
# 	y0_row_norms_max: 4.97437953949
# 	y0_row_norms_mean: 1.8801959753
# 	y0_row_norms_min: 0.269537061453
# Monitoring step:
# 	Epochs seen: 18
# 	Batches seen: 12600
# 	Examples seen: 1260000
# 	h0_col_norms_max: 6.86682319641
# 	h0_col_norms_mean: 4.50339365005
# 	h0_col_norms_min: 2.31233620644
# 	h0_max_x_max_u: 0.999516963959
# 	h0_max_x_mean_u: 0.825054645538
# 	h0_max_x_min_u: 0.415735602379
# 	h0_mean_x_max_u: 0.86960953474
# 	h0_mean_x_mean_u: 0.46474981308
# 	h0_mean_x_min_u: 0.078937202692
# 	h0_min_x_max_u: 0.526811599731
# 	h0_min_x_mean_u: 0.122473374009
# 	h0_min_x_min_u: 0.000119351301691
# 	h0_range_x_max_u: 0.981574773788
# 	h0_range_x_mean_u: 0.702581107616
# 	h0_range_x_min_u: 0.234001144767
# 	h0_row_norms_max: 5.20213222504
# 	h0_row_norms_mean: 2.71517372131
# 	h0_row_norms_min: 0.187550604343
# 	learning_rate: 0.0500000119209
# 	objective: 1.15322387218
# 	y0_col_norms_max: 6.69969367981
# 	y0_col_norms_mean: 5.23075580597
# 	y0_col_norms_min: 3.90060520172
# 	y0_max_max_class: 0.981929063797
# 	y0_mean_max_class: 0.611525595188
# 	y0_min_max_class: 0.158794820309
# 	y0_misclass: 0.301899939775
# 	y0_nll: 1.15322387218
# 	y0_row_norms_max: 5.0061044693
# 	y0_row_norms_mean: 1.89147019386
# 	y0_row_norms_min: 0.274556845427
# Monitoring step:
# 	Epochs seen: 19
# 	Batches seen: 13300
# 	Examples seen: 1330000
# 	h0_col_norms_max: 6.88600873947
# 	h0_col_norms_mean: 4.50815629959
# 	h0_col_norms_min: 2.31795573235
# 	h0_max_x_max_u: 0.999599575996
# 	h0_max_x_mean_u: 0.826031208038
# 	h0_max_x_min_u: 0.414205819368
# 	h0_mean_x_max_u: 0.871385455132
# 	h0_mean_x_mean_u: 0.464278191328
# 	h0_mean_x_min_u: 0.0765586197376
# 	h0_min_x_max_u: 0.526606321335
# 	h0_min_x_mean_u: 0.121115654707
# 	h0_min_x_min_u: 0.000102197343949
# 	h0_range_x_max_u: 0.982713222504
# 	h0_range_x_mean_u: 0.704915463924
# 	h0_range_x_min_u: 0.235197812319
# 	h0_row_norms_max: 5.20211648941
# 	h0_row_norms_mean: 2.71808433533
# 	h0_row_norms_min: 0.188663721085
# 	learning_rate: 0.0500000119209
# 	objective: 1.1383459568
# 	y0_col_norms_max: 6.75912189484
# 	y0_col_norms_mean: 5.25741195679
# 	y0_col_norms_min: 3.91526079178
# 	y0_max_max_class: 0.981744766235
# 	y0_mean_max_class: 0.608007609844
# 	y0_min_max_class: 0.157311916351
# 	y0_misclass: 0.300400018692
# 	y0_nll: 1.1383459568
# 	y0_row_norms_max: 5.03556203842
# 	y0_row_norms_mean: 1.90233004093
# 	y0_row_norms_min: 0.27922102809
# Monitoring step:
# 	Epochs seen: 20
# 	Batches seen: 14000
# 	Examples seen: 1400000
# 	h0_col_norms_max: 6.9055185318
# 	h0_col_norms_mean: 4.51292943954
# 	h0_col_norms_min: 2.32348203659
# 	h0_max_x_max_u: 0.99966531992
# 	h0_max_x_mean_u: 0.827069818974
# 	h0_max_x_min_u: 0.413228005171
# 	h0_mean_x_max_u: 0.873442709446
# 	h0_mean_x_mean_u: 0.463807225227
# 	h0_mean_x_min_u: 0.0743419006467
# 	h0_min_x_max_u: 0.526465117931
# 	h0_min_x_mean_u: 0.119795568287
# 	h0_min_x_min_u: 8.97258287296e-05
# 	h0_range_x_max_u: 0.983564257622
# 	h0_range_x_mean_u: 0.707274198532
# 	h0_range_x_min_u: 0.236258268356
# 	h0_row_norms_max: 5.20210409164
# 	h0_row_norms_mean: 2.72099924088
# 	h0_row_norms_min: 0.189804911613
# 	learning_rate: 0.0500000119209
# 	objective: 1.12473881245
# 	y0_col_norms_max: 6.82020235062
# 	y0_col_norms_mean: 5.28375387192
# 	y0_col_norms_min: 3.92851233482
# 	y0_max_max_class: 0.983108997345
# 	y0_mean_max_class: 0.617405593395
# 	y0_min_max_class: 0.161070674658
# 	y0_misclass: 0.295599937439
# 	y0_nll: 1.12473881245
# 	y0_row_norms_max: 5.0666179657
# 	y0_row_norms_mean: 1.9131039381
# 	y0_row_norms_min: 0.283238619566
# Monitoring step:
# 	Epochs seen: 21
# 	Batches seen: 14700
# 	Examples seen: 1470000
# 	h0_col_norms_max: 6.92524957657
# 	h0_col_norms_mean: 4.51767110825
# 	h0_col_norms_min: 2.32903122902
# 	h0_max_x_max_u: 0.999722480774
# 	h0_max_x_mean_u: 0.828045248985
# 	h0_max_x_min_u: 0.412587344646
# 	h0_mean_x_max_u: 0.876020610332
# 	h0_mean_x_mean_u: 0.463421523571
# 	h0_mean_x_min_u: 0.0729787498713
# 	h0_min_x_max_u: 0.527292490005
# 	h0_min_x_mean_u: 0.118628837168
# 	h0_min_x_min_u: 7.91330967331e-05
# 	h0_range_x_max_u: 0.984615266323
# 	h0_range_x_mean_u: 0.709416210651
# 	h0_range_x_min_u: 0.237383231521
# 	h0_row_norms_max: 5.20209789276
# 	h0_row_norms_mean: 2.72388243675
# 	h0_row_norms_min: 0.190943494439
# 	learning_rate: 0.0500000119209
# 	objective: 1.11244452
# 	y0_col_norms_max: 6.88120317459
# 	y0_col_norms_mean: 5.30948495865
# 	y0_col_norms_min: 3.94294309616
# 	y0_max_max_class: 0.98252338171
# 	y0_mean_max_class: 0.622131645679
# 	y0_min_max_class: 0.163150832057
# 	y0_misclass: 0.292399913073
# 	y0_nll: 1.11244452
# 	y0_row_norms_max: 5.09567403793
# 	y0_row_norms_mean: 1.9236112833
# 	y0_row_norms_min: 0.286658555269
# Monitoring step:
# 	Epochs seen: 22
# 	Batches seen: 15400
# 	Examples seen: 1540000
# 	h0_col_norms_max: 6.94503688812
# 	h0_col_norms_mean: 4.52242422104
# 	h0_col_norms_min: 2.33468937874
# 	h0_max_x_max_u: 0.999764978886
# 	h0_max_x_mean_u: 0.828845143318
# 	h0_max_x_min_u: 0.410626977682
# 	h0_mean_x_max_u: 0.878633975983
# 	h0_mean_x_mean_u: 0.462923645973
# 	h0_mean_x_min_u: 0.0707540363073
# 	h0_min_x_max_u: 0.528625309467
# 	h0_min_x_mean_u: 0.117522716522
# 	h0_min_x_min_u: 6.94385889801e-05
# 	h0_range_x_max_u: 0.98523491621
# 	h0_range_x_mean_u: 0.711322188377
# 	h0_range_x_min_u: 0.238271832466
# 	h0_row_norms_max: 5.20208454132
# 	h0_row_norms_mean: 2.7267537117
# 	h0_row_norms_min: 0.192089781165
# 	learning_rate: 0.0500000119209
# 	objective: 1.09816777706
# 	y0_col_norms_max: 6.93549776077
# 	y0_col_norms_mean: 5.33471441269
# 	y0_col_norms_min: 3.95724892616
# 	y0_max_max_class: 0.983858764172
# 	y0_mean_max_class: 0.622402489185
# 	y0_min_max_class: 0.16118735075
# 	y0_misclass: 0.28900000453
# 	y0_nll: 1.09816777706
# 	y0_row_norms_max: 5.12528467178
# 	y0_row_norms_mean: 1.9338363409
# 	y0_row_norms_min: 0.290664941072
# Monitoring step:
# 	Epochs seen: 23
# 	Batches seen: 16100
# 	Examples seen: 1610000
# 	h0_col_norms_max: 6.9639673233
# 	h0_col_norms_mean: 4.52715921402
# 	h0_col_norms_min: 2.34046816826
# 	h0_max_x_max_u: 0.9998010993
# 	h0_max_x_mean_u: 0.829900920391
# 	h0_max_x_min_u: 0.409650593996
# 	h0_mean_x_max_u: 0.87995839119
# 	h0_mean_x_mean_u: 0.462643057108
# 	h0_mean_x_min_u: 0.0695882067084
# 	h0_min_x_max_u: 0.527741611004
# 	h0_min_x_mean_u: 0.116366773844
# 	h0_min_x_min_u: 6.20892242296e-05
# 	h0_range_x_max_u: 0.986062169075
# 	h0_range_x_mean_u: 0.71353417635
# 	h0_range_x_min_u: 0.239093795419
# 	h0_row_norms_max: 5.20206880569
# 	h0_row_norms_mean: 2.72960448265
# 	h0_row_norms_min: 0.193260505795
# 	learning_rate: 0.0500000119209
# 	objective: 1.08729624748
# 	y0_col_norms_max: 6.99163770676
# 	y0_col_norms_mean: 5.35970067978
# 	y0_col_norms_min: 3.97105336189
# 	y0_max_max_class: 0.985534489155
# 	y0_mean_max_class: 0.628228008747
# 	y0_min_max_class: 0.168042883277
# 	y0_misclass: 0.288399994373
# 	y0_nll: 1.08729624748
# 	y0_row_norms_max: 5.15317964554
# 	y0_row_norms_mean: 1.94397211075
# 	y0_row_norms_min: 0.295816838741
# Monitoring step:
# 	Epochs seen: 24
# 	Batches seen: 16800
# 	Examples seen: 1680000
# 	h0_col_norms_max: 6.98371267319
# 	h0_col_norms_mean: 4.53191232681
# 	h0_col_norms_min: 2.34630322456
# 	h0_max_x_max_u: 0.999830543995
# 	h0_max_x_mean_u: 0.830756604671
# 	h0_max_x_min_u: 0.408456772566
# 	h0_mean_x_max_u: 0.881654381752
# 	h0_mean_x_mean_u: 0.462233245373
# 	h0_mean_x_min_u: 0.0674661621451
# 	h0_min_x_max_u: 0.527419388294
# 	h0_min_x_mean_u: 0.11530982703
# 	h0_min_x_min_u: 5.53572026547e-05
# 	h0_range_x_max_u: 0.986677765846
# 	h0_range_x_mean_u: 0.715446770191
# 	h0_range_x_min_u: 0.240152031183
# 	h0_row_norms_max: 5.20205640793
# 	h0_row_norms_mean: 2.73245239258
# 	h0_row_norms_min: 0.194436684251
# 	learning_rate: 0.0500000119209
# 	objective: 1.08146393299
# 	y0_col_norms_max: 7.04574871063
# 	y0_col_norms_mean: 5.38431549072
# 	y0_col_norms_min: 3.98542308807
# 	y0_max_max_class: 0.983030498028
# 	y0_mean_max_class: 0.63257163763
# 	y0_min_max_class: 0.168110653758
# 	y0_misclass: 0.288100004196
# 	y0_nll: 1.08146393299
# 	y0_row_norms_max: 5.18126535416
# 	y0_row_norms_mean: 1.95391201973
# 	y0_row_norms_min: 0.298544734716
# Monitoring step:
# 	Epochs seen: 25
# 	Batches seen: 17500
# 	Examples seen: 1750000
# 	h0_col_norms_max: 7.00322532654
# 	h0_col_norms_mean: 4.53664588928
# 	h0_col_norms_min: 2.35177659988
# 	h0_max_x_max_u: 0.999856710434
# 	h0_max_x_mean_u: 0.831625819206
# 	h0_max_x_min_u: 0.407306224108
# 	h0_mean_x_max_u: 0.883183062077
# 	h0_mean_x_mean_u: 0.461926549673
# 	h0_mean_x_min_u: 0.0663268268108
# 	h0_min_x_max_u: 0.527416050434
# 	h0_min_x_mean_u: 0.114324934781
# 	h0_min_x_min_u: 5.04315103171e-05
# 	h0_range_x_max_u: 0.987335383892
# 	h0_range_x_mean_u: 0.717301011086
# 	h0_range_x_min_u: 0.241144642234
# 	h0_row_norms_max: 5.20205020905
# 	h0_row_norms_mean: 2.73528075218
# 	h0_row_norms_min: 0.195608645678
# 	learning_rate: 0.0500000119209
# 	objective: 1.0641772747
# 	y0_col_norms_max: 7.10181856155
# 	y0_col_norms_mean: 5.40848207474
# 	y0_col_norms_min: 3.99811124802
# 	y0_max_max_class: 0.985230624676
# 	y0_mean_max_class: 0.632628619671
# 	y0_min_max_class: 0.165635436773
# 	y0_misclass: 0.284899950027
# 	y0_nll: 1.0641772747
# 	y0_row_norms_max: 5.20955610275
# 	y0_row_norms_mean: 1.96361243725
# 	y0_row_norms_min: 0.302782356739
# Monitoring step:
# 	Epochs seen: 26
# 	Batches seen: 18200
# 	Examples seen: 1820000
# 	h0_col_norms_max: 7.02203369141
# 	h0_col_norms_mean: 4.54139661789
# 	h0_col_norms_min: 2.35733914375
# 	h0_max_x_max_u: 0.999877810478
# 	h0_max_x_mean_u: 0.832457065582
# 	h0_max_x_min_u: 0.406166285276
# 	h0_mean_x_max_u: 0.884599864483
# 	h0_mean_x_mean_u: 0.461609423161
# 	h0_mean_x_min_u: 0.0649443864822
# 	h0_min_x_max_u: 0.527783215046
# 	h0_min_x_mean_u: 0.113359093666
# 	h0_min_x_min_u: 4.57084206573e-05
# 	h0_range_x_max_u: 0.987969100475
# 	h0_range_x_mean_u: 0.719097614288
# 	h0_range_x_min_u: 0.242049947381
# 	h0_row_norms_max: 5.2020368576
# 	h0_row_norms_mean: 2.7381029129
# 	h0_row_norms_min: 0.196784749627
# 	learning_rate: 0.0500000119209
# 	objective: 1.05612659454
# 	y0_col_norms_max: 7.1514954567
# 	y0_col_norms_mean: 5.43258857727
# 	y0_col_norms_min: 4.01129579544
# 	y0_max_max_class: 0.984615206718
# 	y0_mean_max_class: 0.6357883811
# 	y0_min_max_class: 0.170936986804
# 	y0_misclass: 0.281599998474
# 	y0_nll: 1.05612659454
# 	y0_row_norms_max: 5.23665952682
# 	y0_row_norms_mean: 1.97331607342
# 	y0_row_norms_min: 0.306320279837
# Monitoring step:
# 	Epochs seen: 27
# 	Batches seen: 18900
# 	Examples seen: 1890000
# 	h0_col_norms_max: 7.04092645645
# 	h0_col_norms_mean: 4.54613780975
# 	h0_col_norms_min: 2.36335730553
# 	h0_max_x_max_u: 0.999895215034
# 	h0_max_x_mean_u: 0.833366513252
# 	h0_max_x_min_u: 0.405678600073
# 	h0_mean_x_max_u: 0.886886775494
# 	h0_mean_x_mean_u: 0.461388230324
# 	h0_mean_x_min_u: 0.0635567680001
# 	h0_min_x_max_u: 0.529219090939
# 	h0_min_x_mean_u: 0.112498186529
# 	h0_min_x_min_u: 4.22295124736e-05
# 	h0_range_x_max_u: 0.988632380962
# 	h0_range_x_mean_u: 0.720868527889
# 	h0_range_x_min_u: 0.242853522301
# 	h0_row_norms_max: 5.20202112198
# 	h0_row_norms_mean: 2.74091458321
# 	h0_row_norms_min: 0.197971314192
# 	learning_rate: 0.0500000119209
# 	objective: 1.03978526592
# 	y0_col_norms_max: 7.2032456398
# 	y0_col_norms_mean: 5.45620965958
# 	y0_col_norms_min: 4.0255355835
# 	y0_max_max_class: 0.986285746098
# 	y0_mean_max_class: 0.640500664711
# 	y0_min_max_class: 0.174854189157
# 	y0_misclass: 0.277900010347
# 	y0_nll: 1.03978526592
# 	y0_row_norms_max: 5.26413965225
# 	y0_row_norms_mean: 1.98284089565
# 	y0_row_norms_min: 0.31075501442
# Monitoring step:
# 	Epochs seen: 28
# 	Batches seen: 19600
# 	Examples seen: 1960000
# 	h0_col_norms_max: 7.05996656418
# 	h0_col_norms_mean: 4.55089139938
# 	h0_col_norms_min: 2.36941146851
# 	h0_max_x_max_u: 0.999908328056
# 	h0_max_x_mean_u: 0.834047198296
# 	h0_max_x_min_u: 0.404358565807
# 	h0_mean_x_max_u: 0.888548195362
# 	h0_mean_x_mean_u: 0.461025893688
# 	h0_mean_x_min_u: 0.0622047893703
# 	h0_min_x_max_u: 0.529432535172
# 	h0_min_x_mean_u: 0.111634418368
# 	h0_min_x_min_u: 3.88804219256e-05
# 	h0_range_x_max_u: 0.989244520664
# 	h0_range_x_mean_u: 0.72241294384
# 	h0_range_x_min_u: 0.243683159351
# 	h0_row_norms_max: 5.20200777054
# 	h0_row_norms_mean: 2.74372315407
# 	h0_row_norms_min: 0.199155151844
# 	learning_rate: 0.0500000119209
# 	objective: 1.0345736742
# 	y0_col_norms_max: 7.24968910217
# 	y0_col_norms_mean: 5.47970438004
# 	y0_col_norms_min: 4.03766155243
# 	y0_max_max_class: 0.986321389675
# 	y0_mean_max_class: 0.638256490231
# 	y0_min_max_class: 0.172947704792
# 	y0_misclass: 0.274099975824
# 	y0_nll: 1.0345736742
# 	y0_row_norms_max: 5.29117202759
# 	y0_row_norms_mean: 1.99223530293
# 	y0_row_norms_min: 0.314755350351
# Monitoring step:
# 	Epochs seen: 29
# 	Batches seen: 20300
# 	Examples seen: 2030000
# 	h0_col_norms_max: 7.07860040665
# 	h0_col_norms_mean: 4.55565404892
# 	h0_col_norms_min: 2.3754336834
# 	h0_max_x_max_u: 0.999920606613
# 	h0_max_x_mean_u: 0.834919691086
# 	h0_max_x_min_u: 0.404372960329
# 	h0_mean_x_max_u: 0.890159070492
# 	h0_mean_x_mean_u: 0.460743427277
# 	h0_mean_x_min_u: 0.0610471963882
# 	h0_min_x_max_u: 0.529054880142
# 	h0_min_x_mean_u: 0.110747747123
# 	h0_min_x_min_u: 3.5775006836e-05
# 	h0_range_x_max_u: 0.989632308483
# 	h0_range_x_mean_u: 0.724171638489
# 	h0_range_x_min_u: 0.244402274489
# 	h0_row_norms_max: 5.202003479
# 	h0_row_norms_mean: 2.74651861191
# 	h0_row_norms_min: 0.200341641903
# 	learning_rate: 0.0500000119209
# 	objective: 1.0209094286
# 	y0_col_norms_max: 7.29883861542
# 	y0_col_norms_mean: 5.50305080414
# 	y0_col_norms_min: 4.05058908463
# 	y0_max_max_class: 0.985620498657
# 	y0_mean_max_class: 0.642233967781
# 	y0_min_max_class: 0.171274468303
# 	y0_misclass: 0.274800002575
# 	y0_nll: 1.0209094286
# 	y0_row_norms_max: 5.31727647781
# 	y0_row_norms_mean: 2.0016067028
# 	y0_row_norms_min: 0.317926347256
# Monitoring step:
# 	Epochs seen: 30
# 	Batches seen: 21000
# 	Examples seen: 2100000
# 	h0_col_norms_max: 7.09697055817
# 	h0_col_norms_mean: 4.56042337418
# 	h0_col_norms_min: 2.38152527809
# 	h0_max_x_max_u: 0.999930739403
# 	h0_max_x_mean_u: 0.83572781086
# 	h0_max_x_min_u: 0.403082072735
# 	h0_mean_x_max_u: 0.891552686691
# 	h0_mean_x_mean_u: 0.460471868515
# 	h0_mean_x_min_u: 0.0595903210342
# 	h0_min_x_max_u: 0.529365181923
# 	h0_min_x_mean_u: 0.109935887158
# 	h0_min_x_min_u: 3.26900371874e-05
# 	h0_range_x_max_u: 0.99003136158
# 	h0_range_x_mean_u: 0.725791811943
# 	h0_range_x_min_u: 0.245078623295
# 	h0_row_norms_max: 5.20199251175
# 	h0_row_norms_mean: 2.74931526184
# 	h0_row_norms_min: 0.201535105705
# 	learning_rate: 0.0500000119209
# 	objective: 1.0169519186
# 	y0_col_norms_max: 7.34747552872
# 	y0_col_norms_mean: 5.52611017227
# 	y0_col_norms_min: 4.0630812645
# 	y0_max_max_class: 0.984959185123
# 	y0_mean_max_class: 0.650128483772
# 	y0_min_max_class: 0.177158400416
# 	y0_misclass: 0.275199949741
# 	y0_nll: 1.0169519186
# 	y0_row_norms_max: 5.34106731415
# 	y0_row_norms_mean: 2.01086091995
# 	y0_row_norms_min: 0.321238338947
# Monitoring step:
# 	Epochs seen: 31
# 	Batches seen: 21700
# 	Examples seen: 2170000
# 	h0_col_norms_max: 7.11522197723
# 	h0_col_norms_mean: 4.56521129608
# 	h0_col_norms_min: 2.38780021667
# 	h0_max_x_max_u: 0.999938666821
# 	h0_max_x_mean_u: 0.836518108845
# 	h0_max_x_min_u: 0.402903854847
# 	h0_mean_x_max_u: 0.893303453922
# 	h0_mean_x_mean_u: 0.460204929113
# 	h0_mean_x_min_u: 0.0588229112327
# 	h0_min_x_max_u: 0.529863476753
# 	h0_min_x_mean_u: 0.109114453197
# 	h0_min_x_min_u: 3.08281523758e-05
# 	h0_range_x_max_u: 0.990572214127
# 	h0_range_x_mean_u: 0.727403521538
# 	h0_range_x_min_u: 0.245708763599
# 	h0_row_norms_max: 5.20197677612
# 	h0_row_norms_mean: 2.75210475922
# 	h0_row_norms_min: 0.202721446753
# 	learning_rate: 0.0500000119209
# 	objective: 1.00485503674
# 	y0_col_norms_max: 7.39780473709
# 	y0_col_norms_mean: 5.54906225204
# 	y0_col_norms_min: 4.07519483566
# 	y0_max_max_class: 0.986046135426
# 	y0_mean_max_class: 0.648053884506
# 	y0_min_max_class: 0.174258187413
# 	y0_misclass: 0.268700003624
# 	y0_nll: 1.00485503674
# 	y0_row_norms_max: 5.36805963516
# 	y0_row_norms_mean: 2.02000069618
# 	y0_row_norms_min: 0.324765712023
# Monitoring step:
# 	Epochs seen: 32
# 	Batches seen: 22400
# 	Examples seen: 2240000
# 	h0_col_norms_max: 7.13342571259
# 	h0_col_norms_mean: 4.56996440887
# 	h0_col_norms_min: 2.39398241043
# 	h0_max_x_max_u: 0.999945402145
# 	h0_max_x_mean_u: 0.837383806705
# 	h0_max_x_min_u: 0.401969999075
# 	h0_mean_x_max_u: 0.894108176231
# 	h0_mean_x_mean_u: 0.459965288639
# 	h0_mean_x_min_u: 0.0576779693365
# 	h0_min_x_max_u: 0.529187202454
# 	h0_min_x_mean_u: 0.108267202973
# 	h0_min_x_min_u: 2.86116610368e-05
# 	h0_range_x_max_u: 0.990992426872
# 	h0_range_x_mean_u: 0.729116559029
# 	h0_range_x_min_u: 0.246370255947
# 	h0_row_norms_max: 5.20197343826
# 	h0_row_norms_mean: 2.75487041473
# 	h0_row_norms_min: 0.203873232007
# 	learning_rate: 0.0500000119209
# 	objective: 0.992530584335
# 	y0_col_norms_max: 7.44820642471
# 	y0_col_norms_mean: 5.57175111771
# 	y0_col_norms_min: 4.0884308815
# 	y0_max_max_class: 0.987434387207
# 	y0_mean_max_class: 0.656689882278
# 	y0_min_max_class: 0.175720617175
# 	y0_misclass: 0.265900015831
# 	y0_nll: 0.992530584335
# 	y0_row_norms_max: 5.39205646515
# 	y0_row_norms_mean: 2.02910661697
# 	y0_row_norms_min: 0.328918367624
# Monitoring step:
# 	Epochs seen: 33
# 	Batches seen: 23100
# 	Examples seen: 2310000
# 	h0_col_norms_max: 7.15088939667
# 	h0_col_norms_mean: 4.5747590065
# 	h0_col_norms_min: 2.40053153038
# 	h0_max_x_max_u: 0.999951243401
# 	h0_max_x_mean_u: 0.838121831417
# 	h0_max_x_min_u: 0.401136130095
# 	h0_mean_x_max_u: 0.896185278893
# 	h0_mean_x_mean_u: 0.45971006155
# 	h0_mean_x_min_u: 0.0569187998772
# 	h0_min_x_max_u: 0.530606865883
# 	h0_min_x_mean_u: 0.107528172433
# 	h0_min_x_min_u: 2.68996827799e-05
# 	h0_range_x_max_u: 0.991412818432
# 	h0_range_x_mean_u: 0.730593562126
# 	h0_range_x_min_u: 0.247075229883
# 	h0_row_norms_max: 5.20196342468
# 	h0_row_norms_mean: 2.75763821602
# 	h0_row_norms_min: 0.205063402653
# 	learning_rate: 0.0500000119209
# 	objective: 0.985263049603
# 	y0_col_norms_max: 7.50546741486
# 	y0_col_norms_mean: 5.59436178207
# 	y0_col_norms_min: 4.10087633133
# 	y0_max_max_class: 0.987176299095
# 	y0_mean_max_class: 0.653024017811
# 	y0_min_max_class: 0.173346623778
# 	y0_misclass: 0.263499975204
# 	y0_nll: 0.985263049603
# 	y0_row_norms_max: 5.41704368591
# 	y0_row_norms_mean: 2.03807425499
# 	y0_row_norms_min: 0.332322955132
# Monitoring step:
# 	Epochs seen: 34
# 	Batches seen: 23800
# 	Examples seen: 2380000
# 	h0_col_norms_max: 7.16835069656
# 	h0_col_norms_mean: 4.57952833176
# 	h0_col_norms_min: 2.40698814392
# 	h0_max_x_max_u: 0.999956190586
# 	h0_max_x_mean_u: 0.83892595768
# 	h0_max_x_min_u: 0.400371491909
# 	h0_mean_x_max_u: 0.897090017796
# 	h0_mean_x_mean_u: 0.459492444992
# 	h0_mean_x_min_u: 0.0556541383266
# 	h0_min_x_max_u: 0.531055569649
# 	h0_min_x_mean_u: 0.106775224209
# 	h0_min_x_min_u: 2.56456987699e-05
# 	h0_range_x_max_u: 0.991898179054
# 	h0_range_x_mean_u: 0.732150793076
# 	h0_range_x_min_u: 0.247787132859
# 	h0_row_norms_max: 5.20195913315
# 	h0_row_norms_mean: 2.76038813591
# 	h0_row_norms_min: 0.206203863025
# 	learning_rate: 0.0500000119209
# 	objective: 0.9776237607
# 	y0_col_norms_max: 7.59001922607
# 	y0_col_norms_mean: 5.61676359177
# 	y0_col_norms_min: 4.11124229431
# 	y0_max_max_class: 0.988541066647
# 	y0_mean_max_class: 0.659739732742
# 	y0_min_max_class: 0.176569059491
# 	y0_misclass: 0.261499971151
# 	y0_nll: 0.9776237607
# 	y0_row_norms_max: 5.44222450256
# 	y0_row_norms_mean: 2.04697585106
# 	y0_row_norms_min: 0.335334897041
# Monitoring step:
# 	Epochs seen: 35
# 	Batches seen: 24500
# 	Examples seen: 2450000
# 	h0_col_norms_max: 7.1852812767
# 	h0_col_norms_mean: 4.58433294296
# 	h0_col_norms_min: 2.41367888451
# 	h0_max_x_max_u: 0.999960541725
# 	h0_max_x_mean_u: 0.839680433273
# 	h0_max_x_min_u: 0.399475336075
# 	h0_mean_x_max_u: 0.898779630661
# 	h0_mean_x_mean_u: 0.459237426519
# 	h0_mean_x_min_u: 0.0550686120987
# 	h0_min_x_max_u: 0.532143771648
# 	h0_min_x_mean_u: 0.106069840491
# 	h0_min_x_min_u: 2.40757526626e-05
# 	h0_range_x_max_u: 0.992251932621
# 	h0_range_x_mean_u: 0.733610451221
# 	h0_range_x_min_u: 0.248341277242
# 	h0_row_norms_max: 5.20195817947
# 	h0_row_norms_mean: 2.76314997673
# 	h0_row_norms_min: 0.2073764503
# 	learning_rate: 0.0500000119209
# 	objective: 0.964793026447
# 	y0_col_norms_max: 7.67540979385
# 	y0_col_norms_mean: 5.63911962509
# 	y0_col_norms_min: 4.12211275101
# 	y0_max_max_class: 0.987431883812
# 	y0_mean_max_class: 0.657895326614
# 	y0_min_max_class: 0.181340277195
# 	y0_misclass: 0.257899999619
# 	y0_nll: 0.964793026447
# 	y0_row_norms_max: 5.46526765823
# 	y0_row_norms_mean: 2.05585980415
# 	y0_row_norms_min: 0.339037150145
# Monitoring step:
# 	Epochs seen: 36
# 	Batches seen: 25200
# 	Examples seen: 2520000
# 	h0_col_norms_max: 7.20219564438
# 	h0_col_norms_mean: 4.58914804459
# 	h0_col_norms_min: 2.42036175728
# 	h0_max_x_max_u: 0.999964475632
# 	h0_max_x_mean_u: 0.840459764004
# 	h0_max_x_min_u: 0.39839926362
# 	h0_mean_x_max_u: 0.899796307087
# 	h0_mean_x_mean_u: 0.459016978741
# 	h0_mean_x_min_u: 0.0543191321194
# 	h0_min_x_max_u: 0.531943619251
# 	h0_min_x_mean_u: 0.105351433158
# 	h0_min_x_min_u: 2.28866774705e-05
# 	h0_range_x_max_u: 0.992614209652
# 	h0_range_x_mean_u: 0.735108375549
# 	h0_range_x_min_u: 0.248977005482
# 	h0_row_norms_max: 5.20195484161
# 	h0_row_norms_mean: 2.76589465141
# 	h0_row_norms_min: 0.208559200168
# 	learning_rate: 0.0500000119209
# 	objective: 0.959475576878
# 	y0_col_norms_max: 7.76060819626
# 	y0_col_norms_mean: 5.66132879257
# 	y0_col_norms_min: 4.13572263718
# 	y0_max_max_class: 0.987481117249
# 	y0_mean_max_class: 0.658438742161
# 	y0_min_max_class: 0.183150798082
# 	y0_misclass: 0.257099986076
# 	y0_nll: 0.959475576878
# 	y0_row_norms_max: 5.48950576782
# 	y0_row_norms_mean: 2.06471633911
# 	y0_row_norms_min: 0.34183177352
# Monitoring step:
# 	Epochs seen: 37
# 	Batches seen: 25900
# 	Examples seen: 2590000
# 	h0_col_norms_max: 7.21883773804
# 	h0_col_norms_mean: 4.59394407272
# 	h0_col_norms_min: 2.42716479301
# 	h0_max_x_max_u: 0.999967753887
# 	h0_max_x_mean_u: 0.841203212738
# 	h0_max_x_min_u: 0.397166341543
# 	h0_mean_x_max_u: 0.901066184044
# 	h0_mean_x_mean_u: 0.458820104599
# 	h0_mean_x_min_u: 0.0533628687263
# 	h0_min_x_max_u: 0.532714784145
# 	h0_min_x_mean_u: 0.104635126889
# 	h0_min_x_min_u: 2.18197601498e-05
# 	h0_range_x_max_u: 0.992861151695
# 	h0_range_x_mean_u: 0.736568331718
# 	h0_range_x_min_u: 0.249448418617
# 	h0_row_norms_max: 5.20194578171
# 	h0_row_norms_mean: 2.76863360405
# 	h0_row_norms_min: 0.209749102592
# 	learning_rate: 0.0500000119209
# 	objective: 0.95030772686
# 	y0_col_norms_max: 7.84454107285
# 	y0_col_norms_mean: 5.68333101273
# 	y0_col_norms_min: 4.14752483368
# 	y0_max_max_class: 0.988651692867
# 	y0_mean_max_class: 0.661089777946
# 	y0_min_max_class: 0.181160211563
# 	y0_misclass: 0.255199939013
# 	y0_nll: 0.95030772686
# 	y0_row_norms_max: 5.51380729675
# 	y0_row_norms_mean: 2.07345557213
# 	y0_row_norms_min: 0.344387501478
# Monitoring step:
# 	Epochs seen: 38
# 	Batches seen: 26600
# 	Examples seen: 2660000
# 	h0_col_norms_max: 7.23514890671
# 	h0_col_norms_mean: 4.59874105453
# 	h0_col_norms_min: 2.43396949768
# 	h0_max_x_max_u: 0.999970555305
# 	h0_max_x_mean_u: 0.842021405697
# 	h0_max_x_min_u: 0.396775275469
# 	h0_mean_x_max_u: 0.902061700821
# 	h0_mean_x_mean_u: 0.458692550659
# 	h0_mean_x_min_u: 0.0529161430895
# 	h0_min_x_max_u: 0.532540559769
# 	h0_min_x_mean_u: 0.103988721967
# 	h0_min_x_min_u: 2.06222357519e-05
# 	h0_range_x_max_u: 0.993154168129
# 	h0_range_x_mean_u: 0.738032758236
# 	h0_range_x_min_u: 0.250002115965
# 	h0_row_norms_max: 5.20194578171
# 	h0_row_norms_mean: 2.77135419846
# 	h0_row_norms_min: 0.210923060775
# 	learning_rate: 0.0500000119209
# 	objective: 0.939654886723
# 	y0_col_norms_max: 7.92994403839
# 	y0_col_norms_mean: 5.70530462265
# 	y0_col_norms_min: 4.15703630447
# 	y0_max_max_class: 0.988367438316
# 	y0_mean_max_class: 0.664783716202
# 	y0_min_max_class: 0.183129951358
# 	y0_misclass: 0.249799996614
# 	y0_nll: 0.939654886723
# 	y0_row_norms_max: 5.53530263901
# 	y0_row_norms_mean: 2.08220458031
# 	y0_row_norms_min: 0.346941024065
# Monitoring step:
# 	Epochs seen: 39
# 	Batches seen: 27300
# 	Examples seen: 2730000
# 	h0_col_norms_max: 7.25108480453
# 	h0_col_norms_mean: 4.60355710983
# 	h0_col_norms_min: 2.44103431702
# 	h0_max_x_max_u: 0.999973595142
# 	h0_max_x_mean_u: 0.842817604542
# 	h0_max_x_min_u: 0.395750761032
# 	h0_mean_x_max_u: 0.90350651741
# 	h0_mean_x_mean_u: 0.458471536636
# 	h0_mean_x_min_u: 0.051997218281
# 	h0_min_x_max_u: 0.533661723137
# 	h0_min_x_mean_u: 0.10327398777
# 	h0_min_x_min_u: 1.98400211957e-05
# 	h0_range_x_max_u: 0.993489027023
# 	h0_range_x_mean_u: 0.739543437958
# 	h0_range_x_min_u: 0.250478386879
# 	h0_row_norms_max: 5.20194482803
# 	h0_row_norms_mean: 2.77407860756
# 	h0_row_norms_min: 0.212092295289
# 	learning_rate: 0.0500000119209
# 	objective: 0.934536457062
# 	y0_col_norms_max: 8.01349639893
# 	y0_col_norms_mean: 5.72724294662
# 	y0_col_norms_min: 4.17011451721
# 	y0_max_max_class: 0.98889285326
# 	y0_mean_max_class: 0.670316874981
# 	y0_min_max_class: 0.183603391051
# 	y0_misclass: 0.25100004673
# 	y0_nll: 0.934536457062
# 	y0_row_norms_max: 5.55787134171
# 	y0_row_norms_mean: 2.09093165398
# 	y0_row_norms_min: 0.350519984961
# Monitoring step:
# 	Epochs seen: 40
# 	Batches seen: 28000
# 	Examples seen: 2800000
# 	h0_col_norms_max: 7.26655673981
# 	h0_col_norms_mean: 4.60836076736
# 	h0_col_norms_min: 2.44818687439
# 	h0_max_x_max_u: 0.999975442886
# 	h0_max_x_mean_u: 0.84348654747
# 	h0_max_x_min_u: 0.394915729761
# 	h0_mean_x_max_u: 0.904493808746
# 	h0_mean_x_mean_u: 0.458196043968
# 	h0_mean_x_min_u: 0.051119223237
# 	h0_min_x_max_u: 0.534291625023
# 	h0_min_x_mean_u: 0.102559410036
# 	h0_min_x_min_u: 1.88560243259e-05
# 	h0_range_x_max_u: 0.99368917942
# 	h0_range_x_mean_u: 0.740927100182
# 	h0_range_x_min_u: 0.251008599997
# 	h0_row_norms_max: 5.20194578171
# 	h0_row_norms_mean: 2.77678799629
# 	h0_row_norms_min: 0.213231042027
# 	learning_rate: 0.0500000119209
# 	objective: 0.926592111588
# 	y0_col_norms_max: 8.09620857239
# 	y0_col_norms_mean: 5.74895477295
# 	y0_col_norms_min: 4.18248319626
# 	y0_max_max_class: 0.990168452263
# 	y0_mean_max_class: 0.668492555618
# 	y0_min_max_class: 0.182805731893
# 	y0_misclass: 0.246199980378
# 	y0_nll: 0.926592111588
# 	y0_row_norms_max: 5.58069753647
# 	y0_row_norms_mean: 2.09948158264
# 	y0_row_norms_min: 0.351928859949
# Monitoring step:
# 	Epochs seen: 41
# 	Batches seen: 28700
# 	Examples seen: 2870000
# 	h0_col_norms_max: 7.28192281723
# 	h0_col_norms_mean: 4.6131811142
# 	h0_col_norms_min: 2.45547223091
# 	h0_max_x_max_u: 0.999977827072
# 	h0_max_x_mean_u: 0.844217419624
# 	h0_max_x_min_u: 0.393983155489
# 	h0_mean_x_max_u: 0.905139446259
# 	h0_mean_x_mean_u: 0.457947343588
# 	h0_mean_x_min_u: 0.0506504885852
# 	h0_min_x_max_u: 0.535038650036
# 	h0_min_x_mean_u: 0.101876460016
# 	h0_min_x_min_u: 1.80737952178e-05
# 	h0_range_x_max_u: 0.993838846684
# 	h0_range_x_mean_u: 0.74234098196
# 	h0_range_x_min_u: 0.251622676849
# 	h0_row_norms_max: 5.20194482803
# 	h0_row_norms_mean: 2.7794919014
# 	h0_row_norms_min: 0.214424699545
# 	learning_rate: 0.0500000119209
# 	objective: 0.917520403862
# 	y0_col_norms_max: 8.18065547943
# 	y0_col_norms_mean: 5.77057504654
# 	y0_col_norms_min: 4.19089651108
# 	y0_max_max_class: 0.989943742752
# 	y0_mean_max_class: 0.671306550503
# 	y0_min_max_class: 0.181246995926
# 	y0_misclass: 0.245299994946
# 	y0_nll: 0.917520403862
# 	y0_row_norms_max: 5.60228013992
# 	y0_row_norms_mean: 2.10808181763
# 	y0_row_norms_min: 0.353967875242
# Monitoring step:
# 	Epochs seen: 42
# 	Batches seen: 29400
# 	Examples seen: 2940000
# 	h0_col_norms_max: 7.29741716385
# 	h0_col_norms_mean: 4.61800813675
# 	h0_col_norms_min: 2.46303009987
# 	h0_max_x_max_u: 0.999979794025
# 	h0_max_x_mean_u: 0.844786167145
# 	h0_max_x_min_u: 0.393002599478
# 	h0_mean_x_max_u: 0.907182872295
# 	h0_mean_x_mean_u: 0.457607090473
# 	h0_mean_x_min_u: 0.049962926656
# 	h0_min_x_max_u: 0.536842167377
# 	h0_min_x_mean_u: 0.101251862943
# 	h0_min_x_min_u: 1.70661605807e-05
# 	h0_range_x_max_u: 0.994024634361
# 	h0_range_x_mean_u: 0.743534147739
# 	h0_range_x_min_u: 0.251996785402
# 	h0_row_norms_max: 5.20194149017
# 	h0_row_norms_mean: 2.78219485283
# 	h0_row_norms_min: 0.215563267469
# 	learning_rate: 0.0500000119209
# 	objective: 0.912411689758
# 	y0_col_norms_max: 8.26158618927
# 	y0_col_norms_mean: 5.79212808609
# 	y0_col_norms_min: 4.20226478577
# 	y0_max_max_class: 0.990438342094
# 	y0_mean_max_class: 0.675387978554
# 	y0_min_max_class: 0.181443333626
# 	y0_misclass: 0.245400011539
# 	y0_nll: 0.912411689758
# 	y0_row_norms_max: 5.62208414078
# 	y0_row_norms_mean: 2.11663174629
# 	y0_row_norms_min: 0.356271803379
# Monitoring step:
# 	Epochs seen: 43
# 	Batches seen: 30100
# 	Examples seen: 3010000
# 	h0_col_norms_max: 7.31220293045
# 	h0_col_norms_mean: 4.62280893326
# 	h0_col_norms_min: 2.47039079666
# 	h0_max_x_max_u: 0.999981284142
# 	h0_max_x_mean_u: 0.845846474171
# 	h0_max_x_min_u: 0.393079012632
# 	h0_mean_x_max_u: 0.907387316227
# 	h0_mean_x_mean_u: 0.457638114691
# 	h0_mean_x_min_u: 0.0494230613112
# 	h0_min_x_max_u: 0.536626815796
# 	h0_min_x_mean_u: 0.100559599698
# 	h0_min_x_min_u: 1.64772263815e-05
# 	h0_range_x_max_u: 0.994255721569
# 	h0_range_x_mean_u: 0.745287120342
# 	h0_range_x_min_u: 0.252552866936
# 	h0_row_norms_max: 5.20193004608
# 	h0_row_norms_mean: 2.78487157822
# 	h0_row_norms_min: 0.216695249081
# 	learning_rate: 0.0500000119209
# 	objective: 0.904083073139
# 	y0_col_norms_max: 8.34342193604
# 	y0_col_norms_mean: 5.81372642517
# 	y0_col_norms_min: 4.21173286438
# 	y0_max_max_class: 0.990920245647
# 	y0_mean_max_class: 0.679921209812
# 	y0_min_max_class: 0.180333584547
# 	y0_misclass: 0.244999974966
# 	y0_nll: 0.904083073139
# 	y0_row_norms_max: 5.6442732811
# 	y0_row_norms_mean: 2.12526035309
# 	y0_row_norms_min: 0.360179781914
# Monitoring step:
# 	Epochs seen: 44
# 	Batches seen: 30800
# 	Examples seen: 3080000
# 	h0_col_norms_max: 7.32698535919
# ...
# 	h0_min_x_min_u: 3.02932880913e-06
# 	h0_range_x_max_u: 0.997824966908
# 	h0_range_x_mean_u: 0.791153550148
# 	h0_range_x_min_u: 0.263395994902
# 	h0_row_norms_max: 5.81979370117
# 	h0_row_norms_mean: 2.88815522194
# 	h0_row_norms_min: 0.26247176528
# 	learning_rate: 0.0500000119209
# 	objective: 0.671356320381
# 	y0_col_norms_max: 10.951415062
# 	y0_col_norms_mean: 6.66326332092
# 	y0_col_norms_min: 4.65550374985
# 	y0_max_max_class: 0.995416879654
# 	y0_mean_max_class: 0.747597515583
# 	y0_min_max_class: 0.215968161821
# 	y0_misclass: 0.18379996717
# 	y0_nll: 0.671356320381
# 	y0_row_norms_max: 6.28151845932
# 	y0_row_norms_mean: 2.46001887321
# 	y0_row_norms_min: 0.452592760324
# Monitoring step:
# 	Epochs seen: 87
# 	Batches seen: 60900
# 	Examples seen: 6090000
# 	h0_col_norms_max: 7.80644702911
# 	h0_col_norms_mean: 4.82322263718
# 	h0_col_norms_min: 2.86187314987
# 	h0_max_x_max_u: 0.99999755621
# 	h0_max_x_mean_u: 0.871532022953
# 	h0_max_x_min_u: 0.378038555384
# 	h0_mean_x_max_u: 0.930176436901
# 	h0_mean_x_mean_u: 0.45161446929
# 	h0_mean_x_min_u: 0.0354637727141
# 	h0_min_x_max_u: 0.550577640533
# 	h0_min_x_mean_u: 0.0795062854886
# 	h0_min_x_min_u: 2.96635039376e-06
# 	h0_range_x_max_u: 0.997871637344
# 	h0_range_x_mean_u: 0.792025506496
# 	h0_range_x_min_u: 0.263986110687
# 	h0_row_norms_max: 5.83781814575
# 	h0_row_norms_mean: 2.89025974274
# 	h0_row_norms_min: 0.26341342926
# 	learning_rate: 0.0500000119209
# 	objective: 0.667890071869
# 	y0_col_norms_max: 10.9951629639
# 	y0_col_norms_mean: 6.68130207062
# 	y0_col_norms_min: 4.66302156448
# 	y0_max_max_class: 0.995864808559
# 	y0_mean_max_class: 0.749678432941
# 	y0_min_max_class: 0.218428686261
# 	y0_misclass: 0.184299945831
# 	y0_nll: 0.667890071869
# 	y0_row_norms_max: 6.2912979126
# 	y0_row_norms_mean: 2.46707653999
# 	y0_row_norms_min: 0.456214725971
# Monitoring step:
# 	Epochs seen: 88
# 	Batches seen: 61600
# 	Examples seen: 6160000
# 	h0_col_norms_max: 7.8153128624
# 	h0_col_norms_mean: 4.82742261887
# 	h0_col_norms_min: 2.87033700943
# 	h0_max_x_max_u: 0.999997615814
# 	h0_max_x_mean_u: 0.871961712837
# 	h0_max_x_min_u: 0.377507984638
# 	h0_mean_x_max_u: 0.93069845438
# 	h0_mean_x_mean_u: 0.451467424631
# 	h0_mean_x_min_u: 0.035342939198
# 	h0_min_x_max_u: 0.55162191391
# 	h0_min_x_mean_u: 0.0791620761156
# 	h0_min_x_min_u: 2.87968100565e-06
# 	h0_range_x_max_u: 0.997899234295
# 	h0_range_x_mean_u: 0.792799472809
# 	h0_range_x_min_u: 0.264255523682
# 	h0_row_norms_max: 5.85567188263
# 	h0_row_norms_mean: 2.89236855507
# 	h0_row_norms_min: 0.264401376247
# 	learning_rate: 0.0500000119209
# 	objective: 0.66116887331
# 	y0_col_norms_max: 11.0380516052
# 	y0_col_norms_mean: 6.6992650032
# 	y0_col_norms_min: 4.67480039597
# 	y0_max_max_class: 0.995762348175
# 	y0_mean_max_class: 0.747215211391
# 	y0_min_max_class: 0.214211285114
# 	y0_misclass: 0.180300012231
# 	y0_nll: 0.66116887331
# 	y0_row_norms_max: 6.30177307129
# 	y0_row_norms_mean: 2.47413921356
# 	y0_row_norms_min: 0.457968503237
# Monitoring step:
# 	Epochs seen: 89
# 	Batches seen: 62300
# 	Examples seen: 6230000
# 	h0_col_norms_max: 7.82399129868
# 	h0_col_norms_mean: 4.83158111572
# 	h0_col_norms_min: 2.878667593
# 	h0_max_x_max_u: 0.999997675419
# 	h0_max_x_mean_u: 0.872455060482
# 	h0_max_x_min_u: 0.377629131079
# 	h0_mean_x_max_u: 0.93080586195
# 	h0_mean_x_mean_u: 0.45138797164
# 	h0_mean_x_min_u: 0.0351605713367
# 	h0_min_x_max_u: 0.550450742245
# 	h0_min_x_mean_u: 0.0787911638618
# 	h0_min_x_min_u: 2.80070844383e-06
# 	h0_range_x_max_u: 0.997937381268
# 	h0_range_x_mean_u: 0.793663680553
# 	h0_range_x_min_u: 0.264548271894
# 	h0_row_norms_max: 5.87294960022
# 	h0_row_norms_mean: 2.89444947243
# 	h0_row_norms_min: 0.265382677317
# 	learning_rate: 0.0500000119209
# 	objective: 0.659553766251
# 	y0_col_norms_max: 11.0798864365
# 	y0_col_norms_mean: 6.71716070175
# 	y0_col_norms_min: 4.6856212616
# 	y0_max_max_class: 0.99598300457
# 	y0_mean_max_class: 0.751618742943
# 	y0_min_max_class: 0.219171613455
# 	y0_misclass: 0.183699920774
# 	y0_nll: 0.659553766251
# 	y0_row_norms_max: 6.31195545197
# 	y0_row_norms_mean: 2.48116540909
# 	y0_row_norms_min: 0.459187418222
# Monitoring step:
# 	Epochs seen: 90
# 	Batches seen: 63000
# 	Examples seen: 6300000
# 	h0_col_norms_max: 7.83276844025
# 	h0_col_norms_mean: 4.83574914932
# 	h0_col_norms_min: 2.88722729683
# 	h0_max_x_max_u: 0.999997675419
# 	h0_max_x_mean_u: 0.872895717621
# 	h0_max_x_min_u: 0.377602756023
# 	h0_mean_x_max_u: 0.931479513645
# 	h0_mean_x_mean_u: 0.451331079006
# 	h0_mean_x_min_u: 0.0351971015334
# 	h0_min_x_max_u: 0.55195504427
# 	h0_min_x_mean_u: 0.0784887075424
# 	h0_min_x_min_u: 2.72919101008e-06
# 	h0_range_x_max_u: 0.997967720032
# 	h0_range_x_mean_u: 0.794406533241
# 	h0_range_x_min_u: 0.264862179756
# 	h0_row_norms_max: 5.88979625702
# 	h0_row_norms_mean: 2.89653921127
# 	h0_row_norms_min: 0.26636826992
# 	learning_rate: 0.0500000119209
# 	objective: 0.654324769974
# 	y0_col_norms_max: 11.1211080551
# 	y0_col_norms_mean: 6.73503923416
# 	y0_col_norms_min: 4.69609975815
# 	y0_max_max_class: 0.995443224907
# 	y0_mean_max_class: 0.748682022095
# 	y0_min_max_class: 0.217343613505
# 	y0_misclass: 0.178900003433
# 	y0_nll: 0.654324769974
# 	y0_row_norms_max: 6.32243061066
# 	y0_row_norms_mean: 2.48814344406
# 	y0_row_norms_min: 0.461236387491
# Monitoring step:
# 	Epochs seen: 91
# 	Batches seen: 63700
# 	Examples seen: 6370000
# 	h0_col_norms_max: 7.84149265289
# 	h0_col_norms_mean: 4.83988142014
# 	h0_col_norms_min: 2.89496731758
# 	h0_max_x_max_u: 0.999997735023
# 	h0_max_x_mean_u: 0.873269498348
# 	h0_max_x_min_u: 0.377843558788
# 	h0_mean_x_max_u: 0.931537330151
# 	h0_mean_x_mean_u: 0.451216071844
# 	h0_mean_x_min_u: 0.0348125845194
# 	h0_min_x_max_u: 0.551194250584
# 	h0_min_x_mean_u: 0.0781601816416
# 	h0_min_x_min_u: 2.65698940893e-06
# 	h0_range_x_max_u: 0.998017728329
# 	h0_range_x_mean_u: 0.795109272003
# 	h0_range_x_min_u: 0.265127331018
# 	h0_row_norms_max: 5.90699863434
# 	h0_row_norms_mean: 2.89859819412
# 	h0_row_norms_min: 0.267307639122
# 	learning_rate: 0.0500000119209
# 	objective: 0.651613116264
# 	y0_col_norms_max: 11.1638936996
# 	y0_col_norms_mean: 6.75276565552
# 	y0_col_norms_min: 4.70824718475
# 	y0_max_max_class: 0.995702564716
# 	y0_mean_max_class: 0.750554978848
# 	y0_min_max_class: 0.217906728387
# 	y0_misclass: 0.179800033569
# 	y0_nll: 0.651613116264
# 	y0_row_norms_max: 6.3331155777
# 	y0_row_norms_mean: 2.49509096146
# 	y0_row_norms_min: 0.463097691536
# Monitoring step:
# 	Epochs seen: 92
# 	Batches seen: 64400
# 	Examples seen: 6440000
# 	h0_col_norms_max: 7.85006523132
# 	h0_col_norms_mean: 4.843998909
# 	h0_col_norms_min: 2.90361213684
# 	h0_max_x_max_u: 0.999997794628
# 	h0_max_x_mean_u: 0.873779535294
# 	h0_max_x_min_u: 0.378433227539
# 	h0_mean_x_max_u: 0.931536853313
# 	h0_mean_x_mean_u: 0.451158851385
# 	h0_mean_x_min_u: 0.0347563847899
# 	h0_min_x_max_u: 0.550078809261
# 	h0_min_x_mean_u: 0.0778001099825
# 	h0_min_x_min_u: 2.58897716776e-06
# 	h0_range_x_max_u: 0.998062252998
# 	h0_range_x_mean_u: 0.795979559422
# 	h0_range_x_min_u: 0.265564620495
# 	h0_row_norms_max: 5.92466640472
# 	h0_row_norms_mean: 2.90065431595
# 	h0_row_norms_min: 0.268252074718
# 	learning_rate: 0.0500000119209
# 	objective: 0.648652911186
# 	y0_col_norms_max: 11.2060527802
# 	y0_col_norms_mean: 6.77048110962
# 	y0_col_norms_min: 4.71646261215
# 	y0_max_max_class: 0.995945572853
# 	y0_mean_max_class: 0.751594901085
# 	y0_min_max_class: 0.216318130493
# 	y0_misclass: 0.177900031209
# 	y0_nll: 0.648652911186
# 	y0_row_norms_max: 6.3440656662
# 	y0_row_norms_mean: 2.50202846527
# 	y0_row_norms_min: 0.464924544096
# Monitoring step:
# 	Epochs seen: 93
# 	Batches seen: 65100
# 	Examples seen: 6510000
# 	h0_col_norms_max: 7.85857152939
# 	h0_col_norms_mean: 4.84809923172
# 	h0_col_norms_min: 2.91165685654
# 	h0_max_x_max_u: 0.999997854233
# 	h0_max_x_mean_u: 0.874216020107
# 	h0_max_x_min_u: 0.377415627241
# 	h0_mean_x_max_u: 0.931951165199
# 	h0_mean_x_mean_u: 0.451127916574
# 	h0_mean_x_min_u: 0.0344424843788
# 	h0_min_x_max_u: 0.550681054592
# 	h0_min_x_mean_u: 0.0774893537164
# 	h0_min_x_min_u: 2.52668951362e-06
# 	h0_range_x_max_u: 0.998098552227
# 	h0_range_x_mean_u: 0.796726584435
# 	h0_range_x_min_u: 0.265742480755
# 	h0_row_norms_max: 5.94105386734
# 	h0_row_norms_mean: 2.90269875526
# 	h0_row_norms_min: 0.269226521254
# 	learning_rate: 0.0500000119209
# 	objective: 0.648365855217
# 	y0_col_norms_max: 11.2448711395
# 	y0_col_norms_mean: 6.7880525589
# 	y0_col_norms_min: 4.72877883911
# 	y0_max_max_class: 0.996031403542
# 	y0_mean_max_class: 0.753560960293
# 	y0_min_max_class: 0.217123702168
# 	y0_misclass: 0.178199976683
# 	y0_nll: 0.648365855217
# 	y0_row_norms_max: 6.35199451447
# 	y0_row_norms_mean: 2.5089263916
# 	y0_row_norms_min: 0.46823912859
# Monitoring step:
# 	Epochs seen: 94
# 	Batches seen: 65800
# 	Examples seen: 6580000
# 	h0_col_norms_max: 7.86708879471
# 	h0_col_norms_mean: 4.85219478607
# 	h0_col_norms_min: 2.91937017441
# 	h0_max_x_max_u: 0.999997913837
# 	h0_max_x_mean_u: 0.874614655972
# 	h0_max_x_min_u: 0.377514123917
# 	h0_mean_x_max_u: 0.932330369949
# 	h0_mean_x_mean_u: 0.450939804316
# 	h0_mean_x_min_u: 0.0342871211469
# 	h0_min_x_max_u: 0.551097750664
# 	h0_min_x_mean_u: 0.0771305859089
# 	h0_min_x_min_u: 2.46222521127e-06
# 	h0_range_x_max_u: 0.998131036758
# 	h0_range_x_mean_u: 0.797483980656
# 	h0_range_x_min_u: 0.265944451094
# 	h0_row_norms_max: 5.95770311356
# 	h0_row_norms_mean: 2.90472722054
# 	h0_row_norms_min: 0.270134240389
# 	learning_rate: 0.0500000119209
# 	objective: 0.641329824924
# 	y0_col_norms_max: 11.284819603
# 	y0_col_norms_mean: 6.8055768013
# 	y0_col_norms_min: 4.74018526077
# 	y0_max_max_class: 0.996137917042
# 	y0_mean_max_class: 0.749185204506
# 	y0_min_max_class: 0.214392066002
# 	y0_misclass: 0.175500005484
# 	y0_nll: 0.641329824924
# 	y0_row_norms_max: 6.36202049255
# 	y0_row_norms_mean: 2.51573038101
# 	y0_row_norms_min: 0.469283014536
# Monitoring step:
# 	Epochs seen: 95
# 	Batches seen: 66500
# 	Examples seen: 6650000
# 	h0_col_norms_max: 7.87581443787
# 	h0_col_norms_mean: 4.85627126694
# 	h0_col_norms_min: 2.92781209946
# 	h0_max_x_max_u: 0.999997973442
# 	h0_max_x_mean_u: 0.87498831749
# 	h0_max_x_min_u: 0.377456277609
# 	h0_mean_x_max_u: 0.932257771492
# 	h0_mean_x_mean_u: 0.450861364603
# 	h0_mean_x_min_u: 0.034186732024
# 	h0_min_x_max_u: 0.549748003483
# 	h0_min_x_mean_u: 0.0768453776836
# 	h0_min_x_min_u: 2.38907341554e-06
# 	h0_range_x_max_u: 0.998162150383
# 	h0_range_x_mean_u: 0.798142969608
# 	h0_range_x_min_u: 0.266261845827
# 	h0_row_norms_max: 5.97389936447
# 	h0_row_norms_mean: 2.90675830841
# 	h0_row_norms_min: 0.271091967821
# 	learning_rate: 0.0500000119209
# 	objective: 0.638700962067
# 	y0_col_norms_max: 11.3249788284
# 	y0_col_norms_mean: 6.82309675217
# 	y0_col_norms_min: 4.75163841248
# 	y0_max_max_class: 0.995996952057
# 	y0_mean_max_class: 0.755040884018
# 	y0_min_max_class: 0.219329982996
# 	y0_misclass: 0.177299976349
# 	y0_nll: 0.638700962067
# 	y0_row_norms_max: 6.37017822266
# 	y0_row_norms_mean: 2.52261352539
# 	y0_row_norms_min: 0.470719516277
# Monitoring step:
# 	Epochs seen: 96
# 	Batches seen: 67200
# 	Examples seen: 6720000
# 	h0_col_norms_max: 7.88403463364
# 	h0_col_norms_mean: 4.86032533646
# 	h0_col_norms_min: 2.93552112579
# 	h0_max_x_max_u: 0.999997973442
# 	h0_max_x_mean_u: 0.875471174717
# 	h0_max_x_min_u: 0.377723455429
# 	h0_mean_x_max_u: 0.932389736176
# 	h0_mean_x_mean_u: 0.450855731964
# 	h0_mean_x_min_u: 0.0341651849449
# 	h0_min_x_max_u: 0.549230456352
# 	h0_min_x_mean_u: 0.0765463337302
# 	h0_min_x_min_u: 2.32354341279e-06
# 	h0_range_x_max_u: 0.998202860355
# 	h0_range_x_mean_u: 0.798924803734
# 	h0_range_x_min_u: 0.266711622477
# 	h0_row_norms_max: 5.99012041092
# 	h0_row_norms_mean: 2.90877199173
# 	h0_row_norms_min: 0.272052198648
# 	learning_rate: 0.0500000119209
# 	objective: 0.637772858143
# 	y0_col_norms_max: 11.3651018143
# 	y0_col_norms_mean: 6.84046697617
# 	y0_col_norms_min: 4.75813484192
# 	y0_max_max_class: 0.99613237381
# 	y0_mean_max_class: 0.756375849247
# 	y0_min_max_class: 0.216511487961
# 	y0_misclass: 0.176599994302
# 	y0_nll: 0.637772858143
# 	y0_row_norms_max: 6.37954187393
# 	y0_row_norms_mean: 2.52944493294
# 	y0_row_norms_min: 0.474232405424
# Monitoring step:
# 	Epochs seen: 97
# 	Batches seen: 67900
# 	Examples seen: 6790000
# 	h0_col_norms_max: 7.89231061935
# 	h0_col_norms_mean: 4.8643784523
# 	h0_col_norms_min: 2.94363331795
# 	h0_max_x_max_u: 0.999998033047
# 	h0_max_x_mean_u: 0.875860869884
# 	h0_max_x_min_u: 0.377290606499
# 	h0_mean_x_max_u: 0.932620406151
# 	h0_mean_x_mean_u: 0.450745731592
# 	h0_mean_x_min_u: 0.0340146273375
# 	h0_min_x_max_u: 0.549680292606
# 	h0_min_x_mean_u: 0.0762255787849
# 	h0_min_x_min_u: 2.26007659876e-06
# 	h0_range_x_max_u: 0.998224973679
# 	h0_range_x_mean_u: 0.799635410309
# 	h0_range_x_min_u: 0.26694047451
# 	h0_row_norms_max: 6.00654268265
# 	h0_row_norms_mean: 2.91077923775
# 	h0_row_norms_min: 0.27297565341
# 	learning_rate: 0.0500000119209
# 	objective: 0.632358849049
# 	y0_col_norms_max: 11.4053468704
# 	y0_col_norms_mean: 6.85786819458
# 	y0_col_norms_min: 4.77048921585
# 	y0_max_max_class: 0.996182084084
# 	y0_mean_max_class: 0.756282687187
# 	y0_min_max_class: 0.219062581658
# 	y0_misclass: 0.173999965191
# 	y0_nll: 0.632358849049
# 	y0_row_norms_max: 6.38874816895
# 	y0_row_norms_mean: 2.53627538681
# 	y0_row_norms_min: 0.475311487913
# Monitoring step:
# 	Epochs seen: 98
# 	Batches seen: 68600
# 	Examples seen: 6860000
# 	h0_col_norms_max: 7.90048551559
# 	h0_col_norms_mean: 4.86839342117
# 	h0_col_norms_min: 2.95111346245
# 	h0_max_x_max_u: 0.999998033047
# 	h0_max_x_mean_u: 0.876363277435
# 	h0_max_x_min_u: 0.378127813339
# 	h0_mean_x_max_u: 0.932867646217
# 	h0_mean_x_mean_u: 0.45078599453
# 	h0_mean_x_min_u: 0.0341064855456
# 	h0_min_x_max_u: 0.549454987049
# 	h0_min_x_mean_u: 0.0759176835418
# 	h0_min_x_min_u: 2.21201571549e-06
# 	h0_range_x_max_u: 0.998262107372
# 	h0_range_x_mean_u: 0.800446033478
# 	h0_range_x_min_u: 0.267233431339
# 	h0_row_norms_max: 6.02178192139
# 	h0_row_norms_mean: 2.91276192665
# 	h0_row_norms_min: 0.273217707872
# 	learning_rate: 0.0500000119209
# 	objective: 0.629202246666
# 	y0_col_norms_max: 11.4422779083
# 	y0_col_norms_mean: 6.87509965897
# 	y0_col_norms_min: 4.78259992599
# 	y0_max_max_class: 0.996568858624
# 	y0_mean_max_class: 0.759656310081
# 	y0_min_max_class: 0.222290426493
# 	y0_misclass: 0.174500003457
# 	y0_nll: 0.629202246666
# 	y0_row_norms_max: 6.39915847778
# 	y0_row_norms_mean: 2.5430290699
# 	y0_row_norms_min: 0.477992713451
# Monitoring step:
# 	Epochs seen: 99
# 	Batches seen: 69300
# 	Examples seen: 6930000
# 	h0_col_norms_max: 7.90848970413
# 	h0_col_norms_mean: 4.872402668
# 	h0_col_norms_min: 2.9588239193
# 	h0_max_x_max_u: 0.999998033047
# 	h0_max_x_mean_u: 0.876689434052
# 	h0_max_x_min_u: 0.377178668976
# 	h0_mean_x_max_u: 0.933080911636
# 	h0_mean_x_mean_u: 0.450660437346
# 	h0_mean_x_min_u: 0.033748138696
# 	h0_min_x_max_u: 0.54962682724
# 	h0_min_x_mean_u: 0.0756039768457
# 	h0_min_x_min_u: 2.12660302168e-06
# 	h0_range_x_max_u: 0.998298466206
# 	h0_range_x_mean_u: 0.801085293293
# 	h0_range_x_min_u: 0.26736921072
# 	h0_row_norms_max: 6.03853797913
# 	h0_row_norms_mean: 2.91474485397
# 	h0_row_norms_min: 0.273217707872
# 	learning_rate: 0.0500000119209
# 	objective: 0.625061333179
# 	y0_col_norms_max: 11.482301712
# 	y0_col_norms_mean: 6.89228582382
# 	y0_col_norms_min: 4.79359149933
# 	y0_max_max_class: 0.996474146843
# 	y0_mean_max_class: 0.758664548397
# 	y0_min_max_class: 0.22163631022
# 	y0_misclass: 0.171900004148
# 	y0_nll: 0.625061333179
# 	y0_row_norms_max: 6.40727233887
# 	y0_row_norms_mean: 2.54974555969
# 	y0_row_norms_min: 0.480201244354
# Monitoring step:
# 	Epochs seen: 100
# 	Batches seen: 70000
# 	Examples seen: 7000000
# 	h0_col_norms_max: 7.91669845581
# 	h0_col_norms_mean: 4.87638998032
# 	h0_col_norms_min: 2.96643424034
# 	h0_max_x_max_u: 0.999998092651
# 	h0_max_x_mean_u: 0.877156496048
# 	h0_max_x_min_u: 0.377661913633
# 	h0_mean_x_max_u: 0.933409035206
# 	h0_mean_x_mean_u: 0.450602531433
# 	h0_mean_x_min_u: 0.0337370634079
# 	h0_min_x_max_u: 0.549587965012
# 	h0_min_x_mean_u: 0.075314424932
# 	h0_min_x_min_u: 2.08217488762e-06
# 	h0_range_x_max_u: 0.998331665993
# 	h0_range_x_mean_u: 0.801842391491
# 	h0_range_x_min_u: 0.267764568329
# 	h0_row_norms_max: 6.05365037918
# 	h0_row_norms_mean: 2.91671586037
# 	h0_row_norms_min: 0.273217707872
# 	learning_rate: 0.0500000119209
# 	objective: 0.623726010323
# 	y0_col_norms_max: 11.5188903809
# 	y0_col_norms_mean: 6.90935611725
# 	y0_col_norms_min: 4.80359125137
# 	y0_max_max_class: 0.996758043766
# 	y0_mean_max_class: 0.759563267231
# 	y0_min_max_class: 0.221193775535
# 	y0_misclass: 0.173800006509
# 	y0_nll: 0.623726010323
# 	y0_row_norms_max: 6.41655635834
# 	y0_row_norms_mean: 2.55642676353
# 	y0_row_norms_min: 0.48346811533

# %%
# Calculate accuracy on test set

nn = serial.load("best_params.pkl")

inputs = test.X.astype("float32")
yhat = nn.fprop(theano.shared(inputs,name='inputs')).eval()

count = 0.
for i in range(test.X.shape[0]):
    if np.argmax(test.y[i])==np.argmax(yhat[i]):
        count += 1.

print "accuracy = ", count / test.X.shape[0]
# Out:
# accuracy =  0.8312

# %% [markdown]
# ## 3-layer SoftMax with Softplus hidden_layer = 800 with Dropout

# %%
# load dataset

train = csv_dataset.CSVDataset("sd19n.csv",one_hot=True,expect_labels=True,expect_headers=False,delimiter=',',end_fraction=0.7)
valid = csv_dataset.CSVDataset("valid.csv",one_hot=True,expect_labels=True,expect_headers=False,delimiter=',')
test = csv_dataset.CSVDataset("test.csv",one_hot=True,expect_labels=True,expect_headers=False,delimiter=',')

# %%
# SoftPlus with Dropout

h0 = mlp.Softplus(layer_name='h0', dim=800, sparse_init=40)
h1 = mlp.Softplus(layer_name='h1', dim=800, sparse_init=40)
y0 = mlp.Softmax(layer_name='y0', n_classes=62, irange=0)
layers = [h0, h1, y0]

model = mlp.MLP(layers, nvis=1024)

monitoring = dict(valid=valid)
termination = MonitorBased(channel_name="valid_y0_misclass", N=10)
extensions = [best_params.MonitorBasedSaveBest(channel_name="valid_y0_misclass",
save_path="train_best.pkl")]

algorithm = sgd.SGD(0.1, batch_size=100, cost=Dropout(),
                    monitoring_dataset = monitoring, termination_criterion = termination)

print 'Running training'
train_job = Train(train, model, algorithm, extensions=extensions, save_path="train.pkl", save_freq=1)
train_job.main_loop()
# Out:
# Running training
# Parameter and initial learning rate summary:
# 	h0_W: 0.10000000149
# 	h0_b: 0.10000000149
# 	h1_W: 0.10000000149
# 	h1_b: 0.10000000149
# 	softmax_b: 0.10000000149
# 	softmax_W: 0.10000000149
# Compiling sgd_update...
# Compiling sgd_update done. Time elapsed: 1.143306 seconds
# compiling begin_record_entry...
# compiling begin_record_entry done. Time elapsed: 0.283400 seconds
# Monitored channels:
# 	learning_rate
# 	total_seconds_last_epoch
# 	training_seconds_this_epoch
# 	valid_h0_col_norms_max
# 	valid_h0_col_norms_mean
# 	valid_h0_col_norms_min
# 	valid_h0_max_x_max_u
# 	valid_h0_max_x_mean_u
# 	valid_h0_max_x_min_u
# 	valid_h0_mean_x_max_u
# 	valid_h0_mean_x_mean_u
# 	valid_h0_mean_x_min_u
# 	valid_h0_min_x_max_u
# 	valid_h0_min_x_mean_u
# 	valid_h0_min_x_min_u
# 	valid_h0_range_x_max_u
# 	valid_h0_range_x_mean_u
# 	valid_h0_range_x_min_u
# 	valid_h0_row_norms_max
# 	valid_h0_row_norms_mean
# 	valid_h0_row_norms_min
# 	valid_h1_col_norms_max
# 	valid_h1_col_norms_mean
# 	valid_h1_col_norms_min
# 	valid_h1_max_x_max_u
# 	valid_h1_max_x_mean_u
# 	valid_h1_max_x_min_u
# 	valid_h1_mean_x_max_u
# 	valid_h1_mean_x_mean_u
# 	valid_h1_mean_x_min_u
# 	valid_h1_min_x_max_u
# 	valid_h1_min_x_mean_u
# 	valid_h1_min_x_min_u
# 	valid_h1_range_x_max_u
# 	valid_h1_range_x_mean_u
# 	valid_h1_range_x_min_u
# 	valid_h1_row_norms_max
# 	valid_h1_row_norms_mean
# 	valid_h1_row_norms_min
# 	valid_objective
# 	valid_y0_col_norms_max
# 	valid_y0_col_norms_mean
# 	valid_y0_col_norms_min
# 	valid_y0_max_max_class
# 	valid_y0_mean_max_class
# 	valid_y0_min_max_class
# 	valid_y0_misclass
# 	valid_y0_nll
# 	valid_y0_row_norms_max
# 	valid_y0_row_norms_mean
# 	valid_y0_row_norms_min
# Compiling accum...
# graph size: 220
# Compiling accum done. Time elapsed: 5.052349 seconds
# Monitoring step:
# 	Epochs seen: 0
# 	Batches seen: 0
# 	Examples seen: 0
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 0.0
# 	training_seconds_this_epoch: 0.0
# 	valid_h0_col_norms_max: 8.85791683197
# 	valid_h0_col_norms_mean: 6.29075813293
# 	valid_h0_col_norms_min: 4.46461009979
# 	valid_h0_max_x_max_u: 7.45899152756
# 	valid_h0_max_x_mean_u: 2.41271352768
# 	valid_h0_max_x_min_u: 0.691943228245
# 	valid_h0_mean_x_max_u: 2.56270718575
# 	valid_h0_mean_x_mean_u: 0.845718443394
# 	valid_h0_mean_x_min_u: 0.183592706919
# 	valid_h0_min_x_max_u: 0.695461750031
# 	valid_h0_min_x_mean_u: 0.185474008322
# 	valid_h0_min_x_min_u: 0.000424755475251
# 	valid_h0_range_x_max_u: 7.23827838898
# 	valid_h0_range_x_mean_u: 2.22723913193
# 	valid_h0_range_x_min_u: 0.266834020615
# 	valid_h0_row_norms_max: 8.33629322052
# 	valid_h0_row_norms_mean: 5.52617502213
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.71524906158
# 	valid_h1_col_norms_mean: 6.3070807457
# 	valid_h1_col_norms_min: 4.3033657074
# 	valid_h1_max_x_max_u: 36.7582168579
# 	valid_h1_max_x_mean_u: 9.43465423584
# 	valid_h1_max_x_min_u: 5.01257181895e-06
# 	valid_h1_mean_x_max_u: 21.3265857697
# 	valid_h1_mean_x_mean_u: 2.86822199821
# 	valid_h1_mean_x_min_u: 1.05305232978e-07
# 	valid_h1_min_x_max_u: 14.2543439865
# 	valid_h1_min_x_mean_u: 0.360884726048
# 	valid_h1_min_x_min_u: 2.55085903301e-14
# 	valid_h1_range_x_max_u: 30.2905807495
# 	valid_h1_range_x_mean_u: 9.07376670837
# 	valid_h1_range_x_min_u: 5.01257181895e-06
# 	valid_h1_row_norms_max: 9.06762981415
# 	valid_h1_row_norms_mean: 6.28522396088
# 	valid_h1_row_norms_min: 3.57794594765
# 	valid_objective: 4.12713813782
# 	valid_y0_col_norms_max: 0.0
# 	valid_y0_col_norms_mean: 0.0
# 	valid_y0_col_norms_min: 0.0
# 	valid_y0_max_max_class: 0.0161290224642
# 	valid_y0_mean_max_class: 0.0161290224642
# 	valid_y0_min_max_class: 0.0161290224642
# 	valid_y0_misclass: 0.969299793243
# 	valid_y0_nll: 4.12713813782
# 	valid_y0_row_norms_max: 0.0
# 	valid_y0_row_norms_mean: 0.0
# 	valid_y0_row_norms_min: 0.0
# Time this epoch: 6.329254 seconds
# Monitoring step:
# 	Epochs seen: 1
# 	Batches seen: 700
# 	Examples seen: 70000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 0.0
# 	training_seconds_this_epoch: 6.32925128937
# 	valid_h0_col_norms_max: 8.82744312286
# 	valid_h0_col_norms_mean: 6.25999879837
# 	valid_h0_col_norms_min: 4.4538192749
# 	valid_h0_max_x_max_u: 8.93565654755
# 	valid_h0_max_x_mean_u: 2.06326723099
# 	valid_h0_max_x_min_u: 0.351536154747
# 	valid_h0_mean_x_max_u: 4.35711669922
# 	valid_h0_mean_x_mean_u: 0.728423416615
# 	valid_h0_mean_x_min_u: 0.0620915815234
# 	valid_h0_min_x_max_u: 1.82693243027
# 	valid_h0_min_x_mean_u: 0.172413825989
# 	valid_h0_min_x_min_u: 0.000104784732684
# 	valid_h0_range_x_max_u: 8.03774833679
# 	valid_h0_range_x_mean_u: 1.89085388184
# 	valid_h0_range_x_min_u: 0.298557221889
# 	valid_h0_row_norms_max: 8.31012439728
# 	valid_h0_row_norms_mean: 5.49896764755
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.69689464569
# 	valid_h1_col_norms_mean: 6.2823767662
# 	valid_h1_col_norms_min: 4.29270935059
# 	valid_h1_max_x_max_u: 6.82028150558
# 	valid_h1_max_x_mean_u: 0.0558781959116
# 	valid_h1_max_x_min_u: 2.91455505563e-11
# 	valid_h1_mean_x_max_u: 1.33179330826
# 	valid_h1_mean_x_mean_u: 0.00517499307171
# 	valid_h1_mean_x_min_u: 1.11330248406e-12
# 	valid_h1_min_x_max_u: 0.000740521994885
# 	valid_h1_min_x_mean_u: 1.417366434e-06
# 	valid_h1_min_x_min_u: 1.11406408023e-22
# 	valid_h1_range_x_max_u: 6.81981086731
# 	valid_h1_range_x_mean_u: 0.0558767877519
# 	valid_h1_range_x_min_u: 2.91455470869e-11
# 	valid_h1_row_norms_max: 8.96744155884
# 	valid_h1_row_norms_mean: 6.26198291779
# 	valid_h1_row_norms_min: 3.66579866409
# 	valid_objective: 3.44759368896
# 	valid_y0_col_norms_max: 8.35398578644
# 	valid_y0_col_norms_mean: 1.27199983597
# 	valid_y0_col_norms_min: 0.482419312
# 	valid_y0_max_max_class: 0.0822117477655
# 	valid_y0_mean_max_class: 0.0472683832049
# 	valid_y0_min_max_class: 0.0345613993704
# 	valid_y0_misclass: 0.906799972057
# 	valid_y0_nll: 3.70520567894
# 	valid_y0_row_norms_max: 2.14799284935
# 	valid_y0_row_norms_mean: 0.440170526505
# 	valid_y0_row_norms_min: 0.110101655126
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.946308 seconds
# Time this epoch: 7.184828 seconds
# Monitoring step:
# 	Epochs seen: 2
# 	Batches seen: 1400
# 	Examples seen: 140000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 9.66538333893
# 	training_seconds_this_epoch: 7.1848359108
# 	valid_h0_col_norms_max: 8.81810951233
# 	valid_h0_col_norms_mean: 6.25644016266
# 	valid_h0_col_norms_min: 4.45308732986
# 	valid_h0_max_x_max_u: 9.15430831909
# 	valid_h0_max_x_mean_u: 1.98605978489
# 	valid_h0_max_x_min_u: 0.325939744711
# 	valid_h0_mean_x_max_u: 4.32973432541
# 	valid_h0_mean_x_mean_u: 0.670301437378
# 	valid_h0_mean_x_min_u: 0.058196913451
# 	valid_h0_min_x_max_u: 1.72130250931
# 	valid_h0_min_x_mean_u: 0.149480342865
# 	valid_h0_min_x_min_u: 8.49552016007e-05
# 	valid_h0_range_x_max_u: 8.30637836456
# 	valid_h0_range_x_mean_u: 1.83657979965
# 	valid_h0_range_x_min_u: 0.299533784389
# 	valid_h0_row_norms_max: 8.29510402679
# 	valid_h0_row_norms_mean: 5.49591636658
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.69595050812
# 	valid_h1_col_norms_mean: 6.27740383148
# 	valid_h1_col_norms_min: 4.29160785675
# 	valid_h1_max_x_max_u: 7.37975597382
# 	valid_h1_max_x_mean_u: 0.107666403055
# 	valid_h1_max_x_min_u: 3.33858218848e-11
# 	valid_h1_mean_x_max_u: 1.22296953201
# 	valid_h1_mean_x_mean_u: 0.00840386655182
# 	valid_h1_mean_x_min_u: 1.2392170623e-12
# 	valid_h1_min_x_max_u: 0.000532662728801
# 	valid_h1_min_x_mean_u: 1.22581286632e-06
# 	valid_h1_min_x_min_u: 3.59570807538e-24
# 	valid_h1_range_x_max_u: 7.37959194183
# 	valid_h1_range_x_mean_u: 0.107665151358
# 	valid_h1_range_x_min_u: 3.33858149459e-11
# 	valid_h1_row_norms_max: 8.96434688568
# 	valid_h1_row_norms_mean: 6.2572145462
# 	valid_h1_row_norms_min: 3.67608118057
# 	valid_objective: 3.21330904961
# 	valid_y0_col_norms_max: 8.26964664459
# 	valid_y0_col_norms_mean: 1.33790969849
# 	valid_y0_col_norms_min: 0.539373755455
# 	valid_y0_max_max_class: 0.238438814878
# 	valid_y0_mean_max_class: 0.0673306062818
# 	valid_y0_min_max_class: 0.0403492450714
# 	valid_y0_misclass: 0.825100004673
# 	valid_y0_nll: 3.4159283638
# 	valid_y0_row_norms_max: 2.14436078072
# 	valid_y0_row_norms_mean: 0.450306952
# 	valid_y0_row_norms_min: 0.159716129303
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.938710 seconds
# Time this epoch: 5.637614 seconds
# Monitoring step:
# 	Epochs seen: 3
# 	Batches seen: 2100
# 	Examples seen: 210000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 11.4781370163
# 	training_seconds_this_epoch: 5.63761138916
# 	valid_h0_col_norms_max: 8.81156826019
# 	valid_h0_col_norms_mean: 6.2538151741
# 	valid_h0_col_norms_min: 4.45541810989
# 	valid_h0_max_x_max_u: 9.03950786591
# 	valid_h0_max_x_mean_u: 1.89761710167
# 	valid_h0_max_x_min_u: 0.301472365856
# 	valid_h0_mean_x_max_u: 4.16836118698
# 	valid_h0_mean_x_mean_u: 0.607817530632
# 	valid_h0_mean_x_min_u: 0.0529077351093
# 	valid_h0_min_x_max_u: 1.58422267437
# 	valid_h0_min_x_mean_u: 0.1259509027
# 	valid_h0_min_x_min_u: 6.65285115247e-05
# 	valid_h0_range_x_max_u: 8.29971790314
# 	valid_h0_range_x_mean_u: 1.77166652679
# 	valid_h0_range_x_min_u: 0.285497844219
# 	valid_h0_row_norms_max: 8.28155136108
# 	valid_h0_row_norms_mean: 5.49364423752
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.69388580322
# 	valid_h1_col_norms_mean: 6.27261638641
# 	valid_h1_col_norms_min: 4.28996229172
# 	valid_h1_max_x_max_u: 8.00510406494
# 	valid_h1_max_x_mean_u: 0.15761642158
# 	valid_h1_max_x_min_u: 1.24938656643e-10
# 	valid_h1_mean_x_max_u: 1.44771647453
# 	valid_h1_mean_x_mean_u: 0.0122774206102
# 	valid_h1_mean_x_min_u: 5.88741295299e-12
# 	valid_h1_min_x_max_u: 0.00162399455439
# 	valid_h1_min_x_mean_u: 3.71919509234e-06
# 	valid_h1_min_x_min_u: 5.88796691979e-23
# 	valid_h1_range_x_max_u: 8.00489616394
# 	valid_h1_range_x_mean_u: 0.157612726092
# 	valid_h1_range_x_min_u: 1.24938587254e-10
# 	valid_h1_row_norms_max: 8.95900821686
# 	valid_h1_row_norms_mean: 6.25261068344
# 	valid_h1_row_norms_min: 3.68445515633
# 	valid_objective: 3.01702976227
# 	valid_y0_col_norms_max: 8.20838165283
# 	valid_y0_col_norms_mean: 1.39047694206
# 	valid_y0_col_norms_min: 0.587713778019
# 	valid_y0_max_max_class: 0.270117908716
# 	valid_y0_mean_max_class: 0.0890035554767
# 	valid_y0_min_max_class: 0.0452725999057
# 	valid_y0_misclass: 0.761699914932
# 	valid_y0_nll: 3.18082809448
# 	valid_y0_row_norms_max: 2.13533353806
# 	valid_y0_row_norms_mean: 0.459793955088
# 	valid_y0_row_norms_min: 0.16054405272
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.863907 seconds
# Time this epoch: 5.171256 seconds
# Monitoring step:
# 	Epochs seen: 4
# 	Batches seen: 2800
# 	Examples seen: 280000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.59160995483
# 	training_seconds_this_epoch: 5.17125272751
# 	valid_h0_col_norms_max: 8.80379009247
# 	valid_h0_col_norms_mean: 6.25151443481
# 	valid_h0_col_norms_min: 4.44655370712
# 	valid_h0_max_x_max_u: 8.99662590027
# 	valid_h0_max_x_mean_u: 1.80408203602
# 	valid_h0_max_x_min_u: 0.276668608189
# 	valid_h0_mean_x_max_u: 4.05027770996
# 	valid_h0_mean_x_mean_u: 0.548072457314
# 	valid_h0_mean_x_min_u: 0.0475394316018
# 	valid_h0_min_x_max_u: 1.47616827488
# 	valid_h0_min_x_mean_u: 0.105026595294
# 	valid_h0_min_x_min_u: 5.1557799452e-05
# 	valid_h0_range_x_max_u: 8.3322687149
# 	valid_h0_range_x_mean_u: 1.69905567169
# 	valid_h0_range_x_min_u: 0.266465365887
# 	valid_h0_row_norms_max: 8.26724720001
# 	valid_h0_row_norms_mean: 5.49169921875
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.692943573
# 	valid_h1_col_norms_mean: 6.26788425446
# 	valid_h1_col_norms_min: 4.28860807419
# 	valid_h1_max_x_max_u: 7.8109254837
# 	valid_h1_max_x_mean_u: 0.191648080945
# 	valid_h1_max_x_min_u: 4.6047474167e-10
# 	valid_h1_mean_x_max_u: 1.15793812275
# 	valid_h1_mean_x_mean_u: 0.014232753776
# 	valid_h1_mean_x_min_u: 1.59392828797e-11
# 	valid_h1_min_x_max_u: 0.00145006692037
# 	valid_h1_min_x_mean_u: 4.26906080975e-06
# 	valid_h1_min_x_min_u: 1.99092690016e-22
# 	valid_h1_range_x_max_u: 7.81090831757
# 	valid_h1_range_x_mean_u: 0.191643819213
# 	valid_h1_range_x_min_u: 4.60474353092e-10
# 	valid_h1_row_norms_max: 8.9556350708
# 	valid_h1_row_norms_mean: 6.24809360504
# 	valid_h1_row_norms_min: 3.69848608971
# 	valid_objective: 2.870667696
# 	valid_y0_col_norms_max: 8.17013931274
# 	valid_y0_col_norms_mean: 1.4361499548
# 	valid_y0_col_norms_min: 0.625487089157
# 	valid_y0_max_max_class: 0.349691808224
# 	valid_y0_mean_max_class: 0.110695227981
# 	valid_y0_min_max_class: 0.0450301878154
# 	valid_y0_misclass: 0.731799781322
# 	valid_y0_nll: 3.03985905647
# 	valid_y0_row_norms_max: 2.13276290894
# 	valid_y0_row_norms_mean: 0.467550694942
# 	valid_y0_row_norms_min: 0.158731088042
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.115795 seconds
# Time this epoch: 5.451649 seconds
# Monitoring step:
# 	Epochs seen: 5
# 	Batches seen: 3500
# 	Examples seen: 350000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.64468574524
# 	training_seconds_this_epoch: 5.45164585114
# 	valid_h0_col_norms_max: 8.79974460602
# 	valid_h0_col_norms_mean: 6.24953460693
# 	valid_h0_col_norms_min: 4.42891645432
# 	valid_h0_max_x_max_u: 8.7917175293
# 	valid_h0_max_x_mean_u: 1.71695029736
# 	valid_h0_max_x_min_u: 0.262235075235
# 	valid_h0_mean_x_max_u: 3.8540160656
# 	valid_h0_mean_x_mean_u: 0.495099544525
# 	valid_h0_mean_x_min_u: 0.0449740290642
# 	valid_h0_min_x_max_u: 1.37320923805
# 	valid_h0_min_x_mean_u: 0.0880272388458
# 	valid_h0_min_x_min_u: 4.48652026535e-05
# 	valid_h0_range_x_max_u: 8.22831535339
# 	valid_h0_range_x_mean_u: 1.62892365456
# 	valid_h0_range_x_min_u: 0.254807502031
# 	valid_h0_row_norms_max: 8.24894618988
# 	valid_h0_row_norms_mean: 5.49009609222
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.6918926239
# 	valid_h1_col_norms_mean: 6.26335048676
# 	valid_h1_col_norms_min: 4.28523874283
# 	valid_h1_max_x_max_u: 7.65338802338
# 	valid_h1_max_x_mean_u: 0.233947724104
# 	valid_h1_max_x_min_u: 2.3394017834e-09
# 	valid_h1_mean_x_max_u: 1.14355885983
# 	valid_h1_mean_x_mean_u: 0.0177746750414
# 	valid_h1_mean_x_min_u: 9.57433438087e-11
# 	valid_h1_min_x_max_u: 0.00253433105536
# 	valid_h1_min_x_mean_u: 7.49108221498e-06
# 	valid_h1_min_x_min_u: 7.0862099307e-21
# 	valid_h1_range_x_max_u: 7.65333747864
# 	valid_h1_range_x_mean_u: 0.233940288424
# 	valid_h1_range_x_min_u: 2.33939889682e-09
# 	valid_h1_row_norms_max: 8.95441913605
# 	valid_h1_row_norms_mean: 6.24372005463
# 	valid_h1_row_norms_min: 3.69384431839
# 	valid_objective: 2.7635447979
# 	valid_y0_col_norms_max: 8.14634418488
# 	valid_y0_col_norms_mean: 1.47993540764
# 	valid_y0_col_norms_min: 0.684157967567
# 	valid_y0_max_max_class: 0.340775221586
# 	valid_y0_mean_max_class: 0.119655407965
# 	valid_y0_min_max_class: 0.050595600158
# 	valid_y0_misclass: 0.691599845886
# 	valid_y0_nll: 2.89895892143
# 	valid_y0_row_norms_max: 2.12871742249
# 	valid_y0_row_norms_mean: 0.475532412529
# 	valid_y0_row_norms_min: 0.177923247218
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.200893 seconds
# Time this epoch: 5.575480 seconds
# Monitoring step:
# 	Epochs seen: 6
# 	Batches seen: 4200
# 	Examples seen: 420000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 9.08151531219
# 	training_seconds_this_epoch: 5.57547903061
# 	valid_h0_col_norms_max: 8.7955827713
# 	valid_h0_col_norms_mean: 6.24779224396
# 	valid_h0_col_norms_min: 4.42805719376
# 	valid_h0_max_x_max_u: 8.60736179352
# 	valid_h0_max_x_mean_u: 1.63726854324
# 	valid_h0_max_x_min_u: 0.239753544331
# 	valid_h0_mean_x_max_u: 3.56066679955
# 	valid_h0_mean_x_mean_u: 0.448816716671
# 	valid_h0_mean_x_min_u: 0.0405327528715
# 	valid_h0_min_x_max_u: 1.24633026123
# 	valid_h0_min_x_mean_u: 0.0738958343863
# 	valid_h0_min_x_min_u: 4.00961253035e-05
# 	valid_h0_range_x_max_u: 8.15869903564
# 	valid_h0_range_x_mean_u: 1.56337225437
# 	valid_h0_range_x_min_u: 0.234869539738
# 	valid_h0_row_norms_max: 8.23773479462
# 	valid_h0_row_norms_mean: 5.4886803627
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.69127750397
# 	valid_h1_col_norms_mean: 6.25897884369
# 	valid_h1_col_norms_min: 4.28297328949
# 	valid_h1_max_x_max_u: 7.5812458992
# 	valid_h1_max_x_mean_u: 0.267524540424
# 	valid_h1_max_x_min_u: 6.68771127366e-09
# 	valid_h1_mean_x_max_u: 1.06579566002
# 	valid_h1_mean_x_mean_u: 0.01987837255
# 	valid_h1_mean_x_min_u: 2.7749544329e-10
# 	valid_h1_min_x_max_u: 0.0031733980868
# 	valid_h1_min_x_mean_u: 9.42716906138e-06
# 	valid_h1_min_x_min_u: 6.06825771977e-20
# 	valid_h1_range_x_max_u: 7.58098077774
# 	valid_h1_range_x_mean_u: 0.267515093088
# 	valid_h1_range_x_min_u: 6.68771127366e-09
# 	valid_h1_row_norms_max: 8.95055389404
# 	valid_h1_row_norms_mean: 6.23951292038
# 	valid_h1_row_norms_min: 3.69984936714
# 	valid_objective: 2.65444970131
# 	valid_y0_col_norms_max: 8.09969806671
# 	valid_y0_col_norms_mean: 1.51859152317
# 	valid_y0_col_norms_min: 0.729213118553
# 	valid_y0_max_max_class: 0.402066916227
# 	valid_y0_mean_max_class: 0.129705145955
# 	valid_y0_min_max_class: 0.0508750267327
# 	valid_y0_misclass: 0.661099970341
# 	valid_y0_nll: 2.79969263077
# 	valid_y0_row_norms_max: 2.11808443069
# 	valid_y0_row_norms_mean: 0.482233762741
# 	valid_y0_row_norms_min: 0.199704229832
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.013083 seconds
# Time this epoch: 5.438342 seconds
# Monitoring step:
# 	Epochs seen: 7
# 	Batches seen: 4900
# 	Examples seen: 490000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 9.04992485046
# 	training_seconds_this_epoch: 5.43834114075
# 	valid_h0_col_norms_max: 8.7874956131
# 	valid_h0_col_norms_mean: 6.24637985229
# 	valid_h0_col_norms_min: 4.41978216171
# 	valid_h0_max_x_max_u: 8.47672748566
# 	valid_h0_max_x_mean_u: 1.56173431873
# 	valid_h0_max_x_min_u: 0.211020767689
# 	valid_h0_mean_x_max_u: 3.4193212986
# 	valid_h0_mean_x_mean_u: 0.407650798559
# 	valid_h0_mean_x_min_u: 0.035308085382
# 	valid_h0_min_x_max_u: 1.12598013878
# 	valid_h0_min_x_mean_u: 0.0620615556836
# 	valid_h0_min_x_min_u: 3.46632223227e-05
# 	valid_h0_range_x_max_u: 8.06485652924
# 	valid_h0_range_x_mean_u: 1.49967312813
# 	valid_h0_range_x_min_u: 0.20865033567
# 	valid_h0_row_norms_max: 8.2232503891
# 	valid_h0_row_norms_mean: 5.48753595352
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.6889705658
# 	valid_h1_col_norms_mean: 6.25481700897
# 	valid_h1_col_norms_min: 4.27616357803
# 	valid_h1_max_x_max_u: 7.34893894196
# 	valid_h1_max_x_mean_u: 0.304500252008
# 	valid_h1_max_x_min_u: 5.45774270222e-08
# 	valid_h1_mean_x_max_u: 0.977794587612
# 	valid_h1_mean_x_mean_u: 0.0236400160939
# 	valid_h1_mean_x_min_u: 2.60495647275e-09
# 	valid_h1_min_x_max_u: 0.00393018964678
# 	valid_h1_min_x_mean_u: 1.3951771507e-05
# 	valid_h1_min_x_min_u: 1.30064452631e-18
# 	valid_h1_range_x_max_u: 7.34851312637
# 	valid_h1_range_x_mean_u: 0.304486423731
# 	valid_h1_range_x_min_u: 5.45774270222e-08
# 	valid_h1_row_norms_max: 8.94371604919
# 	valid_h1_row_norms_mean: 6.23550033569
# 	valid_h1_row_norms_min: 3.69889235497
# 	valid_objective: 2.55118155479
# 	valid_y0_col_norms_max: 8.06169605255
# 	valid_y0_col_norms_mean: 1.55458426476
# 	valid_y0_col_norms_min: 0.770044803619
# 	valid_y0_max_max_class: 0.507458806038
# 	valid_y0_mean_max_class: 0.160771623254
# 	valid_y0_min_max_class: 0.053430031985
# 	valid_y0_misclass: 0.627799928188
# 	valid_y0_nll: 2.63049459457
# 	valid_y0_row_norms_max: 2.11128330231
# 	valid_y0_row_norms_mean: 0.488579332829
# 	valid_y0_row_norms_min: 0.213698938489
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.146055 seconds
# Time this epoch: 5.140900 seconds
# Monitoring step:
# 	Epochs seen: 8
# 	Batches seen: 5600
# 	Examples seen: 560000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 9.04260444641
# 	training_seconds_this_epoch: 5.14089488983
# 	valid_h0_col_norms_max: 8.7895488739
# 	valid_h0_col_norms_mean: 6.24523115158
# 	valid_h0_col_norms_min: 4.41425180435
# 	valid_h0_max_x_max_u: 8.29079818726
# 	valid_h0_max_x_mean_u: 1.49565255642
# 	valid_h0_max_x_min_u: 0.191996589303
# 	valid_h0_mean_x_max_u: 3.23151016235
# 	valid_h0_mean_x_mean_u: 0.372822880745
# 	valid_h0_mean_x_min_u: 0.031592965126
# 	valid_h0_min_x_max_u: 1.03991770744
# 	valid_h0_min_x_mean_u: 0.052817389369
# 	valid_h0_min_x_min_u: 2.97314036288e-05
# 	valid_h0_range_x_max_u: 7.96261072159
# 	valid_h0_range_x_mean_u: 1.44283509254
# 	valid_h0_range_x_min_u: 0.190024420619
# 	valid_h0_row_norms_max: 8.20426940918
# 	valid_h0_row_norms_mean: 5.4866271019
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.68726444244
# 	valid_h1_col_norms_mean: 6.25092029572
# 	valid_h1_col_norms_min: 4.27351140976
# 	valid_h1_max_x_max_u: 7.30290269852
# 	valid_h1_max_x_mean_u: 0.343968003988
# 	valid_h1_max_x_min_u: 2.83473781337e-07
# 	valid_h1_mean_x_max_u: 1.00780797005
# 	valid_h1_mean_x_mean_u: 0.0274071209133
# 	valid_h1_mean_x_min_u: 1.28799015897e-08
# 	valid_h1_min_x_max_u: 0.00508235767484
# 	valid_h1_min_x_mean_u: 1.94260501303e-05
# 	valid_h1_min_x_min_u: 1.10183675325e-17
# 	valid_h1_range_x_max_u: 7.30227470398
# 	valid_h1_range_x_mean_u: 0.343948543072
# 	valid_h1_range_x_min_u: 2.83473752916e-07
# 	valid_h1_row_norms_max: 8.94126033783
# 	valid_h1_row_norms_mean: 6.23173666
# 	valid_h1_row_norms_min: 3.70717668533
# 	valid_objective: 2.49752831459
# 	valid_y0_col_norms_max: 8.02574062347
# 	valid_y0_col_norms_mean: 1.59461510181
# 	valid_y0_col_norms_min: 0.811304032803
# 	valid_y0_max_max_class: 0.460968196392
# 	valid_y0_mean_max_class: 0.164821863174
# 	valid_y0_min_max_class: 0.0548060685396
# 	valid_y0_misclass: 0.596599936485
# 	valid_y0_nll: 2.52251625061
# 	valid_y0_row_norms_max: 2.10920453072
# 	valid_y0_row_norms_mean: 0.495959043503
# 	valid_y0_row_norms_min: 0.212072983384
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.777327 seconds
# Time this epoch: 5.716746 seconds
# Monitoring step:
# 	Epochs seen: 9
# 	Batches seen: 6300
# 	Examples seen: 630000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.07409191132
# 	training_seconds_this_epoch: 5.71674966812
# 	valid_h0_col_norms_max: 8.78630542755
# 	valid_h0_col_norms_mean: 6.24418640137
# 	valid_h0_col_norms_min: 4.40724515915
# 	valid_h0_max_x_max_u: 8.18888187408
# 	valid_h0_max_x_mean_u: 1.43657743931
# 	valid_h0_max_x_min_u: 0.175272345543
# 	valid_h0_mean_x_max_u: 3.13761496544
# 	valid_h0_mean_x_mean_u: 0.343383342028
# 	valid_h0_mean_x_min_u: 0.0279873386025
# 	valid_h0_min_x_max_u: 0.980448842049
# 	valid_h0_min_x_mean_u: 0.0457166433334
# 	valid_h0_min_x_min_u: 2.47061125265e-05
# 	valid_h0_range_x_max_u: 7.90031290054
# 	valid_h0_range_x_mean_u: 1.39086067677
# 	valid_h0_range_x_min_u: 0.173922255635
# 	valid_h0_row_norms_max: 8.19668388367
# 	valid_h0_row_norms_mean: 5.48581647873
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.68615055084
# 	valid_h1_col_norms_mean: 6.2471871376
# 	valid_h1_col_norms_min: 4.26817464828
# 	valid_h1_max_x_max_u: 6.88554525375
# 	valid_h1_max_x_mean_u: 0.365793913603
# 	valid_h1_max_x_min_u: 1.7661691345e-06
# 	valid_h1_mean_x_max_u: 0.896148920059
# 	valid_h1_mean_x_mean_u: 0.0291331186891
# 	valid_h1_mean_x_min_u: 8.75476544593e-08
# 	valid_h1_min_x_max_u: 0.00321906432509
# 	valid_h1_min_x_mean_u: 1.95990523935e-05
# 	valid_h1_min_x_min_u: 2.01870410939e-16
# 	valid_h1_range_x_max_u: 6.88499259949
# 	valid_h1_range_x_mean_u: 0.365774303675
# 	valid_h1_range_x_min_u: 1.7661691345e-06
# 	valid_h1_row_norms_max: 8.93754673004
# 	valid_h1_row_norms_mean: 6.22811412811
# 	valid_h1_row_norms_min: 3.7027592659
# 	valid_objective: 2.43925118446
# 	valid_y0_col_norms_max: 7.97839450836
# 	valid_y0_col_norms_mean: 1.6279579401
# 	valid_y0_col_norms_min: 0.847162544727
# 	valid_y0_max_max_class: 0.517194211483
# 	valid_y0_mean_max_class: 0.175468847156
# 	valid_y0_min_max_class: 0.0556137934327
# 	valid_y0_misclass: 0.564499974251
# 	valid_y0_nll: 2.45529794693
# 	valid_y0_row_norms_max: 2.10738110542
# 	valid_y0_row_norms_mean: 0.501689255238
# 	valid_y0_row_norms_min: 0.204175621271
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.057598 seconds
# Time this epoch: 5.279089 seconds
# Monitoring step:
# 	Epochs seen: 10
# 	Batches seen: 7000
# 	Examples seen: 700000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 9.36985778809
# 	training_seconds_this_epoch: 5.27909421921
# 	valid_h0_col_norms_max: 8.78301143646
# 	valid_h0_col_norms_mean: 6.24348258972
# 	valid_h0_col_norms_min: 4.40222597122
# 	valid_h0_max_x_max_u: 8.02378940582
# 	valid_h0_max_x_mean_u: 1.38296699524
# 	valid_h0_max_x_min_u: 0.163136690855
# 	valid_h0_mean_x_max_u: 2.82270383835
# 	valid_h0_mean_x_mean_u: 0.316910147667
# 	valid_h0_mean_x_min_u: 0.0254733469337
# 	valid_h0_min_x_max_u: 0.835571467876
# 	valid_h0_min_x_mean_u: 0.0391401052475
# 	valid_h0_min_x_min_u: 2.0851057343e-05
# 	valid_h0_range_x_max_u: 7.8209643364
# 	valid_h0_range_x_mean_u: 1.3438270092
# 	valid_h0_range_x_min_u: 0.161927223206
# 	valid_h0_row_norms_max: 8.18519878387
# 	valid_h0_row_norms_mean: 5.48529243469
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.68377685547
# 	valid_h1_col_norms_mean: 6.24370670319
# 	valid_h1_col_norms_min: 4.26231002808
# 	valid_h1_max_x_max_u: 7.2330198288
# 	valid_h1_max_x_mean_u: 0.38933250308
# 	valid_h1_max_x_min_u: 6.77643220115e-06
# 	valid_h1_mean_x_max_u: 0.915423631668
# 	valid_h1_mean_x_mean_u: 0.0323979817331
# 	valid_h1_mean_x_min_u: 3.32355142518e-07
# 	valid_h1_min_x_max_u: 0.00425413576886
# 	valid_h1_min_x_mean_u: 2.62116664089e-05
# 	valid_h1_min_x_min_u: 1.14243494646e-15
# 	valid_h1_range_x_max_u: 7.23242807388
# 	valid_h1_range_x_mean_u: 0.389306157827
# 	valid_h1_range_x_min_u: 6.77643129166e-06
# 	valid_h1_row_norms_max: 8.93570327759
# 	valid_h1_row_norms_mean: 6.22474241257
# 	valid_h1_row_norms_min: 3.70592451096
# 	valid_objective: 2.39774990082
# 	valid_y0_col_norms_max: 7.94540596008
# 	valid_y0_col_norms_mean: 1.66209077835
# 	valid_y0_col_norms_min: 0.894515395164
# 	valid_y0_max_max_class: 0.517523288727
# 	valid_y0_mean_max_class: 0.189157173038
# 	valid_y0_min_max_class: 0.0579753145576
# 	valid_y0_misclass: 0.53870010376
# 	valid_y0_nll: 2.35088729858
# 	valid_y0_row_norms_max: 2.10616612434
# 	valid_y0_row_norms_mean: 0.507757306099
# 	valid_y0_row_norms_min: 0.217247337103
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.836958 seconds
# Time this epoch: 5.073770 seconds
# Monitoring step:
# 	Epochs seen: 11
# 	Batches seen: 7700
# 	Examples seen: 770000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.35968208313
# 	training_seconds_this_epoch: 5.07377052307
# 	valid_h0_col_norms_max: 8.77896404266
# 	valid_h0_col_norms_mean: 6.24302387238
# 	valid_h0_col_norms_min: 4.39395952225
# 	valid_h0_max_x_max_u: 7.97103404999
# 	valid_h0_max_x_mean_u: 1.33757317066
# 	valid_h0_max_x_min_u: 0.154813930392
# 	valid_h0_mean_x_max_u: 2.60559487343
# 	valid_h0_mean_x_mean_u: 0.295889437199
# 	valid_h0_mean_x_min_u: 0.0240765158087
# 	valid_h0_min_x_max_u: 0.765076816082
# 	valid_h0_min_x_mean_u: 0.0343915224075
# 	valid_h0_min_x_min_u: 1.91903855011e-05
# 	valid_h0_range_x_max_u: 7.77822542191
# 	valid_h0_range_x_mean_u: 1.30318069458
# 	valid_h0_range_x_min_u: 0.153758004308
# 	valid_h0_row_norms_max: 8.16964817047
# 	valid_h0_row_norms_mean: 5.48496103287
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.68110752106
# 	valid_h1_col_norms_mean: 6.24056196213
# 	valid_h1_col_norms_min: 4.25946903229
# 	valid_h1_max_x_max_u: 7.1016087532
# 	valid_h1_max_x_mean_u: 0.420890539885
# 	valid_h1_max_x_min_u: 2.26938318519e-05
# 	valid_h1_mean_x_max_u: 0.884212315083
# 	valid_h1_mean_x_mean_u: 0.036248408258
# 	valid_h1_mean_x_min_u: 1.28908538954e-06
# 	valid_h1_min_x_max_u: 0.00450507597998
# 	valid_h1_min_x_mean_u: 3.38358222507e-05
# 	valid_h1_min_x_min_u: 7.27948500497e-15
# 	valid_h1_range_x_max_u: 7.10100889206
# 	valid_h1_range_x_mean_u: 0.420856952667
# 	valid_h1_range_x_min_u: 2.26938300329e-05
# 	valid_h1_row_norms_max: 8.93369293213
# 	valid_h1_row_norms_mean: 6.22167539597
# 	valid_h1_row_norms_min: 3.70726537704
# 	valid_objective: 2.31761336327
# 	valid_y0_col_norms_max: 7.92232751846
# 	valid_y0_col_norms_mean: 1.69452095032
# 	valid_y0_col_norms_min: 0.936365485191
# 	valid_y0_max_max_class: 0.613619983196
# 	valid_y0_mean_max_class: 0.221156448126
# 	valid_y0_min_max_class: 0.0608509480953
# 	valid_y0_misclass: 0.534899950027
# 	valid_y0_nll: 2.24693346024
# 	valid_y0_row_norms_max: 2.10286450386
# 	valid_y0_row_norms_mean: 0.514158368111
# 	valid_y0_row_norms_min: 0.218781813979
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.011167 seconds
# Time this epoch: 5.422372 seconds
# Monitoring step:
# 	Epochs seen: 12
# 	Batches seen: 8400
# 	Examples seen: 840000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.70914554596
# 	training_seconds_this_epoch: 5.42236995697
# 	valid_h0_col_norms_max: 8.77832889557
# 	valid_h0_col_norms_mean: 6.24275302887
# 	valid_h0_col_norms_min: 4.38988447189
# 	valid_h0_max_x_max_u: 7.93448543549
# 	valid_h0_max_x_mean_u: 1.30127835274
# 	valid_h0_max_x_min_u: 0.144956335425
# 	valid_h0_mean_x_max_u: 2.45017361641
# 	valid_h0_mean_x_mean_u: 0.27871209383
# 	valid_h0_mean_x_min_u: 0.0222272537649
# 	valid_h0_min_x_max_u: 0.679817259312
# 	valid_h0_min_x_mean_u: 0.0303671155125
# 	valid_h0_min_x_min_u: 1.81541108759e-05
# 	valid_h0_range_x_max_u: 7.76946210861
# 	valid_h0_range_x_mean_u: 1.27091109753
# 	valid_h0_range_x_min_u: 0.144041568041
# 	valid_h0_row_norms_max: 8.16784000397
# 	valid_h0_row_norms_mean: 5.48483276367
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.67873382568
# 	valid_h1_col_norms_mean: 6.23766422272
# 	valid_h1_col_norms_min: 4.25481271744
# 	valid_h1_max_x_max_u: 7.22551107407
# 	valid_h1_max_x_mean_u: 0.450084209442
# 	valid_h1_max_x_min_u: 5.48273746972e-05
# 	valid_h1_mean_x_max_u: 0.922226548195
# 	valid_h1_mean_x_mean_u: 0.0396928116679
# 	valid_h1_mean_x_min_u: 3.02171042676e-06
# 	valid_h1_min_x_max_u: 0.00517384568229
# 	valid_h1_min_x_mean_u: 4.33537315985e-05
# 	valid_h1_min_x_min_u: 1.53335884165e-14
# 	valid_h1_range_x_max_u: 7.22474527359
# 	valid_h1_range_x_mean_u: 0.450040906668
# 	valid_h1_range_x_min_u: 5.48273746972e-05
# 	valid_h1_row_norms_max: 8.93082046509
# 	valid_h1_row_norms_mean: 6.21884822845
# 	valid_h1_row_norms_min: 3.7156291008
# 	valid_objective: 2.2906126976
# 	valid_y0_col_norms_max: 7.89190292358
# 	valid_y0_col_norms_mean: 1.73153543472
# 	valid_y0_col_norms_min: 0.98167514801
# 	valid_y0_max_max_class: 0.644308626652
# 	valid_y0_mean_max_class: 0.227223142982
# 	valid_y0_min_max_class: 0.0611574649811
# 	valid_y0_misclass: 0.51139998436
# 	valid_y0_nll: 2.16582679749
# 	valid_y0_row_norms_max: 2.09959435463
# 	valid_y0_row_norms_mean: 0.521262705326
# 	valid_y0_row_norms_min: 0.235664471984
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.810020 seconds
# Time this epoch: 5.460587 seconds
# Monitoring step:
# 	Epochs seen: 13
# 	Batches seen: 9100
# 	Examples seen: 910000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.65015602112
# 	training_seconds_this_epoch: 5.46059179306
# 	valid_h0_col_norms_max: 8.7737493515
# 	valid_h0_col_norms_mean: 6.24256038666
# 	valid_h0_col_norms_min: 4.39313173294
# 	valid_h0_max_x_max_u: 7.87768793106
# 	valid_h0_max_x_mean_u: 1.26776123047
# 	valid_h0_max_x_min_u: 0.137183025479
# 	valid_h0_mean_x_max_u: 2.3007645607
# 	valid_h0_mean_x_mean_u: 0.263653427362
# 	valid_h0_mean_x_min_u: 0.020506773144
# 	valid_h0_min_x_max_u: 0.617452144623
# 	valid_h0_min_x_mean_u: 0.0271039195359
# 	valid_h0_min_x_min_u: 1.65614110301e-05
# 	valid_h0_range_x_max_u: 7.7311835289
# 	valid_h0_range_x_mean_u: 1.24065768719
# 	valid_h0_range_x_min_u: 0.136429548264
# 	valid_h0_row_norms_max: 8.16235542297
# 	valid_h0_row_norms_mean: 5.48474121094
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.67738819122
# 	valid_h1_col_norms_mean: 6.23487281799
# 	valid_h1_col_norms_min: 4.25251197815
# 	valid_h1_max_x_max_u: 7.02455043793
# 	valid_h1_max_x_mean_u: 0.472326725721
# 	valid_h1_max_x_min_u: 0.000100218931038
# 	valid_h1_mean_x_max_u: 0.868333756924
# 	valid_h1_mean_x_mean_u: 0.042872633785
# 	valid_h1_mean_x_min_u: 5.61742854188e-06
# 	valid_h1_min_x_max_u: 0.00669227633625
# 	valid_h1_min_x_mean_u: 5.19582645211e-05
# 	valid_h1_min_x_min_u: 4.5018886351e-14
# 	valid_h1_range_x_max_u: 7.02379655838
# 	valid_h1_range_x_mean_u: 0.472274690866
# 	valid_h1_range_x_min_u: 0.000100218931038
# 	valid_h1_row_norms_max: 8.92800426483
# 	valid_h1_row_norms_mean: 6.21613025665
# 	valid_h1_row_norms_min: 3.71963500977
# 	valid_objective: 2.22805595398
# 	valid_y0_col_norms_max: 7.85899114609
# 	valid_y0_col_norms_mean: 1.76320934296
# 	valid_y0_col_norms_min: 0.997556805611
# 	valid_y0_max_max_class: 0.665218532085
# 	valid_y0_mean_max_class: 0.240537911654
# 	valid_y0_min_max_class: 0.0613444708288
# 	valid_y0_misclass: 0.496299952269
# 	valid_y0_nll: 2.09769940376
# 	valid_y0_row_norms_max: 2.0973470211
# 	valid_y0_row_norms_mean: 0.527104914188
# 	valid_y0_row_norms_min: 0.231122985482
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.961955 seconds
# Time this epoch: 6.056308 seconds
# Monitoring step:
# 	Epochs seen: 14
# 	Batches seen: 9800
# 	Examples seen: 980000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.78268146515
# 	training_seconds_this_epoch: 6.0563082695
# 	valid_h0_col_norms_max: 8.76674365997
# 	valid_h0_col_norms_mean: 6.24241924286
# 	valid_h0_col_norms_min: 4.38973283768
# 	valid_h0_max_x_max_u: 7.85428714752
# 	valid_h0_max_x_mean_u: 1.23561131954
# 	valid_h0_max_x_min_u: 0.137253761292
# 	valid_h0_mean_x_max_u: 2.2485473156
# 	valid_h0_mean_x_mean_u: 0.250005453825
# 	valid_h0_mean_x_min_u: 0.0203885771334
# 	valid_h0_min_x_max_u: 0.587521016598
# 	valid_h0_min_x_mean_u: 0.024247162044
# 	valid_h0_min_x_min_u: 1.47534801727e-05
# 	valid_h0_range_x_max_u: 7.72036552429
# 	valid_h0_range_x_mean_u: 1.21136403084
# 	valid_h0_range_x_min_u: 0.136485040188
# 	valid_h0_row_norms_max: 8.15992069244
# 	valid_h0_row_norms_mean: 5.4846777916
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.67410945892
# 	valid_h1_col_norms_mean: 6.23225831985
# 	valid_h1_col_norms_min: 4.24650287628
# 	valid_h1_max_x_max_u: 6.97531414032
# 	valid_h1_max_x_mean_u: 0.482140392065
# 	valid_h1_max_x_min_u: 0.000171291598235
# 	valid_h1_mean_x_max_u: 0.810347378254
# 	valid_h1_mean_x_mean_u: 0.0445443093777
# 	valid_h1_mean_x_min_u: 1.02282792795e-05
# 	valid_h1_min_x_max_u: 0.00680477265269
# 	valid_h1_min_x_mean_u: 5.75702360948e-05
# 	valid_h1_min_x_min_u: 1.21440496006e-13
# 	valid_h1_range_x_max_u: 6.97483873367
# 	valid_h1_range_x_mean_u: 0.48208257556
# 	valid_h1_range_x_min_u: 0.000171291525476
# 	valid_h1_row_norms_max: 8.92674064636
# 	valid_h1_row_norms_mean: 6.21356582642
# 	valid_h1_row_norms_min: 3.72971892357
# 	valid_objective: 2.18569993973
# 	valid_y0_col_norms_max: 7.82018661499
# 	valid_y0_col_norms_mean: 1.79245722294
# 	valid_y0_col_norms_min: 1.02694499493
# 	valid_y0_max_max_class: 0.652931392193
# 	valid_y0_mean_max_class: 0.24635013938
# 	valid_y0_min_max_class: 0.0641485080123
# 	valid_y0_misclass: 0.481399983168
# 	valid_y0_nll: 2.05730843544
# 	valid_y0_row_norms_max: 2.09662890434
# 	valid_y0_row_norms_mean: 0.532205998898
# 	valid_y0_row_norms_min: 0.239922478795
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.215256 seconds
# Time this epoch: 5.688427 seconds
# Monitoring step:
# 	Epochs seen: 15
# 	Batches seen: 10500
# 	Examples seen: 1050000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 10.0522966385
# 	training_seconds_this_epoch: 5.68842840195
# 	valid_h0_col_norms_max: 8.76445865631
# 	valid_h0_col_norms_mean: 6.24261188507
# 	valid_h0_col_norms_min: 4.39259767532
# 	valid_h0_max_x_max_u: 7.76442241669
# 	valid_h0_max_x_mean_u: 1.20902228355
# 	valid_h0_max_x_min_u: 0.128004848957
# 	valid_h0_mean_x_max_u: 2.0256896019
# 	valid_h0_mean_x_mean_u: 0.238042682409
# 	valid_h0_mean_x_min_u: 0.0188453495502
# 	valid_h0_min_x_max_u: 0.50597435236
# 	valid_h0_min_x_mean_u: 0.0217736177146
# 	valid_h0_min_x_min_u: 1.36926837513e-05
# 	valid_h0_range_x_max_u: 7.65959501266
# 	valid_h0_range_x_mean_u: 1.18724882603
# 	valid_h0_range_x_min_u: 0.12746296823
# 	valid_h0_row_norms_max: 8.15855312347
# 	valid_h0_row_norms_mean: 5.48490142822
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.67425060272
# 	valid_h1_col_norms_mean: 6.22996044159
# 	valid_h1_col_norms_min: 4.24513959885
# 	valid_h1_max_x_max_u: 7.06126213074
# 	valid_h1_max_x_mean_u: 0.512325584888
# 	valid_h1_max_x_min_u: 0.000329495524056
# 	valid_h1_mean_x_max_u: 0.797658324242
# 	valid_h1_mean_x_mean_u: 0.0485452413559
# 	valid_h1_mean_x_min_u: 2.14016890823e-05
# 	valid_h1_min_x_max_u: 0.00656509492546
# 	valid_h1_min_x_mean_u: 6.85600389261e-05
# 	valid_h1_min_x_min_u: 3.71533506001e-13
# 	valid_h1_range_x_max_u: 7.06052970886
# 	valid_h1_range_x_mean_u: 0.512257099152
# 	valid_h1_range_x_min_u: 0.000329495407641
# 	valid_h1_row_norms_max: 8.92516231537
# 	valid_h1_row_norms_mean: 6.21127986908
# 	valid_h1_row_norms_min: 3.71213555336
# 	valid_objective: 2.14181852341
# 	valid_y0_col_norms_max: 7.78178882599
# 	valid_y0_col_norms_mean: 1.82571482658
# 	valid_y0_col_norms_min: 1.08429968357
# 	valid_y0_max_max_class: 0.690850973129
# 	valid_y0_mean_max_class: 0.261052489281
# 	valid_y0_min_max_class: 0.0644350573421
# 	valid_y0_misclass: 0.461599946022
# 	valid_y0_nll: 1.97951591015
# 	valid_y0_row_norms_max: 2.09639954567
# 	valid_y0_row_norms_mean: 0.538733303547
# 	valid_y0_row_norms_min: 0.234043583274
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.850415 seconds
# Time this epoch: 5.530880 seconds
# Monitoring step:
# 	Epochs seen: 16
# 	Batches seen: 11200
# 	Examples seen: 1120000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 9.03806972504
# 	training_seconds_this_epoch: 5.53088140488
# 	valid_h0_col_norms_max: 8.76235866547
# 	valid_h0_col_norms_mean: 6.24264431
# 	valid_h0_col_norms_min: 4.39484834671
# 	valid_h0_max_x_max_u: 7.73042488098
# 	valid_h0_max_x_mean_u: 1.18654167652
# 	valid_h0_max_x_min_u: 0.128007605672
# 	valid_h0_mean_x_max_u: 1.96570014954
# 	valid_h0_mean_x_mean_u: 0.228535041213
# 	valid_h0_mean_x_min_u: 0.0187042616308
# 	valid_h0_min_x_max_u: 0.474469453096
# 	valid_h0_min_x_mean_u: 0.0199027154595
# 	valid_h0_min_x_min_u: 1.22605406432e-05
# 	valid_h0_range_x_max_u: 7.64878606796
# 	valid_h0_range_x_mean_u: 1.16663944721
# 	valid_h0_range_x_min_u: 0.127568140626
# 	valid_h0_row_norms_max: 8.15696430206
# 	valid_h0_row_norms_mean: 5.48497533798
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.67084217072
# 	valid_h1_col_norms_mean: 6.22762393951
# 	valid_h1_col_norms_min: 4.24273586273
# 	valid_h1_max_x_max_u: 7.18930625916
# 	valid_h1_max_x_mean_u: 0.528614878654
# 	valid_h1_max_x_min_u: 0.000509957084432
# 	valid_h1_mean_x_max_u: 0.849754571915
# 	valid_h1_mean_x_mean_u: 0.0514102689922
# 	valid_h1_mean_x_min_u: 3.29694921675e-05
# 	valid_h1_min_x_max_u: 0.00692245131359
# 	valid_h1_min_x_mean_u: 7.48637903598e-05
# 	valid_h1_min_x_min_u: 5.4771904243e-13
# 	valid_h1_range_x_max_u: 7.18781661987
# 	valid_h1_range_x_mean_u: 0.528540074825
# 	valid_h1_range_x_min_u: 0.000509956851602
# 	valid_h1_row_norms_max: 8.92591762543
# 	valid_h1_row_norms_mean: 6.20900630951
# 	valid_h1_row_norms_min: 3.71995568275
# 	valid_objective: 2.14119553566
# 	valid_y0_col_norms_max: 7.74149656296
# 	valid_y0_col_norms_mean: 1.85401678085
# 	valid_y0_col_norms_min: 1.11117327213
# 	valid_y0_max_max_class: 0.670850336552
# 	valid_y0_mean_max_class: 0.267093092203
# 	valid_y0_min_max_class: 0.0635628476739
# 	valid_y0_misclass: 0.445800036192
# 	valid_y0_nll: 1.93590939045
# 	valid_y0_row_norms_max: 2.09682846069
# 	valid_y0_row_norms_mean: 0.543886601925
# 	valid_y0_row_norms_min: 0.244563445449
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.820827 seconds
# Time this epoch: 4.972548 seconds
# Monitoring step:
# 	Epochs seen: 17
# 	Batches seen: 11900
# 	Examples seen: 1190000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.66767120361
# 	training_seconds_this_epoch: 4.97255182266
# 	valid_h0_col_norms_max: 8.75635242462
# 	valid_h0_col_norms_mean: 6.24284410477
# 	valid_h0_col_norms_min: 4.40074729919
# 	valid_h0_max_x_max_u: 7.64240169525
# 	valid_h0_max_x_mean_u: 1.16851496696
# 	valid_h0_max_x_min_u: 0.123407781124
# 	valid_h0_mean_x_max_u: 1.9111328125
# 	valid_h0_mean_x_mean_u: 0.220534443855
# 	valid_h0_mean_x_min_u: 0.0177356246859
# 	valid_h0_min_x_max_u: 0.451096951962
# 	valid_h0_min_x_mean_u: 0.0183711331338
# 	valid_h0_min_x_min_u: 1.17086265163e-05
# 	valid_h0_range_x_max_u: 7.57209777832
# 	valid_h0_range_x_mean_u: 1.15014362335
# 	valid_h0_range_x_min_u: 0.12300799787
# 	valid_h0_row_norms_max: 8.15429592133
# 	valid_h0_row_norms_mean: 5.48520469666
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.66871738434
# 	valid_h1_col_norms_mean: 6.2254576683
# 	valid_h1_col_norms_min: 4.2346701622
# 	valid_h1_max_x_max_u: 7.53654384613
# 	valid_h1_max_x_mean_u: 0.55382412672
# 	valid_h1_max_x_min_u: 0.00067463866435
# 	valid_h1_mean_x_max_u: 0.852198600769
# 	valid_h1_mean_x_mean_u: 0.054733004421
# 	valid_h1_mean_x_min_u: 4.33755485574e-05
# 	valid_h1_min_x_max_u: 0.00827458687127
# 	valid_h1_min_x_mean_u: 8.54720492498e-05
# 	valid_h1_min_x_min_u: 9.26352419252e-13
# 	valid_h1_range_x_max_u: 7.53561210632
# 	valid_h1_range_x_mean_u: 0.553738772869
# 	valid_h1_range_x_min_u: 0.000674638315104
# 	valid_h1_row_norms_max: 8.92191028595
# 	valid_h1_row_norms_mean: 6.20687866211
# 	valid_h1_row_norms_min: 3.70850682259
# 	valid_objective: 2.09557104111
# 	valid_y0_col_norms_max: 7.70339679718
# 	valid_y0_col_norms_mean: 1.88112580776
# 	valid_y0_col_norms_min: 1.14905416965
# 	valid_y0_max_max_class: 0.759706735611
# 	valid_y0_mean_max_class: 0.280732393265
# 	valid_y0_min_max_class: 0.0675170868635
# 	valid_y0_misclass: 0.433999985456
# 	valid_y0_nll: 1.86773574352
# 	valid_y0_row_norms_max: 2.09314846992
# 	valid_y0_row_norms_mean: 0.548925697803
# 	valid_y0_row_norms_min: 0.234691768885
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.867911 seconds
# Time this epoch: 6.044903 seconds
# Monitoring step:
# 	Epochs seen: 18
# 	Batches seen: 12600
# 	Examples seen: 1260000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.50621318817
# 	training_seconds_this_epoch: 6.04490852356
# 	valid_h0_col_norms_max: 8.75650119781
# 	valid_h0_col_norms_mean: 6.24322605133
# 	valid_h0_col_norms_min: 4.40607213974
# 	valid_h0_max_x_max_u: 7.62460660934
# 	valid_h0_max_x_mean_u: 1.15084695816
# 	valid_h0_max_x_min_u: 0.117434524
# 	valid_h0_mean_x_max_u: 1.84625124931
# 	valid_h0_mean_x_mean_u: 0.213165789843
# 	valid_h0_mean_x_min_u: 0.0166464801878
# 	valid_h0_min_x_max_u: 0.423233419657
# 	valid_h0_min_x_mean_u: 0.0169697850943
# 	valid_h0_min_x_min_u: 1.10942937681e-05
# 	valid_h0_range_x_max_u: 7.55918884277
# 	valid_h0_range_x_mean_u: 1.13387715816
# 	valid_h0_range_x_min_u: 0.117071568966
# 	valid_h0_row_norms_max: 8.15013790131
# 	valid_h0_row_norms_mean: 5.48559856415
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.66783905029
# 	valid_h1_col_norms_mean: 6.22345256805
# 	valid_h1_col_norms_min: 4.22914743423
# 	valid_h1_max_x_max_u: 7.25564146042
# 	valid_h1_max_x_mean_u: 0.570544779301
# 	valid_h1_max_x_min_u: 0.000901475839783
# 	valid_h1_mean_x_max_u: 0.811232626438
# 	valid_h1_mean_x_mean_u: 0.0572473779321
# 	valid_h1_mean_x_min_u: 6.17801706539e-05
# 	valid_h1_min_x_max_u: 0.0075192716904
# 	valid_h1_min_x_mean_u: 9.16859280551e-05
# 	valid_h1_min_x_min_u: 1.82943178835e-12
# 	valid_h1_range_x_max_u: 7.25498247147
# 	valid_h1_range_x_mean_u: 0.570453166962
# 	valid_h1_range_x_min_u: 0.000901475083083
# 	valid_h1_row_norms_max: 8.91963100433
# 	valid_h1_row_norms_mean: 6.20489168167
# 	valid_h1_row_norms_min: 3.71031594276
# 	valid_objective: 2.07106018066
# 	valid_y0_col_norms_max: 7.66858053207
# 	valid_y0_col_norms_mean: 1.91001880169
# 	valid_y0_col_norms_min: 1.1712231636
# 	valid_y0_max_max_class: 0.7653850317
# 	valid_y0_mean_max_class: 0.300681740046
# 	valid_y0_min_max_class: 0.0677900612354
# 	valid_y0_misclass: 0.429599940777
# 	valid_y0_nll: 1.82471179962
# 	valid_y0_row_norms_max: 2.09033751488
# 	valid_y0_row_norms_mean: 0.554522037506
# 	valid_y0_row_norms_min: 0.245654553175
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.954377 seconds
# Time this epoch: 5.541415 seconds
# Monitoring step:
# 	Epochs seen: 19
# 	Batches seen: 13300
# 	Examples seen: 1330000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 9.34825706482
# 	training_seconds_this_epoch: 5.5414185524
# 	valid_h0_col_norms_max: 8.75888347626
# 	valid_h0_col_norms_mean: 6.24365711212
# 	valid_h0_col_norms_min: 4.41389036179
# 	valid_h0_max_x_max_u: 7.58373212814
# 	valid_h0_max_x_mean_u: 1.1344653368
# 	valid_h0_max_x_min_u: 0.115213699639
# 	valid_h0_mean_x_max_u: 1.75268805027
# 	valid_h0_mean_x_mean_u: 0.206220015883
# 	valid_h0_mean_x_min_u: 0.0162715632468
# 	valid_h0_min_x_max_u: 0.399969816208
# 	valid_h0_min_x_mean_u: 0.0157101470977
# 	valid_h0_min_x_min_u: 1.0294115782e-05
# 	valid_h0_range_x_max_u: 7.52066612244
# 	valid_h0_range_x_mean_u: 1.11875498295
# 	valid_h0_range_x_min_u: 0.114789128304
# 	valid_h0_row_norms_max: 8.15030288696
# 	valid_h0_row_norms_mean: 5.48605537415
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.66550159454
# 	valid_h1_col_norms_mean: 6.22156524658
# 	valid_h1_col_norms_min: 4.22782850266
# 	valid_h1_max_x_max_u: 7.19875192642
# 	valid_h1_max_x_mean_u: 0.583737373352
# 	valid_h1_max_x_min_u: 0.00114723015577
# 	valid_h1_mean_x_max_u: 0.821269929409
# 	valid_h1_mean_x_mean_u: 0.0592244528234
# 	valid_h1_mean_x_min_u: 7.86768578109e-05
# 	valid_h1_min_x_max_u: 0.00927448552102
# 	valid_h1_min_x_mean_u: 0.00010052187281
# 	valid_h1_min_x_min_u: 3.97445661451e-12
# 	valid_h1_range_x_max_u: 7.19753789902
# 	valid_h1_range_x_mean_u: 0.583636581898
# 	valid_h1_range_x_min_u: 0.00114722945727
# 	valid_h1_row_norms_max: 8.91858005524
# 	valid_h1_row_norms_mean: 6.20303249359
# 	valid_h1_row_norms_min: 3.72173953056
# 	valid_objective: 1.99771952629
# 	valid_y0_col_norms_max: 7.63993024826
# 	valid_y0_col_norms_mean: 1.93626856804
# 	valid_y0_col_norms_min: 1.19773936272
# 	valid_y0_max_max_class: 0.767949700356
# 	valid_y0_mean_max_class: 0.301597863436
# 	valid_y0_min_max_class: 0.0696611702442
# 	valid_y0_misclass: 0.415700078011
# 	valid_y0_nll: 1.79243886471
# 	valid_y0_row_norms_max: 2.08840370178
# 	valid_y0_row_norms_mean: 0.559413969517
# 	valid_y0_row_norms_min: 0.245595067739
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.840924 seconds
# Time this epoch: 5.010462 seconds
# Monitoring step:
# 	Epochs seen: 20
# 	Batches seen: 14000
# 	Examples seen: 1400000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.72860050201
# 	training_seconds_this_epoch: 5.01046180725
# 	valid_h0_col_norms_max: 8.76022815704
# 	valid_h0_col_norms_mean: 6.24403905869
# 	valid_h0_col_norms_min: 4.40879392624
# 	valid_h0_max_x_max_u: 7.55509710312
# 	valid_h0_max_x_mean_u: 1.12118279934
# 	valid_h0_max_x_min_u: 0.113115534186
# 	valid_h0_mean_x_max_u: 1.68139827251
# 	valid_h0_mean_x_mean_u: 0.200558960438
# 	valid_h0_mean_x_min_u: 0.0160261839628
# 	valid_h0_min_x_max_u: 0.369989752769
# 	valid_h0_min_x_mean_u: 0.0146135054529
# 	valid_h0_min_x_min_u: 9.54283677856e-06
# 	valid_h0_range_x_max_u: 7.49274253845
# 	valid_h0_range_x_mean_u: 1.10656964779
# 	valid_h0_range_x_min_u: 0.112714514136
# 	valid_h0_row_norms_max: 8.14838123322
# 	valid_h0_row_norms_mean: 5.48642683029
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.66342258453
# 	valid_h1_col_norms_mean: 6.21973514557
# 	valid_h1_col_norms_min: 4.23051738739
# 	valid_h1_max_x_max_u: 7.15380954742
# 	valid_h1_max_x_mean_u: 0.596482932568
# 	valid_h1_max_x_min_u: 0.00145838106982
# 	valid_h1_mean_x_max_u: 0.821957409382
# 	valid_h1_mean_x_mean_u: 0.0608196482062
# 	valid_h1_mean_x_min_u: 0.00010121538071
# 	valid_h1_min_x_max_u: 0.00721530197188
# 	valid_h1_min_x_mean_u: 9.79887699941e-05
# 	valid_h1_min_x_min_u: 1.00710256107e-11
# 	valid_h1_range_x_max_u: 7.15245199203
# 	valid_h1_range_x_mean_u: 0.596385121346
# 	valid_h1_range_x_min_u: 0.00145838002209
# 	valid_h1_row_norms_max: 8.91842079163
# 	valid_h1_row_norms_mean: 6.20122337341
# 	valid_h1_row_norms_min: 3.71871614456
# 	valid_objective: 2.01960134506
# 	valid_y0_col_norms_max: 7.59005260468
# 	valid_y0_col_norms_mean: 1.96143627167
# 	valid_y0_col_norms_min: 1.22609937191
# 	valid_y0_max_max_class: 0.777559757233
# 	valid_y0_mean_max_class: 0.31106826663
# 	valid_y0_min_max_class: 0.0719244852662
# 	valid_y0_misclass: 0.407400101423
# 	valid_y0_nll: 1.75068151951
# 	valid_y0_row_norms_max: 2.08262252808
# 	valid_y0_row_norms_mean: 0.56423330307
# 	valid_y0_row_norms_min: 0.259366542101
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.736844 seconds
# Time this epoch: 5.825803 seconds
# Monitoring step:
# 	Epochs seen: 21
# 	Batches seen: 14700
# 	Examples seen: 1470000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.03712844849
# 	training_seconds_this_epoch: 5.82580518723
# 	valid_h0_col_norms_max: 8.75643825531
# 	valid_h0_col_norms_mean: 6.24452018738
# 	valid_h0_col_norms_min: 4.40499448776
# 	valid_h0_max_x_max_u: 7.56167078018
# 	valid_h0_max_x_mean_u: 1.10801315308
# 	valid_h0_max_x_min_u: 0.110573634505
# 	valid_h0_mean_x_max_u: 1.65624606609
# 	valid_h0_mean_x_mean_u: 0.194999992847
# 	valid_h0_mean_x_min_u: 0.0155246518552
# 	valid_h0_min_x_max_u: 0.349012434483
# 	valid_h0_min_x_mean_u: 0.0136246634647
# 	valid_h0_min_x_min_u: 8.92905700312e-06
# ...
# 	valid_h1_row_norms_mean: 6.14595794678
# 	valid_h1_row_norms_min: 3.650826931
# 	valid_objective: 1.45750629902
# 	valid_y0_col_norms_max: 6.06276130676
# 	valid_y0_col_norms_mean: 2.84973788261
# 	valid_y0_col_norms_min: 2.08201479912
# 	valid_y0_max_max_class: 0.963950037956
# 	valid_y0_mean_max_class: 0.57181853056
# 	valid_y0_min_max_class: 0.127070918679
# 	valid_y0_misclass: 0.25180003047
# 	valid_y0_nll: 0.97242307663
# 	valid_y0_row_norms_max: 2.04214763641
# 	valid_y0_row_norms_mean: 0.760167837143
# 	valid_y0_row_norms_min: 0.341725260019
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 0.867482 seconds
# Time this epoch: 5.646987 seconds
# Monitoring step:
# 	Epochs seen: 87
# 	Batches seen: 60900
# 	Examples seen: 6090000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.82714939117
# 	training_seconds_this_epoch: 5.64699077606
# 	valid_h0_col_norms_max: 8.7111825943
# 	valid_h0_col_norms_mean: 6.33040618896
# 	valid_h0_col_norms_min: 4.3624663353
# 	valid_h0_max_x_max_u: 7.77721595764
# 	valid_h0_max_x_mean_u: 0.934181630611
# 	valid_h0_max_x_min_u: 0.0580275692046
# 	valid_h0_mean_x_max_u: 0.929784595966
# 	valid_h0_mean_x_mean_u: 0.109826415777
# 	valid_h0_mean_x_min_u: 0.00681587820873
# 	valid_h0_min_x_max_u: 0.0734961107373
# 	valid_h0_min_x_mean_u: 0.00190515536815
# 	valid_h0_min_x_min_u: 9.06173113435e-07
# 	valid_h0_range_x_max_u: 7.76169967651
# 	valid_h0_range_x_mean_u: 0.93227660656
# 	valid_h0_range_x_min_u: 0.0579273253679
# 	valid_h0_row_norms_max: 8.00775337219
# 	valid_h0_row_norms_mean: 5.55901956558
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.61965656281
# 	valid_h1_col_norms_mean: 6.16542434692
# 	valid_h1_col_norms_min: 4.23264455795
# 	valid_h1_max_x_max_u: 5.99527168274
# 	valid_h1_max_x_mean_u: 0.918798446655
# 	valid_h1_max_x_min_u: 0.0263458564878
# 	valid_h1_mean_x_max_u: 0.595469415188
# 	valid_h1_mean_x_mean_u: 0.111401565373
# 	valid_h1_mean_x_min_u: 0.00250101438724
# 	valid_h1_min_x_max_u: 0.00882906652987
# 	valid_h1_min_x_mean_u: 0.000287827308057
# 	valid_h1_min_x_min_u: 6.41302344562e-09
# 	valid_h1_range_x_max_u: 5.99449872971
# 	valid_h1_range_x_mean_u: 0.918510556221
# 	valid_h1_range_x_min_u: 0.0263453181833
# 	valid_h1_row_norms_max: 8.88023471832
# 	valid_h1_row_norms_mean: 6.14554023743
# 	valid_h1_row_norms_min: 3.64837002754
# 	valid_objective: 1.43288445473
# 	valid_y0_col_norms_max: 6.04920291901
# 	valid_y0_col_norms_mean: 2.85759139061
# 	valid_y0_col_norms_min: 2.09417366982
# 	valid_y0_max_max_class: 0.96878439188
# 	valid_y0_mean_max_class: 0.572607636452
# 	valid_y0_min_max_class: 0.126793727279
# 	valid_y0_misclass: 0.255100011826
# 	valid_y0_nll: 0.964119076729
# 	valid_y0_row_norms_max: 2.04371452332
# 	valid_y0_row_norms_mean: 0.76215416193
# 	valid_y0_row_norms_min: 0.338076472282
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.237834 seconds
# Time this epoch: 5.495528 seconds
# Monitoring step:
# 	Epochs seen: 88
# 	Batches seen: 61600
# 	Examples seen: 6160000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.30997371674
# 	training_seconds_this_epoch: 5.49553203583
# 	valid_h0_col_norms_max: 8.71267604828
# 	valid_h0_col_norms_mean: 6.33203077316
# 	valid_h0_col_norms_min: 4.36312437057
# 	valid_h0_max_x_max_u: 7.78889274597
# 	valid_h0_max_x_mean_u: 0.9357213974
# 	valid_h0_max_x_min_u: 0.0579367205501
# 	valid_h0_mean_x_max_u: 0.912929952145
# 	valid_h0_mean_x_mean_u: 0.109540782869
# 	valid_h0_mean_x_min_u: 0.00678760046139
# 	valid_h0_min_x_max_u: 0.0694474205375
# 	valid_h0_min_x_mean_u: 0.00185005413368
# 	valid_h0_min_x_min_u: 8.67930907589e-07
# 	valid_h0_range_x_max_u: 7.77506542206
# 	valid_h0_range_x_mean_u: 0.933871388435
# 	valid_h0_range_x_min_u: 0.0578324273229
# 	valid_h0_row_norms_max: 8.00633525848
# 	valid_h0_row_norms_mean: 5.56033754349
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.61998748779
# 	valid_h1_col_norms_mean: 6.16506004333
# 	valid_h1_col_norms_min: 4.22981500626
# 	valid_h1_max_x_max_u: 6.06937265396
# 	valid_h1_max_x_mean_u: 0.922657668591
# 	valid_h1_max_x_min_u: 0.0273487791419
# 	valid_h1_mean_x_max_u: 0.587691545486
# 	valid_h1_mean_x_mean_u: 0.111413829029
# 	valid_h1_mean_x_min_u: 0.00254906388
# 	valid_h1_min_x_max_u: 0.00899423286319
# 	valid_h1_min_x_mean_u: 0.000285471498501
# 	valid_h1_min_x_min_u: 6.25567242452e-09
# 	valid_h1_range_x_max_u: 6.06861305237
# 	valid_h1_range_x_mean_u: 0.922372341156
# 	valid_h1_range_x_min_u: 0.0273477081209
# 	valid_h1_row_norms_max: 8.88013935089
# 	valid_h1_row_norms_mean: 6.14515590668
# 	valid_h1_row_norms_min: 3.64620733261
# 	valid_objective: 1.46542263031
# 	valid_y0_col_norms_max: 6.04852437973
# 	valid_y0_col_norms_mean: 2.86651301384
# 	valid_y0_col_norms_min: 2.10211205482
# 	valid_y0_max_max_class: 0.96485054493
# 	valid_y0_mean_max_class: 0.571131944656
# 	valid_y0_min_max_class: 0.123993560672
# 	valid_y0_misclass: 0.251199990511
# 	valid_y0_nll: 0.960858106613
# 	valid_y0_row_norms_max: 2.04733347893
# 	valid_y0_row_norms_mean: 0.764433979988
# 	valid_y0_row_norms_min: 0.333939105272
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.266442 seconds
# Time this epoch: 5.956785 seconds
# Monitoring step:
# 	Epochs seen: 89
# 	Batches seen: 62300
# 	Examples seen: 6230000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 9.56097507477
# 	training_seconds_this_epoch: 5.95678949356
# 	valid_h0_col_norms_max: 8.71153926849
# 	valid_h0_col_norms_mean: 6.3335776329
# 	valid_h0_col_norms_min: 4.3714261055
# 	valid_h0_max_x_max_u: 7.7543554306
# 	valid_h0_max_x_mean_u: 0.93564504385
# 	valid_h0_max_x_min_u: 0.0577990487218
# 	valid_h0_mean_x_max_u: 0.894919574261
# 	valid_h0_mean_x_mean_u: 0.109213583171
# 	valid_h0_mean_x_min_u: 0.00675465911627
# 	valid_h0_min_x_max_u: 0.0672802254558
# 	valid_h0_min_x_mean_u: 0.00181642384268
# 	valid_h0_min_x_min_u: 8.4496019781e-07
# 	valid_h0_range_x_max_u: 7.74092149734
# 	valid_h0_range_x_mean_u: 0.93382871151
# 	valid_h0_range_x_min_u: 0.0576953180134
# 	valid_h0_row_norms_max: 8.0036649704
# 	valid_h0_row_norms_mean: 5.5615735054
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.61940670013
# 	valid_h1_col_norms_mean: 6.16466140747
# 	valid_h1_col_norms_min: 4.22926092148
# 	valid_h1_max_x_max_u: 6.07945919037
# 	valid_h1_max_x_mean_u: 0.931934595108
# 	valid_h1_max_x_min_u: 0.0270545259118
# 	valid_h1_mean_x_max_u: 0.59933835268
# 	valid_h1_mean_x_mean_u: 0.112640544772
# 	valid_h1_mean_x_min_u: 0.00248823990114
# 	valid_h1_min_x_max_u: 0.0092219831422
# 	valid_h1_min_x_mean_u: 0.00029059604276
# 	valid_h1_min_x_min_u: 6.5992713516e-09
# 	valid_h1_range_x_max_u: 6.0787320137
# 	valid_h1_range_x_mean_u: 0.931644022465
# 	valid_h1_range_x_min_u: 0.0270540453494
# 	valid_h1_row_norms_max: 8.87965869904
# 	valid_h1_row_norms_mean: 6.14475822449
# 	valid_h1_row_norms_min: 3.64735174179
# 	valid_objective: 1.45972311497
# 	valid_y0_col_norms_max: 6.04300451279
# 	valid_y0_col_norms_mean: 2.87549710274
# 	valid_y0_col_norms_min: 2.11727905273
# 	valid_y0_max_max_class: 0.970230937004
# 	valid_y0_mean_max_class: 0.581909477711
# 	valid_y0_min_max_class: 0.127311632037
# 	valid_y0_misclass: 0.256600052118
# 	valid_y0_nll: 0.951073408127
# 	valid_y0_row_norms_max: 2.05172204971
# 	valid_y0_row_norms_mean: 0.766569793224
# 	valid_y0_row_norms_min: 0.337711215019
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.053270 seconds
# Time this epoch: 6.541510 seconds
# Monitoring step:
# 	Epochs seen: 90
# 	Batches seen: 63000
# 	Examples seen: 6300000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.302734375
# 	training_seconds_this_epoch: 6.54150438309
# 	valid_h0_col_norms_max: 8.71362400055
# 	valid_h0_col_norms_mean: 6.33511829376
# 	valid_h0_col_norms_min: 4.36728239059
# 	valid_h0_max_x_max_u: 7.80560922623
# 	valid_h0_max_x_mean_u: 0.933410465717
# 	valid_h0_max_x_min_u: 0.0577328912914
# 	valid_h0_mean_x_max_u: 0.904452741146
# 	valid_h0_mean_x_mean_u: 0.108588397503
# 	valid_h0_mean_x_min_u: 0.00673963408917
# 	valid_h0_min_x_max_u: 0.0676836520433
# 	valid_h0_min_x_mean_u: 0.001799386926
# 	valid_h0_min_x_min_u: 7.93509684627e-07
# 	valid_h0_range_x_max_u: 7.79084396362
# 	valid_h0_range_x_mean_u: 0.931611299515
# 	valid_h0_range_x_min_u: 0.0576263293624
# 	valid_h0_row_norms_max: 8.0005197525
# 	valid_h0_row_norms_mean: 5.56281709671
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.61930561066
# 	valid_h1_col_norms_mean: 6.16421604156
# 	valid_h1_col_norms_min: 4.23207330704
# 	valid_h1_max_x_max_u: 6.03621768951
# 	valid_h1_max_x_mean_u: 0.924863278866
# 	valid_h1_max_x_min_u: 0.0278963353485
# 	valid_h1_mean_x_max_u: 0.590649724007
# 	valid_h1_mean_x_mean_u: 0.112449817359
# 	valid_h1_mean_x_min_u: 0.00265288236551
# 	valid_h1_min_x_max_u: 0.0091385692358
# 	valid_h1_min_x_mean_u: 0.000292544806143
# 	valid_h1_min_x_min_u: 7.01901559097e-09
# 	valid_h1_range_x_max_u: 6.03544998169
# 	valid_h1_range_x_mean_u: 0.924570977688
# 	valid_h1_range_x_min_u: 0.0278952792287
# 	valid_h1_row_norms_max: 8.87994670868
# 	valid_h1_row_norms_mean: 6.14428138733
# 	valid_h1_row_norms_min: 3.64327406883
# 	valid_objective: 1.44984817505
# 	valid_y0_col_norms_max: 6.03203821182
# 	valid_y0_col_norms_mean: 2.8824801445
# 	valid_y0_col_norms_min: 2.13714551926
# 	valid_y0_max_max_class: 0.9662976861
# 	valid_y0_mean_max_class: 0.574270665646
# 	valid_y0_min_max_class: 0.129606604576
# 	valid_y0_misclass: 0.255099952221
# 	valid_y0_nll: 0.9590934515
# 	valid_y0_row_norms_max: 2.05869746208
# 	valid_y0_row_norms_mean: 0.768190562725
# 	valid_y0_row_norms_min: 0.323839068413
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.183856 seconds
# Time this epoch: 5.389076 seconds
# Monitoring step:
# 	Epochs seen: 91
# 	Batches seen: 63700
# 	Examples seen: 6370000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 8.92805290222
# 	training_seconds_this_epoch: 5.38907194138
# 	valid_h0_col_norms_max: 8.7184305191
# 	valid_h0_col_norms_mean: 6.33651256561
# 	valid_h0_col_norms_min: 4.3662238121
# 	valid_h0_max_x_max_u: 7.81282663345
# 	valid_h0_max_x_mean_u: 0.934779942036
# 	valid_h0_max_x_min_u: 0.0573940314353
# 	valid_h0_mean_x_max_u: 0.910528242588
# 	valid_h0_mean_x_mean_u: 0.108676813543
# 	valid_h0_mean_x_min_u: 0.00669919513166
# 	valid_h0_min_x_max_u: 0.0685661360621
# 	valid_h0_min_x_mean_u: 0.00179083831608
# 	valid_h0_min_x_min_u: 7.57989937483e-07
# 	valid_h0_range_x_max_u: 7.79813671112
# 	valid_h0_range_x_mean_u: 0.932988882065
# 	valid_h0_range_x_min_u: 0.0572894588113
# 	valid_h0_row_norms_max: 7.99850511551
# 	valid_h0_row_norms_mean: 5.56393003464
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.61910629272
# 	valid_h1_col_norms_mean: 6.16387176514
# 	valid_h1_col_norms_min: 4.23174381256
# 	valid_h1_max_x_max_u: 5.95048332214
# 	valid_h1_max_x_mean_u: 0.923987388611
# 	valid_h1_max_x_min_u: 0.026413269341
# 	valid_h1_mean_x_max_u: 0.582389116287
# 	valid_h1_mean_x_mean_u: 0.111538730562
# 	valid_h1_mean_x_min_u: 0.00249812868424
# 	valid_h1_min_x_max_u: 0.00890119560063
# 	valid_h1_min_x_mean_u: 0.000287189002847
# 	valid_h1_min_x_min_u: 6.65289512369e-09
# 	valid_h1_range_x_max_u: 5.94967031479
# 	valid_h1_range_x_mean_u: 0.923700153828
# 	valid_h1_range_x_min_u: 0.0264122523367
# 	valid_h1_row_norms_max: 8.8798418045
# 	valid_h1_row_norms_mean: 6.14391851425
# 	valid_h1_row_norms_min: 3.64391160011
# 	valid_objective: 1.46074676514
# 	valid_y0_col_norms_max: 6.01191949844
# 	valid_y0_col_norms_mean: 2.8911986351
# 	valid_y0_col_norms_min: 2.14595723152
# 	valid_y0_max_max_class: 0.966289639473
# 	valid_y0_mean_max_class: 0.57704693079
# 	valid_y0_min_max_class: 0.12649025023
# 	valid_y0_misclass: 0.254900068045
# 	valid_y0_nll: 0.952305674553
# 	valid_y0_row_norms_max: 2.06082820892
# 	valid_y0_row_norms_mean: 0.770266652107
# 	valid_y0_row_norms_min: 0.332794457674
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.247009 seconds
# Time this epoch: 5.398815 seconds
# Monitoring step:
# 	Epochs seen: 92
# 	Batches seen: 64400
# 	Examples seen: 6440000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 7.7754983902
# 	training_seconds_this_epoch: 5.39881229401
# 	valid_h0_col_norms_max: 8.71988010406
# 	valid_h0_col_norms_mean: 6.3380279541
# 	valid_h0_col_norms_min: 4.36868715286
# 	valid_h0_max_x_max_u: 7.80419254303
# 	valid_h0_max_x_mean_u: 0.935983717442
# 	valid_h0_max_x_min_u: 0.0571914799511
# 	valid_h0_mean_x_max_u: 0.917648673058
# 	valid_h0_mean_x_mean_u: 0.108459800482
# 	valid_h0_mean_x_min_u: 0.00666637718678
# 	valid_h0_min_x_max_u: 0.0660677030683
# 	valid_h0_min_x_mean_u: 0.00175386341289
# 	valid_h0_min_x_min_u: 7.40555208267e-07
# 	valid_h0_range_x_max_u: 7.78932094574
# 	valid_h0_range_x_mean_u: 0.934230029583
# 	valid_h0_range_x_min_u: 0.0570871904492
# 	valid_h0_row_norms_max: 7.99604415894
# 	valid_h0_row_norms_mean: 5.56515264511
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.6190738678
# 	valid_h1_col_norms_mean: 6.16351413727
# 	valid_h1_col_norms_min: 4.23275852203
# 	valid_h1_max_x_max_u: 5.96692895889
# 	valid_h1_max_x_mean_u: 0.93245446682
# 	valid_h1_max_x_min_u: 0.0275952965021
# 	valid_h1_mean_x_max_u: 0.586541950703
# 	valid_h1_mean_x_mean_u: 0.112429305911
# 	valid_h1_mean_x_min_u: 0.00248498679139
# 	valid_h1_min_x_max_u: 0.00865246728063
# 	valid_h1_min_x_mean_u: 0.000287867384031
# 	valid_h1_min_x_min_u: 6.66236843472e-09
# 	valid_h1_range_x_max_u: 5.96628665924
# 	valid_h1_range_x_mean_u: 0.932166457176
# 	valid_h1_range_x_min_u: 0.0275943875313
# 	valid_h1_row_norms_max: 8.87819862366
# 	valid_h1_row_norms_mean: 6.14355802536
# 	valid_h1_row_norms_min: 3.64257645607
# 	valid_objective: 1.44699406624
# 	valid_y0_col_norms_max: 5.99568748474
# 	valid_y0_col_norms_mean: 2.90039396286
# 	valid_y0_col_norms_min: 2.17046523094
# 	valid_y0_max_max_class: 0.96619951725
# 	valid_y0_mean_max_class: 0.579329669476
# 	valid_y0_min_max_class: 0.127237051725
# 	valid_y0_misclass: 0.249999970198
# 	valid_y0_nll: 0.941979706287
# 	valid_y0_row_norms_max: 2.0634059906
# 	valid_y0_row_norms_mean: 0.7726136446
# 	valid_y0_row_norms_min: 0.353997886181
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.147898 seconds
# Time this epoch: 5.542562 seconds
# Monitoring step:
# 	Epochs seen: 93
# 	Batches seen: 65100
# 	Examples seen: 6510000
# 	learning_rate: 0.100000023842
# 	total_seconds_last_epoch: 9.56665802002
# 	training_seconds_this_epoch: 5.54256391525
# 	valid_h0_col_norms_max: 8.71993160248
# 	valid_h0_col_norms_mean: 6.33945560455
# 	valid_h0_col_norms_min: 4.36887693405
# 	valid_h0_max_x_max_u: 7.83667421341
# 	valid_h0_max_x_mean_u: 0.934200227261
# 	valid_h0_max_x_min_u: 0.056768823415
# 	valid_h0_mean_x_max_u: 0.920552134514
# 	valid_h0_mean_x_mean_u: 0.108143866062
# 	valid_h0_mean_x_min_u: 0.00654965778813
# 	valid_h0_min_x_max_u: 0.0662643238902
# 	valid_h0_min_x_mean_u: 0.0017389972927
# 	valid_h0_min_x_min_u: 7.06069101852e-07
# 	valid_h0_range_x_max_u: 7.82259845734
# 	valid_h0_range_x_mean_u: 0.932461082935
# 	valid_h0_range_x_min_u: 0.0566760115325
# 	valid_h0_row_norms_max: 7.99579715729
# 	valid_h0_row_norms_mean: 5.56627702713
# 	valid_h0_row_norms_min: 3.10926389694
# 	valid_h1_col_norms_max: 8.61884212494
# 	valid_h1_col_norms_mean: 6.16303730011
# 	valid_h1_col_norms_min: 4.23297739029
# 	valid_h1_max_x_max_u: 5.92161512375
# 	valid_h1_max_x_mean_u: 0.924952685833
# 	valid_h1_max_x_min_u: 0.0267819799483
# 	valid_h1_mean_x_max_u: 0.58473443985
# 	valid_h1_mean_x_mean_u: 0.111683987081
# 	valid_h1_mean_x_min_u: 0.00246920553036
# 	valid_h1_min_x_max_u: 0.00872045569122
# 	valid_h1_min_x_mean_u: 0.000285543093923
# 	valid_h1_min_x_min_u: 6.66327926169e-09
# 	valid_h1_range_x_max_u: 5.92084121704
# 	valid_h1_range_x_mean_u: 0.924667179585
# 	valid_h1_range_x_min_u: 0.0267811212689
# 	valid_h1_row_norms_max: 8.87755489349
# 	valid_h1_row_norms_mean: 6.14304637909
# 	valid_h1_row_norms_min: 3.64106321335
# 	valid_objective: 1.4562972784
# 	valid_y0_col_norms_max: 5.99511814117
# 	valid_y0_col_norms_mean: 2.90585327148
# 	valid_y0_col_norms_min: 2.15357899666
# 	valid_y0_max_max_class: 0.967477440834
# 	valid_y0_mean_max_class: 0.583315730095
# 	valid_y0_min_max_class: 0.12644392252
# 	valid_y0_misclass: 0.253300011158
# 	valid_y0_nll: 0.946564733982
# 	valid_y0_row_norms_max: 2.06650829315
# 	valid_y0_row_norms_mean: 0.773801326752
# 	valid_y0_row_norms_min: 0.347277522087
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.534871 seconds
# Saving to train.pkl...
# Saving to train.pkl done. Time elapsed: 1.237681 seconds

# %%
# Calculate accuracy on test set

model = serial.load("train_best.pkl")

inputs = test.X.astype("float32")
yhat = model.fprop(theano.shared(inputs,name='inputs')).eval()

count = 0.
for i in range(test.X.shape[0]):
    if np.argmax(test.y[i])==np.argmax(yhat[i]):
        count += 1.

print "accuracy = ", count / test.X.shape[0]
# Out:
# accuracy =  0.764

# %% [markdown]
# ## 2-layer Softmax with RectLinear hidden_layer = 400 with Momentum

# %%
# Rectified Linear with Momentum

from pylearn2.training_algorithms import sgd, learning_rule

h0 = mlp.RectifiedLinear(layer_name='h0', dim=400, sparse_init=40)
y0 = mlp.Softmax(layer_name='y0', n_classes=62, irange=0)
layers = [h0, y0]

model = mlp.MLP(layers, nvis=1024)

# momentum
initial_momentum = 0.5
final_momentum = 0.99
start = 1
saturate = 50
momentum_rule = learning_rule.Momentum(initial_momentum)

monitoring = dict(valid=valid)
termination = MonitorBased(channel_name="valid_y0_misclass", N=10)
extensions = [best_params.MonitorBasedSaveBest(channel_name="valid_y0_misclass",save_path="rect_best.pkl"),
              learning_rule.MomentumAdjustor(final_momentum,start,saturate)]

algorithm = sgd.SGD(0.1, batch_size=100, cost=Dropout(),learning_rule=momentum_rule,
                    monitoring_dataset = monitoring, termination_criterion = termination)

print 'Running training'
train_job = Train(train, model, algorithm, extensions=extensions, save_path="rect.pkl", save_freq=5)
train_job.main_loop()
# Out:
# Running training
# Parameter and initial learning rate summary:
# 	h0_W: 0.10000000149
# 	h0_b: 0.10000000149
# 	softmax_b: 0.10000000149
# 	softmax_W: 0.10000000149
# Compiling sgd_update...
# Compiling sgd_update done. Time elapsed: 20.328927 seconds
# compiling begin_record_entry...
# compiling begin_record_entry done. Time elapsed: 0.239022 seconds
# Monitored channels:
# 	learning_rate
# 	momentum
# 	total_seconds_last_epoch
# 	training_seconds_this_epoch
# 	valid_h0_col_norms_max
# 	valid_h0_col_norms_mean
# 	valid_h0_col_norms_min
# 	valid_h0_max_x_max_u
# 	valid_h0_max_x_mean_u
# 	valid_h0_max_x_min_u
# 	valid_h0_mean_x_max_u
# 	valid_h0_mean_x_mean_u
# 	valid_h0_mean_x_min_u
# 	valid_h0_min_x_max_u
# 	valid_h0_min_x_mean_u
# 	valid_h0_min_x_min_u
# 	valid_h0_range_x_max_u
# 	valid_h0_range_x_mean_u
# 	valid_h0_range_x_min_u
# 	valid_h0_row_norms_max
# 	valid_h0_row_norms_mean
# 	valid_h0_row_norms_min
# 	valid_objective
# 	valid_y0_col_norms_max
# 	valid_y0_col_norms_mean
# 	valid_y0_col_norms_min
# 	valid_y0_max_max_class
# 	valid_y0_mean_max_class
# 	valid_y0_min_max_class
# 	valid_y0_misclass
# 	valid_y0_nll
# 	valid_y0_row_norms_max
# 	valid_y0_row_norms_mean
# 	valid_y0_row_norms_min
# Compiling accum...
# graph size: 158
# Compiling accum done. Time elapsed: 20.796107 seconds
# Monitoring step:
# 	Epochs seen: 0
# 	Batches seen: 0
# 	Examples seen: 0
# 	learning_rate: 0.100000023842
# 	momentum: 0.499999672174
# 	total_seconds_last_epoch: 0.0
# 	training_seconds_this_epoch: 0.0
# 	valid_h0_col_norms_max: 8.85791683197
# 	valid_h0_col_norms_mean: 6.31083011627
# 	valid_h0_col_norms_min: 4.46461009979
# 	valid_h0_max_x_max_u: 7.17846059799
# 	valid_h0_max_x_mean_u: 2.21492815018
# 	valid_h0_max_x_min_u: 0.000362653721822
# 	valid_h0_mean_x_max_u: 1.9454562664
# 	valid_h0_mean_x_mean_u: 0.388079941273
# 	valid_h0_mean_x_min_u: 3.62653736374e-06
# 	valid_h0_min_x_max_u: 0.00445132609457
# 	valid_h0_min_x_mean_u: 1.11283143269e-05
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 7.17846059799
# 	valid_h0_range_x_mean_u: 2.2149169445
# 	valid_h0_range_x_min_u: 0.000362653721822
# 	valid_h0_row_norms_max: 6.53977298737
# 	valid_h0_row_norms_mean: 3.87043476105
# 	valid_h0_row_norms_min: 1.16303682327
# 	valid_objective: 4.12713813782
# 	valid_y0_col_norms_max: 0.0
# 	valid_y0_col_norms_mean: 0.0
# 	valid_y0_col_norms_min: 0.0
# 	valid_y0_max_max_class: 0.0161290224642
# 	valid_y0_mean_max_class: 0.0161290224642
# 	valid_y0_min_max_class: 0.0161290224642
# 	valid_y0_misclass: 0.969299793243
# 	valid_y0_nll: 4.12713813782
# 	valid_y0_row_norms_max: 0.0
# 	valid_y0_row_norms_mean: 0.0
# 	valid_y0_row_norms_min: 0.0
# Time this epoch: 3.866276 seconds
# Monitoring step:
# 	Epochs seen: 1
# 	Batches seen: 700
# 	Examples seen: 70000
# 	learning_rate: 0.100000023842
# 	momentum: 0.499999672174
# 	total_seconds_last_epoch: 0.0
# 	training_seconds_this_epoch: 3.86627221107
# 	valid_h0_col_norms_max: 8.83640861511
# 	valid_h0_col_norms_mean: 6.29239034653
# 	valid_h0_col_norms_min: 4.4846997261
# 	valid_h0_max_x_max_u: 5.27720451355
# 	valid_h0_max_x_mean_u: 1.82819998264
# 	valid_h0_max_x_min_u: 0.00288202590309
# 	valid_h0_mean_x_max_u: 0.84692555666
# 	valid_h0_mean_x_mean_u: 0.20877751708
# 	valid_h0_mean_x_min_u: 3.86978572351e-05
# 	valid_h0_min_x_max_u: 0.000303998443997
# 	valid_h0_min_x_mean_u: 7.59996055422e-07
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 5.27720451355
# 	valid_h0_range_x_mean_u: 1.82819926739
# 	valid_h0_range_x_min_u: 0.00288202590309
# 	valid_h0_row_norms_max: 6.53945493698
# 	valid_h0_row_norms_mean: 3.85987901688
# 	valid_h0_row_norms_min: 1.18483805656
# 	valid_objective: 2.30850100517
# 	valid_y0_col_norms_max: 1.82424533367
# 	valid_y0_col_norms_mean: 1.12232375145
# 	valid_y0_col_norms_min: 0.636102974415
# 	valid_y0_max_max_class: 0.769099056721
# 	valid_y0_mean_max_class: 0.297822624445
# 	valid_y0_min_max_class: 0.0728303715587
# 	valid_y0_misclass: 0.396599948406
# 	valid_y0_nll: 1.82225334644
# 	valid_y0_row_norms_max: 0.700394570827
# 	valid_y0_row_norms_mean: 0.448414862156
# 	valid_y0_row_norms_min: 0.0347776636481
# Time this epoch: 3.271120 seconds
# Monitoring step:
# 	Epochs seen: 2
# 	Batches seen: 1400
# 	Examples seen: 140000
# 	learning_rate: 0.100000023842
# 	momentum: 0.5100004673
# 	total_seconds_last_epoch: 5.36522912979
# 	training_seconds_this_epoch: 3.2711212635
# 	valid_h0_col_norms_max: 8.82272815704
# 	valid_h0_col_norms_mean: 6.28544044495
# 	valid_h0_col_norms_min: 4.4501786232
# 	valid_h0_max_x_max_u: 4.81269311905
# 	valid_h0_max_x_mean_u: 1.6357666254
# 	valid_h0_max_x_min_u: 0.00806189700961
# 	valid_h0_mean_x_max_u: 0.773145318031
# 	valid_h0_mean_x_mean_u: 0.16068354249
# 	valid_h0_mean_x_min_u: 0.000107278130599
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.81269311905
# 	valid_h0_range_x_mean_u: 1.6357666254
# 	valid_h0_range_x_min_u: 0.00806189700961
# 	valid_h0_row_norms_max: 6.53714752197
# 	valid_h0_row_norms_mean: 3.8561835289
# 	valid_h0_row_norms_min: 1.21607077122
# 	valid_objective: 2.03020644188
# 	valid_y0_col_norms_max: 2.23972725868
# 	valid_y0_col_norms_mean: 1.41907513142
# 	valid_y0_col_norms_min: 0.860084712505
# 	valid_y0_max_max_class: 0.822088897228
# 	valid_y0_mean_max_class: 0.359780400991
# 	valid_y0_min_max_class: 0.0793638601899
# 	valid_y0_misclass: 0.366199910641
# 	valid_y0_nll: 1.59914660454
# 	valid_y0_row_norms_max: 0.950951933861
# 	valid_y0_row_norms_mean: 0.565195739269
# 	valid_y0_row_norms_min: 0.04754576087
# Time this epoch: 2.969181 seconds
# Monitoring step:
# 	Epochs seen: 3
# 	Batches seen: 2100
# 	Examples seen: 210000
# 	learning_rate: 0.100000023842
# 	momentum: 0.519999980927
# 	total_seconds_last_epoch: 4.39748239517
# 	training_seconds_this_epoch: 2.96917748451
# 	valid_h0_col_norms_max: 8.8185300827
# 	valid_h0_col_norms_mean: 6.28304433823
# 	valid_h0_col_norms_min: 4.43531847
# 	valid_h0_max_x_max_u: 4.69235229492
# 	valid_h0_max_x_mean_u: 1.52521204948
# 	valid_h0_max_x_min_u: 0.00327459536493
# 	valid_h0_mean_x_max_u: 0.724997699261
# 	valid_h0_mean_x_mean_u: 0.137637078762
# 	valid_h0_mean_x_min_u: 5.93660588493e-05
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.69235229492
# 	valid_h0_range_x_mean_u: 1.52521204948
# 	valid_h0_range_x_min_u: 0.00327459536493
# 	valid_h0_row_norms_max: 6.53357458115
# 	valid_h0_row_norms_mean: 3.85530471802
# 	valid_h0_row_norms_min: 1.27315080166
# 	valid_objective: 1.877430439
# 	valid_y0_col_norms_max: 2.60843372345
# 	valid_y0_col_norms_mean: 1.63602805138
# 	valid_y0_col_norms_min: 1.05417203903
# 	valid_y0_max_max_class: 0.855097591877
# 	valid_y0_mean_max_class: 0.397789895535
# 	valid_y0_min_max_class: 0.0800943747163
# 	valid_y0_misclass: 0.330199986696
# 	valid_y0_nll: 1.45547735691
# 	valid_y0_row_norms_max: 1.11414325237
# 	valid_y0_row_norms_mean: 0.648204684258
# 	valid_y0_row_norms_min: 0.06904450804
# Time this epoch: 2.626701 seconds
# Monitoring step:
# 	Epochs seen: 4
# 	Batches seen: 2800
# 	Examples seen: 280000
# 	learning_rate: 0.100000023842
# 	momentum: 0.529999256134
# 	total_seconds_last_epoch: 4.04009771347
# 	training_seconds_this_epoch: 2.62670326233
# 	valid_h0_col_norms_max: 8.80762577057
# 	valid_h0_col_norms_mean: 6.28295040131
# 	valid_h0_col_norms_min: 4.42061471939
# 	valid_h0_max_x_max_u: 4.56680202484
# 	valid_h0_max_x_mean_u: 1.46547484398
# 	valid_h0_max_x_min_u: 0.000409378582845
# 	valid_h0_mean_x_max_u: 0.683071613312
# 	valid_h0_mean_x_mean_u: 0.124506756663
# 	valid_h0_mean_x_min_u: 5.91334355704e-06
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.56680202484
# 	valid_h0_range_x_mean_u: 1.46547484398
# 	valid_h0_range_x_min_u: 0.000409378582845
# 	valid_h0_row_norms_max: 6.52728414536
# 	valid_h0_row_norms_mean: 3.85573506355
# 	valid_h0_row_norms_min: 1.29761242867
# 	valid_objective: 1.80620980263
# 	valid_y0_col_norms_max: 2.79935956001
# 	valid_y0_col_norms_mean: 1.8159301281
# 	valid_y0_col_norms_min: 1.18304383755
# 	valid_y0_max_max_class: 0.857190549374
# 	valid_y0_mean_max_class: 0.421991407871
# 	valid_y0_min_max_class: 0.0836295261979
# 	valid_y0_misclass: 0.321100026369
# 	valid_y0_nll: 1.3799585104
# 	valid_y0_row_norms_max: 1.22933483124
# 	valid_y0_row_norms_mean: 0.71620953083
# 	valid_y0_row_norms_min: 0.091106697917
# Time this epoch: 2.715399 seconds
# Monitoring step:
# 	Epochs seen: 5
# 	Batches seen: 3500
# 	Examples seen: 350000
# 	learning_rate: 0.100000023842
# 	momentum: 0.540000140667
# 	total_seconds_last_epoch: 3.72465252876
# 	training_seconds_this_epoch: 2.71539735794
# 	valid_h0_col_norms_max: 8.80228328705
# 	valid_h0_col_norms_mean: 6.28390598297
# 	valid_h0_col_norms_min: 4.41828298569
# 	valid_h0_max_x_max_u: 4.50926589966
# 	valid_h0_max_x_mean_u: 1.42875254154
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.654073894024
# 	valid_h0_mean_x_mean_u: 0.116019047797
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.50926589966
# 	valid_h0_range_x_mean_u: 1.42875254154
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.52341794968
# 	valid_h0_row_norms_mean: 3.85684919357
# 	valid_h0_row_norms_min: 1.29793787003
# 	valid_objective: 1.75651204586
# 	valid_y0_col_norms_max: 2.99276709557
# 	valid_y0_col_norms_mean: 1.96618747711
# 	valid_y0_col_norms_min: 1.30306363106
# 	valid_y0_max_max_class: 0.883394122124
# 	valid_y0_mean_max_class: 0.446046978235
# 	valid_y0_min_max_class: 0.086241774261
# 	valid_y0_misclass: 0.303600013256
# 	valid_y0_nll: 1.29766201973
# 	valid_y0_row_norms_max: 1.33501708508
# 	valid_y0_row_norms_mean: 0.772960782051
# 	valid_y0_row_norms_min: 0.106505513191
# Saving to rect.pkl...
# Saving to rect.pkl done. Time elapsed: 0.227056 seconds
# Time this epoch: 2.661540 seconds
# Monitoring step:
# 	Epochs seen: 6
# 	Batches seen: 4200
# 	Examples seen: 420000
# 	learning_rate: 0.100000023842
# 	momentum: 0.549999773502
# 	total_seconds_last_epoch: 3.91464185715
# 	training_seconds_this_epoch: 2.66153860092
# 	valid_h0_col_norms_max: 8.79721069336
# 	valid_h0_col_norms_mean: 6.28533697128
# 	valid_h0_col_norms_min: 4.41446352005
# 	valid_h0_max_x_max_u: 4.51986932755
# 	valid_h0_max_x_mean_u: 1.39423334599
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.71021682024
# 	valid_h0_mean_x_mean_u: 0.10952322185
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.51986932755
# 	valid_h0_range_x_mean_u: 1.39423334599
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.52152633667
# 	valid_h0_row_norms_mean: 3.85820293427
# 	valid_h0_row_norms_min: 1.2980093956
# 	valid_objective: 1.68376588821
# 	valid_y0_col_norms_max: 3.10929584503
# 	valid_y0_col_norms_mean: 2.09415030479
# 	valid_y0_col_norms_min: 1.40067315102
# 	valid_y0_max_max_class: 0.8726734519
# 	valid_y0_mean_max_class: 0.454213291407
# 	valid_y0_min_max_class: 0.0926025509834
# 	valid_y0_misclass: 0.288999974728
# 	valid_y0_nll: 1.25501966476
# 	valid_y0_row_norms_max: 1.43676912785
# 	valid_y0_row_norms_mean: 0.820993900299
# 	valid_y0_row_norms_min: 0.150356292725
# Time this epoch: 2.752410 seconds
# Monitoring step:
# 	Epochs seen: 7
# 	Batches seen: 4900
# 	Examples seen: 490000
# 	learning_rate: 0.100000023842
# 	momentum: 0.560000061989
# 	total_seconds_last_epoch: 3.81028151512
# 	training_seconds_this_epoch: 2.75240755081
# 	valid_h0_col_norms_max: 8.79173374176
# 	valid_h0_col_norms_mean: 6.28765869141
# 	valid_h0_col_norms_min: 4.4138379097
# 	valid_h0_max_x_max_u: 4.49322223663
# 	valid_h0_max_x_mean_u: 1.3771790266
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.68368691206
# 	valid_h0_mean_x_mean_u: 0.106446169317
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.49322223663
# 	valid_h0_range_x_mean_u: 1.3771790266
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.51931715012
# 	valid_h0_row_norms_mean: 3.85999107361
# 	valid_h0_row_norms_min: 1.29813313484
# 	valid_objective: 1.63510489464
# 	valid_y0_col_norms_max: 3.24947667122
# 	valid_y0_col_norms_mean: 2.21404194832
# 	valid_y0_col_norms_min: 1.50733292103
# 	valid_y0_max_max_class: 0.898734688759
# 	valid_y0_mean_max_class: 0.475509285927
# 	valid_y0_min_max_class: 0.0935414880514
# 	valid_y0_misclass: 0.286299943924
# 	valid_y0_nll: 1.20120942593
# 	valid_y0_row_norms_max: 1.506041646
# 	valid_y0_row_norms_mean: 0.865747153759
# 	valid_y0_row_norms_min: 0.216269463301
# Time this epoch: 2.533925 seconds
# Monitoring step:
# 	Epochs seen: 8
# 	Batches seen: 5600
# 	Examples seen: 560000
# 	learning_rate: 0.100000023842
# 	momentum: 0.569999396801
# 	total_seconds_last_epoch: 3.79036068916
# 	training_seconds_this_epoch: 2.53392720222
# 	valid_h0_col_norms_max: 8.78824710846
# 	valid_h0_col_norms_mean: 6.29011726379
# 	valid_h0_col_norms_min: 4.41238546371
# 	valid_h0_max_x_max_u: 4.49840831757
# 	valid_h0_max_x_mean_u: 1.36760890484
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.793042957783
# 	valid_h0_mean_x_mean_u: 0.104185886681
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.00137177226134
# 	valid_h0_min_x_mean_u: 3.42943053511e-06
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.49840831757
# 	valid_h0_range_x_mean_u: 1.36760544777
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.51993846893
# 	valid_h0_row_norms_mean: 3.8618516922
# 	valid_h0_row_norms_min: 1.29801142216
# 	valid_objective: 1.63230752945
# 	valid_y0_col_norms_max: 3.35691523552
# 	valid_y0_col_norms_mean: 2.31899189949
# 	valid_y0_col_norms_min: 1.56695556641
# 	valid_y0_max_max_class: 0.906564414501
# 	valid_y0_mean_max_class: 0.495541870594
# 	valid_y0_min_max_class: 0.105788834393
# 	valid_y0_misclass: 0.287900000811
# 	valid_y0_nll: 1.17002511024
# 	valid_y0_row_norms_max: 1.57251262665
# 	valid_y0_row_norms_mean: 0.904847800732
# 	valid_y0_row_norms_min: 0.319359600544
# Time this epoch: 2.521948 seconds
# Monitoring step:
# 	Epochs seen: 9
# 	Batches seen: 6300
# 	Examples seen: 630000
# 	learning_rate: 0.100000023842
# 	momentum: 0.580000340939
# 	total_seconds_last_epoch: 3.21105265617
# 	training_seconds_this_epoch: 2.52194595337
# 	valid_h0_col_norms_max: 8.78489971161
# 	valid_h0_col_norms_mean: 6.2932934761
# 	valid_h0_col_norms_min: 4.41104650497
# 	valid_h0_max_x_max_u: 4.51134395599
# 	valid_h0_max_x_mean_u: 1.34868776798
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.686026215553
# 	valid_h0_mean_x_mean_u: 0.0992114171386
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.51134395599
# 	valid_h0_range_x_mean_u: 1.34868776798
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.51993846893
# 	valid_h0_row_norms_mean: 3.86406898499
# 	valid_h0_row_norms_min: 1.29863011837
# 	valid_objective: 1.59202289581
# 	valid_y0_col_norms_max: 3.46953892708
# 	valid_y0_col_norms_mean: 2.41842460632
# 	valid_y0_col_norms_min: 1.61202049255
# 	valid_y0_max_max_class: 0.911189138889
# 	valid_y0_mean_max_class: 0.488584071398
# 	valid_y0_min_max_class: 0.102966323495
# 	valid_y0_misclass: 0.261799961329
# 	valid_y0_nll: 1.13433754444
# 	valid_y0_row_norms_max: 1.60553538799
# 	valid_y0_row_norms_mean: 0.942565321922
# 	valid_y0_row_norms_min: 0.405532866716
# Time this epoch: 2.875753 seconds
# Monitoring step:
# 	Epochs seen: 10
# 	Batches seen: 7000
# 	Examples seen: 700000
# 	learning_rate: 0.100000023842
# 	momentum: 0.590000092983
# 	total_seconds_last_epoch: 3.55929660797
# 	training_seconds_this_epoch: 2.87575554848
# 	valid_h0_col_norms_max: 8.77894306183
# 	valid_h0_col_norms_mean: 6.29631233215
# 	valid_h0_col_norms_min: 4.40370368958
# 	valid_h0_max_x_max_u: 4.46625995636
# 	valid_h0_max_x_mean_u: 1.33850181103
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.622957825661
# 	valid_h0_mean_x_mean_u: 0.0954506695271
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.46625995636
# 	valid_h0_range_x_mean_u: 1.33850181103
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.51993846893
# 	valid_h0_row_norms_mean: 3.86629152298
# 	valid_h0_row_norms_min: 1.29929673672
# 	valid_objective: 1.56481409073
# 	valid_y0_col_norms_max: 3.57663798332
# 	valid_y0_col_norms_mean: 2.50456523895
# 	valid_y0_col_norms_min: 1.68946909904
# 	valid_y0_max_max_class: 0.921530485153
# 	valid_y0_mean_max_class: 0.505464494228
# 	valid_y0_min_max_class: 0.108158953488
# 	valid_y0_misclass: 0.267599999905
# 	valid_y0_nll: 1.12064826488
# 	valid_y0_row_norms_max: 1.67293262482
# 	valid_y0_row_norms_mean: 0.97513204813
# 	valid_y0_row_norms_min: 0.457296580076
# Saving to rect.pkl...
# Saving to rect.pkl done. Time elapsed: 0.366758 seconds
# Time this epoch: 2.892865 seconds
# Monitoring step:
# 	Epochs seen: 11
# 	Batches seen: 7700
# 	Examples seen: 770000
# 	learning_rate: 0.100000023842
# 	momentum: 0.600000143051
# 	total_seconds_last_epoch: 4.01639890671
# 	training_seconds_this_epoch: 2.89286756516
# 	valid_h0_col_norms_max: 8.77466106415
# 	valid_h0_col_norms_mean: 6.29973506927
# 	valid_h0_col_norms_min: 4.4103140831
# 	valid_h0_max_x_max_u: 4.51138067245
# 	valid_h0_max_x_mean_u: 1.33107709885
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.588400304317
# 	valid_h0_mean_x_mean_u: 0.0934371724725
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.51138067245
# 	valid_h0_range_x_mean_u: 1.33107709885
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.51963758469
# 	valid_h0_row_norms_mean: 3.86871790886
# 	valid_h0_row_norms_min: 1.29985713959
# 	valid_objective: 1.52451598644
# 	valid_y0_col_norms_max: 3.68034815788
# 	valid_y0_col_norms_mean: 2.585242033
# 	valid_y0_col_norms_min: 1.7759449482
# 	valid_y0_max_max_class: 0.935565292835
# 	valid_y0_mean_max_class: 0.515168488026
# 	valid_y0_min_max_class: 0.106796130538
# 	valid_y0_misclass: 0.266599982977
# 	valid_y0_nll: 1.09442090988
# 	valid_y0_row_norms_max: 1.74529528618
# 	valid_y0_row_norms_mean: 1.00537061691
# 	valid_y0_row_norms_min: 0.467007577419
# Time this epoch: 2.781927 seconds
# Monitoring step:
# 	Epochs seen: 12
# 	Batches seen: 8400
# 	Examples seen: 840000
# 	learning_rate: 0.100000023842
# 	momentum: 0.6099999547
# 	total_seconds_last_epoch: 3.79733991623
# 	training_seconds_this_epoch: 2.78192400932
# 	valid_h0_col_norms_max: 8.77064800262
# 	valid_h0_col_norms_mean: 6.30377578735
# 	valid_h0_col_norms_min: 4.40813732147
# 	valid_h0_max_x_max_u: 4.44783163071
# 	valid_h0_max_x_mean_u: 1.33813214302
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.637684464455
# 	valid_h0_mean_x_mean_u: 0.0948067381978
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.44783163071
# 	valid_h0_range_x_mean_u: 1.33813214302
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.51963758469
# 	valid_h0_row_norms_mean: 3.87144041061
# 	valid_h0_row_norms_min: 1.30051743984
# 	valid_objective: 1.5433754921
# 	valid_y0_col_norms_max: 3.72925329208
# 	valid_y0_col_norms_mean: 2.66466355324
# 	valid_y0_col_norms_min: 1.8404866457
# 	valid_y0_max_max_class: 0.933786869049
# 	valid_y0_mean_max_class: 0.538232326508
# 	valid_y0_min_max_class: 0.113153763115
# 	valid_y0_misclass: 0.267200022936
# 	valid_y0_nll: 1.05751883984
# 	valid_y0_row_norms_max: 1.78340649605
# 	valid_y0_row_norms_mean: 1.03570258617
# 	valid_y0_row_norms_min: 0.468474805355
# Time this epoch: 2.871375 seconds
# Monitoring step:
# 	Epochs seen: 13
# 	Batches seen: 9100
# 	Examples seen: 910000
# 	learning_rate: 0.100000023842
# 	momentum: 0.61999976635
# 	total_seconds_last_epoch: 3.48429512978
# 	training_seconds_this_epoch: 2.8713722229
# 	valid_h0_col_norms_max: 8.77009487152
# 	valid_h0_col_norms_mean: 6.30764913559
# 	valid_h0_col_norms_min: 4.41533851624
# 	valid_h0_max_x_max_u: 4.42697763443
# 	valid_h0_max_x_mean_u: 1.32699608803
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.612391471863
# 	valid_h0_mean_x_mean_u: 0.0899638831615
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.42697763443
# 	valid_h0_range_x_mean_u: 1.32699608803
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.51963758469
# 	valid_h0_row_norms_mean: 3.87401604652
# 	valid_h0_row_norms_min: 1.30156707764
# 	valid_objective: 1.52360928059
# 	valid_y0_col_norms_max: 3.86378717422
# 	valid_y0_col_norms_mean: 2.73561263084
# 	valid_y0_col_norms_min: 1.90689313412
# 	valid_y0_max_max_class: 0.93368190527
# 	valid_y0_mean_max_class: 0.518983364105
# 	valid_y0_min_max_class: 0.107270278037
# 	valid_y0_misclass: 0.260199904442
# 	valid_y0_nll: 1.06839287281
# 	valid_y0_row_norms_max: 1.82313990593
# 	valid_y0_row_norms_mean: 1.06294167042
# 	valid_y0_row_norms_min: 0.497075349092
# Time this epoch: 2.736702 seconds
# Monitoring step:
# 	Epochs seen: 14
# 	Batches seen: 9800
# 	Examples seen: 980000
# 	learning_rate: 0.100000023842
# 	momentum: 0.629999577999
# 	total_seconds_last_epoch: 4.02584648132
# 	training_seconds_this_epoch: 2.73670339584
# 	valid_h0_col_norms_max: 8.76616573334
# 	valid_h0_col_norms_mean: 6.31157112122
# 	valid_h0_col_norms_min: 4.41467142105
# 	valid_h0_max_x_max_u: 4.40259647369
# 	valid_h0_max_x_mean_u: 1.32357859612
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.57227563858
# 	valid_h0_mean_x_mean_u: 0.0893739014864
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.40259647369
# 	valid_h0_range_x_mean_u: 1.32357859612
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.51963758469
# 	valid_h0_row_norms_mean: 3.87671136856
# 	valid_h0_row_norms_min: 1.30205583572
# 	valid_objective: 1.50410950184
# 	valid_y0_col_norms_max: 3.91547656059
# 	valid_y0_col_norms_mean: 2.80005979538
# 	valid_y0_col_norms_min: 1.99173462391
# 	valid_y0_max_max_class: 0.941774666309
# 	valid_y0_mean_max_class: 0.530539691448
# 	valid_y0_min_max_class: 0.117200925946
# 	valid_y0_misclass: 0.257099956274
# 	valid_y0_nll: 1.04082131386
# 	valid_y0_row_norms_max: 1.84681153297
# 	valid_y0_row_norms_mean: 1.0873862505
# 	valid_y0_row_norms_min: 0.506144046783
# Time this epoch: 3.282026 seconds
# Monitoring step:
# 	Epochs seen: 15
# 	Batches seen: 10500
# 	Examples seen: 1050000
# 	learning_rate: 0.100000023842
# 	momentum: 0.639999389648
# 	total_seconds_last_epoch: 3.99126887321
# 	training_seconds_this_epoch: 3.28202390671
# 	valid_h0_col_norms_max: 8.77278995514
# 	valid_h0_col_norms_mean: 6.31571960449
# 	valid_h0_col_norms_min: 4.40778875351
# 	valid_h0_max_x_max_u: 4.38814640045
# 	valid_h0_max_x_mean_u: 1.31900680065
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.559762895107
# 	valid_h0_mean_x_mean_u: 0.0883122682571
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.38814640045
# 	valid_h0_range_x_mean_u: 1.31900680065
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.51963758469
# 	valid_h0_row_norms_mean: 3.87948036194
# 	valid_h0_row_norms_min: 1.3025046587
# 	valid_objective: 1.47090065479
# 	valid_y0_col_norms_max: 3.98919129372
# 	valid_y0_col_norms_mean: 2.86128473282
# 	valid_y0_col_norms_min: 2.09429335594
# 	valid_y0_max_max_class: 0.938551843166
# 	valid_y0_mean_max_class: 0.537668466568
# 	valid_y0_min_max_class: 0.117831662297
# 	valid_y0_misclass: 0.254199951887
# 	valid_y0_nll: 1.02019155025
# 	valid_y0_row_norms_max: 1.87197613716
# 	valid_y0_row_norms_mean: 1.11086332798
# 	valid_y0_row_norms_min: 0.501975595951
# Saving to rect.pkl...
# Saving to rect.pkl done. Time elapsed: 0.367257 seconds
# Time this epoch: 2.995177 seconds
# Monitoring step:
# 	Epochs seen: 16
# 	Batches seen: 11200
# 	Examples seen: 1120000
# 	learning_rate: 0.100000023842
# 	momentum: 0.650000393391
# 	total_seconds_last_epoch: 4.85496425629
# 	training_seconds_this_epoch: 2.99517941475
# 	valid_h0_col_norms_max: 8.76818561554
# 	valid_h0_col_norms_mean: 6.32056045532
# 	valid_h0_col_norms_min: 4.42163705826
# 	valid_h0_max_x_max_u: 4.42986297607
# 	valid_h0_max_x_mean_u: 1.32461369038
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.615256845951
# 	valid_h0_mean_x_mean_u: 0.0878766924143
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.42986297607
# 	valid_h0_range_x_mean_u: 1.32461369038
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.5206193924
# 	valid_h0_row_norms_mean: 3.88265132904
# 	valid_h0_row_norms_min: 1.30272257328
# 	valid_objective: 1.45791304111
# 	valid_y0_col_norms_max: 4.03681278229
# 	valid_y0_col_norms_mean: 2.92626190186
# 	valid_y0_col_norms_min: 2.13894867897
# 	valid_y0_max_max_class: 0.947053134441
# 	valid_y0_mean_max_class: 0.544348180294
# 	valid_y0_min_max_class: 0.121541902423
# 	valid_y0_misclass: 0.251300007105
# 	valid_y0_nll: 1.0033415556
# 	valid_y0_row_norms_max: 1.89219963551
# 	valid_y0_row_norms_mean: 1.1357177496
# 	valid_y0_row_norms_min: 0.514643669128
# Time this epoch: 3.248681 seconds
# Monitoring step:
# 	Epochs seen: 17
# 	Batches seen: 11900
# 	Examples seen: 1190000
# 	learning_rate: 0.100000023842
# 	momentum: 0.660000145435
# 	total_seconds_last_epoch: 4.32455205917
# 	training_seconds_this_epoch: 3.24868440628
# 	valid_h0_col_norms_max: 8.76545524597
# 	valid_h0_col_norms_mean: 6.32549476624
# 	valid_h0_col_norms_min: 4.42421150208
# 	valid_h0_max_x_max_u: 4.42296361923
# 	valid_h0_max_x_mean_u: 1.3260601759
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.605593502522
# 	valid_h0_mean_x_mean_u: 0.0857236459851
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.42296361923
# 	valid_h0_range_x_mean_u: 1.3260601759
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.52259397507
# 	valid_h0_row_norms_mean: 3.88586997986
# 	valid_h0_row_norms_min: 1.30249142647
# 	valid_objective: 1.44566905499
# 	valid_y0_col_norms_max: 4.08714008331
# 	valid_y0_col_norms_mean: 2.9853348732
# 	valid_y0_col_norms_min: 2.19714426994
# 	valid_y0_max_max_class: 0.95383143425
# 	valid_y0_mean_max_class: 0.541947424412
# 	valid_y0_min_max_class: 0.119236312807
# 	valid_y0_misclass: 0.244099974632
# 	valid_y0_nll: 0.992872297764
# 	valid_y0_row_norms_max: 1.93994057178
# 	valid_y0_row_norms_mean: 1.15859377384
# 	valid_y0_row_norms_min: 0.498172670603
# Time this epoch: 2.869901 seconds
# Monitoring step:
# 	Epochs seen: 18
# 	Batches seen: 12600
# 	Examples seen: 1260000
# 	learning_rate: 0.100000023842
# 	momentum: 0.669999718666
# 	total_seconds_last_epoch: 4.31130552292
# 	training_seconds_this_epoch: 2.86989879608
# 	valid_h0_col_norms_max: 8.76226139069
# 	valid_h0_col_norms_mean: 6.33053874969
# 	valid_h0_col_norms_min: 4.42016410828
# 	valid_h0_max_x_max_u: 4.3431353569
# 	valid_h0_max_x_mean_u: 1.31824624538
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.592075645924
# 	valid_h0_mean_x_mean_u: 0.0851351097226
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.3431353569
# 	valid_h0_range_x_mean_u: 1.31824624538
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.52259397507
# 	valid_h0_row_norms_mean: 3.88908529282
# 	valid_h0_row_norms_min: 1.30377578735
# 	valid_objective: 1.45645666122
# 	valid_y0_col_norms_max: 4.10065793991
# 	valid_y0_col_norms_mean: 3.038813591
# 	valid_y0_col_norms_min: 2.25263500214
# 	valid_y0_max_max_class: 0.949333369732
# 	valid_y0_mean_max_class: 0.555052518845
# 	valid_y0_min_max_class: 0.122133940458
# 	valid_y0_misclass: 0.266099900007
# 	valid_y0_nll: 1.00089287758
# 	valid_y0_row_norms_max: 1.98254823685
# 	valid_y0_row_norms_mean: 1.17975568771
# 	valid_y0_row_norms_min: 0.522017419338
# Time this epoch: 3.081165 seconds
# Monitoring step:
# 	Epochs seen: 19
# 	Batches seen: 13300
# 	Examples seen: 1330000
# 	learning_rate: 0.100000023842
# 	momentum: 0.679999709129
# 	total_seconds_last_epoch: 4.02906084061
# 	training_seconds_this_epoch: 3.08116221428
# 	valid_h0_col_norms_max: 8.76230716705
# 	valid_h0_col_norms_mean: 6.33658218384
# 	valid_h0_col_norms_min: 4.42905950546
# 	valid_h0_max_x_max_u: 4.47477912903
# 	valid_h0_max_x_mean_u: 1.32386887074
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.561336159706
# 	valid_h0_mean_x_mean_u: 0.0844489634037
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.47477912903
# 	valid_h0_range_x_mean_u: 1.32386887074
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.52259397507
# 	valid_h0_row_norms_mean: 3.89284610748
# 	valid_h0_row_norms_min: 1.30482935905
# 	valid_objective: 1.45320999622
# 	valid_y0_col_norms_max: 4.19294166565
# 	valid_y0_col_norms_mean: 3.09655642509
# 	valid_y0_col_norms_min: 2.35025811195
# 	valid_y0_max_max_class: 0.948710501194
# 	valid_y0_mean_max_class: 0.555235862732
# 	valid_y0_min_max_class: 0.123099274933
# 	valid_y0_misclass: 0.24359998107
# 	valid_y0_nll: 0.966258764267
# 	valid_y0_row_norms_max: 2.00969219208
# 	valid_y0_row_norms_mean: 1.20178353786
# 	valid_y0_row_norms_min: 0.498577356339
# Time this epoch: 2.867279 seconds
# Monitoring step:
# 	Epochs seen: 20
# 	Batches seen: 14000
# 	Examples seen: 1400000
# 	learning_rate: 0.100000023842
# 	momentum: 0.690000712872
# 	total_seconds_last_epoch: 4.46734857559
# 	training_seconds_this_epoch: 2.8672773838
# 	valid_h0_col_norms_max: 8.75997638702
# 	valid_h0_col_norms_mean: 6.34239912033
# 	valid_h0_col_norms_min: 4.4354929924
# 	valid_h0_max_x_max_u: 4.38190937042
# 	valid_h0_max_x_mean_u: 1.31575059891
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.567654669285
# 	valid_h0_mean_x_mean_u: 0.0818916335702
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.38190937042
# 	valid_h0_range_x_mean_u: 1.31575059891
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.52259397507
# 	valid_h0_row_norms_mean: 3.89657497406
# 	valid_h0_row_norms_min: 1.30522704124
# 	valid_objective: 1.45567727089
# 	valid_y0_col_norms_max: 4.23290920258
# 	valid_y0_col_norms_mean: 3.14977741241
# 	valid_y0_col_norms_min: 2.37298822403
# 	valid_y0_max_max_class: 0.956442773342
# 	valid_y0_mean_max_class: 0.553217172623
# 	valid_y0_min_max_class: 0.125803291798
# 	valid_y0_misclass: 0.257099986076
# 	valid_y0_nll: 0.990607023239
# 	valid_y0_row_norms_max: 2.03969502449
# 	valid_y0_row_norms_mean: 1.2235686779
# 	valid_y0_row_norms_min: 0.557263731956
# Saving to rect.pkl...
# Saving to rect.pkl done. Time elapsed: 0.399295 seconds
# Time this epoch: 3.463654 seconds
# Monitoring step:
# 	Epochs seen: 21
# 	Batches seen: 14700
# 	Examples seen: 1470000
# 	learning_rate: 0.100000023842
# 	momentum: 0.699999094009
# 	total_seconds_last_epoch: 3.99601483345
# 	training_seconds_this_epoch: 3.46365118027
# 	valid_h0_col_norms_max: 8.76354694366
# 	valid_h0_col_norms_mean: 6.3485660553
# 	valid_h0_col_norms_min: 4.43477630615
# 	valid_h0_max_x_max_u: 4.31461620331
# 	valid_h0_max_x_mean_u: 1.31377923489
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.525015950203
# 	valid_h0_mean_x_mean_u: 0.08000870049
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.31461620331
# 	valid_h0_range_x_mean_u: 1.31377923489
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.5224313736
# 	valid_h0_row_norms_mean: 3.90045166016
# 	valid_h0_row_norms_min: 1.30719316006
# 	valid_objective: 1.45847094059
# 	valid_y0_col_norms_max: 4.31926965714
# 	valid_y0_col_norms_mean: 3.19986915588
# 	valid_y0_col_norms_min: 2.42781662941
# 	valid_y0_max_max_class: 0.953257799149
# 	valid_y0_mean_max_class: 0.560561358929
# 	valid_y0_min_max_class: 0.125170528889
# 	valid_y0_misclass: 0.256399959326
# 	valid_y0_nll: 0.9837038517
# 	valid_y0_row_norms_max: 2.07737612724
# 	valid_y0_row_norms_mean: 1.24304747581
# 	valid_y0_row_norms_min: 0.569546401501
# Time this epoch: 3.177806 seconds
# Monitoring step:
# 	Epochs seen: 22
# 	Batches seen: 15400
# 	Examples seen: 1540000
# 	learning_rate: 0.100000023842
# 	momentum: 0.709999144077
# 	total_seconds_last_epoch: 4.38201189041
# 	training_seconds_this_epoch: 3.17780804634
# 	valid_h0_col_norms_max: 8.76663970947
# 	valid_h0_col_norms_mean: 6.35517644882
# 	valid_h0_col_norms_min: 4.44092321396
# 	valid_h0_max_x_max_u: 4.35003948212
# 	valid_h0_max_x_mean_u: 1.30003285408
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.52004545927
# 	valid_h0_mean_x_mean_u: 0.0778322741389
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.35003948212
# 	valid_h0_range_x_mean_u: 1.30003285408
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.52274990082
# 	valid_h0_row_norms_mean: 3.90460538864
# 	valid_h0_row_norms_min: 1.30760657787
# 	valid_objective: 1.44283545017
# 	valid_y0_col_norms_max: 4.35574388504
# 	valid_y0_col_norms_mean: 3.24776339531
# 	valid_y0_col_norms_min: 2.40332317352
# 	valid_y0_max_max_class: 0.949914932251
# 	valid_y0_mean_max_class: 0.548210144043
# 	valid_y0_min_max_class: 0.124919511378
# 	valid_y0_misclass: 0.24430000782
# 	valid_y0_nll: 0.98221385479
# 	valid_y0_row_norms_max: 2.09428358078
# 	valid_y0_row_norms_mean: 1.26157534122
# 	valid_y0_row_norms_min: 0.552668690681
# Time this epoch: 3.231844 seconds
# Monitoring step:
# 	Epochs seen: 23
# 	Batches seen: 16100
# 	Examples seen: 1610000
# 	learning_rate: 0.100000023842
# 	momentum: 0.720000207424
# 	total_seconds_last_epoch: 3.90287041664
# 	training_seconds_this_epoch: 3.23184132576
# 	valid_h0_col_norms_max: 8.76669406891
# 	valid_h0_col_norms_mean: 6.36248493195
# 	valid_h0_col_norms_min: 4.44614124298
# 	valid_h0_max_x_max_u: 4.33219718933
# 	valid_h0_max_x_mean_u: 1.31003248692
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.51956063509
# 	valid_h0_mean_x_mean_u: 0.0791662484407
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.33219718933
# 	valid_h0_range_x_mean_u: 1.31003248692
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.52274990082
# 	valid_h0_row_norms_mean: 3.90911054611
# 	valid_h0_row_norms_min: 1.30925285816
# 	valid_objective: 1.42337179184
# 	valid_y0_col_norms_max: 4.42407846451
# 	valid_y0_col_norms_mean: 3.29616117477
# 	valid_y0_col_norms_min: 2.52364611626
# 	valid_y0_max_max_class: 0.970929384232
# 	valid_y0_mean_max_class: 0.572090685368
# 	valid_y0_min_max_class: 0.127370864153
# 	valid_y0_misclass: 0.252100050449
# 	valid_y0_nll: 0.957391321659
# 	valid_y0_row_norms_max: 2.15113401413
# 	valid_y0_row_norms_mean: 1.28148674965
# 	valid_y0_row_norms_min: 0.583824872971
# Time this epoch: 2.792726 seconds
# Monitoring step:
# 	Epochs seen: 24
# 	Batches seen: 16800
# 	Examples seen: 1680000
# 	learning_rate: 0.100000023842
# 	momentum: 0.730000317097
# 	total_seconds_last_epoch: 3.93717861176
# 	training_seconds_this_epoch: 2.79272413254
# 	valid_h0_col_norms_max: 8.76693630219
# 	valid_h0_col_norms_mean: 6.37006378174
# 	valid_h0_col_norms_min: 4.44619846344
# 	valid_h0_max_x_max_u: 4.30939483643
# 	valid_h0_max_x_mean_u: 1.2961410284
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.518366992474
# 	valid_h0_mean_x_mean_u: 0.0761943086982
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.30939483643
# 	valid_h0_range_x_mean_u: 1.2961410284
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.5255279541
# 	valid_h0_row_norms_mean: 3.9136838913
# 	valid_h0_row_norms_min: 1.30928719044
# 	valid_objective: 1.42387282848
# 	valid_y0_col_norms_max: 4.42450714111
# 	valid_y0_col_norms_mean: 3.34071564674
# 	valid_y0_col_norms_min: 2.5368475914
# 	valid_y0_max_max_class: 0.956787228584
# 	valid_y0_mean_max_class: 0.560404121876
# 	valid_y0_min_max_class: 0.122392423451
# 	valid_y0_misclass: 0.248899996281
# 	valid_y0_nll: 0.973572313786
# 	valid_y0_row_norms_max: 2.20142269135
# 	valid_y0_row_norms_mean: 1.2990193367
# 	valid_y0_row_norms_min: 0.615826964378
# Time this epoch: 2.776100 seconds
# Monitoring step:
# 	Epochs seen: 25
# 	Batches seen: 17500
# 	Examples seen: 1750000
# 	learning_rate: 0.100000023842
# 	momentum: 0.7399995327
# 	total_seconds_last_epoch: 3.48535299301
# 	training_seconds_this_epoch: 2.77609848976
# 	valid_h0_col_norms_max: 8.76522350311
# 	valid_h0_col_norms_mean: 6.37912654877
# 	valid_h0_col_norms_min: 4.46154308319
# 	valid_h0_max_x_max_u: 4.34127855301
# 	valid_h0_max_x_mean_u: 1.32116794586
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.537149846554
# 	valid_h0_mean_x_mean_u: 0.0771360620856
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.34127855301
# 	valid_h0_range_x_mean_u: 1.32116794586
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.5255279541
# 	valid_h0_row_norms_mean: 3.91914963722
# 	valid_h0_row_norms_min: 1.31078851223
# 	valid_objective: 1.42000246048
# 	valid_y0_col_norms_max: 4.4972910881
# 	valid_y0_col_norms_mean: 3.39481878281
# 	valid_y0_col_norms_min: 2.59157752991
# 	valid_y0_max_max_class: 0.963754892349
# 	valid_y0_mean_max_class: 0.571450352669
# 	valid_y0_min_max_class: 0.127890184522
# 	valid_y0_misclass: 0.251100003719
# 	valid_y0_nll: 0.958552181721
# 	valid_y0_row_norms_max: 2.20536184311
# 	valid_y0_row_norms_mean: 1.32065916061
# 	valid_y0_row_norms_min: 0.627885341644
# Saving to rect.pkl...
# Saving to rect.pkl done. Time elapsed: 0.422525 seconds
# Time this epoch: 2.962707 seconds
# Monitoring step:
# 	Epochs seen: 26
# 	Batches seen: 18200
# 	Examples seen: 1820000
# 	learning_rate: 0.100000023842
# 	momentum: 0.749999403954
# 	total_seconds_last_epoch: 3.89596843719
# 	training_seconds_this_epoch: 2.96270823479
# 	valid_h0_col_norms_max: 8.76736164093
# 	valid_h0_col_norms_mean: 6.38828372955
# 	valid_h0_col_norms_min: 4.47421121597
# 	valid_h0_max_x_max_u: 4.24360895157
# 	valid_h0_max_x_mean_u: 1.32331597805
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.529843091965
# 	valid_h0_mean_x_mean_u: 0.0771675482392
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.24360895157
# 	valid_h0_range_x_mean_u: 1.32331597805
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.52934217453
# 	valid_h0_row_norms_mean: 3.92467927933
# 	valid_h0_row_norms_min: 1.31254220009
# 	valid_objective: 1.43512833118
# 	valid_y0_col_norms_max: 4.55975627899
# 	valid_y0_col_norms_mean: 3.44026064873
# 	valid_y0_col_norms_min: 2.64793133736
# 	valid_y0_max_max_class: 0.96662157774
# 	valid_y0_mean_max_class: 0.582286655903
# 	valid_y0_min_max_class: 0.136356398463
# 	valid_y0_misclass: 0.253699988127
# 	valid_y0_nll: 0.944827973843
# 	valid_y0_row_norms_max: 2.22241616249
# 	valid_y0_row_norms_mean: 1.3383898735
# 	valid_y0_row_norms_min: 0.618070423603
# Time this epoch: 2.747402 seconds
# Monitoring step:
# 	Epochs seen: 27
# 	Batches seen: 18900
# 	Examples seen: 1890000
# 	learning_rate: 0.100000023842
# 	momentum: 0.760000526905
# 	total_seconds_last_epoch: 3.68790459633
# 	training_seconds_this_epoch: 2.74740076065
# 	valid_h0_col_norms_max: 8.77148151398
# 	valid_h0_col_norms_mean: 6.39749717712
# 	valid_h0_col_norms_min: 4.49399423599
# 	valid_h0_max_x_max_u: 4.25134325027
# 	valid_h0_max_x_mean_u: 1.30173480511
# 	valid_h0_max_x_min_u: 0.0
# 	valid_h0_mean_x_max_u: 0.496227532625
# 	valid_h0_mean_x_mean_u: 0.0732041373849
# 	valid_h0_mean_x_min_u: 0.0
# 	valid_h0_min_x_max_u: 0.0
# 	valid_h0_min_x_mean_u: 0.0
# 	valid_h0_min_x_min_u: 0.0
# 	valid_h0_range_x_max_u: 4.25134325027
# 	valid_h0_range_x_mean_u: 1.30173480511
# 	valid_h0_range_x_min_u: 0.0
# 	valid_h0_row_norms_max: 6.52934265137
# 	valid_h0_row_norms_mean: 3.93018770218
# 	valid_h0_row_norms_min: 1.31443834305
# 	valid_objective: 1.42965459824
# 	valid_y0_col_norms_max: 4.5757818222
# 	valid_y0_col_norms_mean: 3.47835850716
# 	valid_y0_col_norms_min: 2.6680624485
# 	valid_y0_max_max_class: 0.962530076504
# 	valid_y0_mean_max_class: 0.555216372013
# 	valid_y0_min_max_class: 0.12590457499
# 	valid_y0_misclass: 0.249799996614
# 	valid_y0_nll: 0.971761405468
# 	valid_y0_row_norms_max: 2.2137401104
# 	valid_y0_row_norms_mean: 1.3540699482
# 	valid_y0_row_norms_min: 0.666570603848
# Saving to rect.pkl...
# Saving to rect.pkl done. Time elapsed: 0.452699 seconds

# %%
# Calculate accuracy on test set

model = serial.load("rect_best.pkl")

inputs = test.X.astype("float32")
yhat = model.fprop(theano.shared(inputs,name='inputs')).eval()

count = 0.
for i in range(test.X.shape[0]):
    if np.argmax(test.y[i])==np.argmax(yhat[i]):
        count += 1.

print "accuracy = ", count / test.X.shape[0]
# Out:
# accuracy =  0.7584

# %% [markdown]
# ## Stacked Denoising Autoencoders

# %%
from pylearn2.models import autoencoder
from pylearn2.corruption import BinomialCorruptor
from pylearn2.costs.autoencoder import MeanSquaredReconstructionError
from pylearn2.datasets.transformer_dataset import TransformerDataset

# %%
train = csv_dataset.CSVDataset("sd19n.csv",one_hot=True,expect_labels=True,expect_headers=False,delimiter=',',end_fraction=0.7)
valid = csv_dataset.CSVDataset("valid.csv",one_hot=True,expect_labels=True,expect_headers=False,delimiter=',')
test = csv_dataset.CSVDataset("test.csv",one_hot=True,expect_labels=True,expect_headers=False,delimiter=',')

# %%
#layer 1

corruptor = BinomialCorruptor(corruption_level=0.2)
model = autoencoder.DenoisingAutoencoder(nvis=1024,nhid=500,irange=0.05,corruptor=corruptor,act_enc="tanh",act_dec=None)
algorithm = sgd.SGD(learning_rate=0.001, batch_size=100, monitoring_batches=5, cost=MeanSquaredReconstructionError(),
                    monitoring_dataset=train, termination_criterion=EpochCounter(10))

print 'Running training'
train_job = Train(train, model, algorithm, save_path="dae_layer1.pkl", save_freq=1)
train_job.main_loop()
# Out:
# Running training
# Parameter and initial learning rate summary:
# 	vb: 0.0010000000475
# 	hb: 0.0010000000475
# 	W: 0.0010000000475
# 	Wprime: 0.0010000000475
# Compiling sgd_update...
# /Users/john/pylearn2/pylearn2/models/model.py:72: UserWarning: The <class 'pylearn2.models.autoencoder.DenoisingAutoencoder'> Model subclass seems not to call the Model constructor. This behavior may be considered an error on or after 2014-11-01.
#   warnings.warn("The " + str(type(self)) + " Model subclass "
# Compiling sgd_update done. Time elapsed: 52.529185 seconds
# compiling begin_record_entry...
# compiling begin_record_entry done. Time elapsed: 0.117066 seconds
# Monitored channels:
# 	learning_rate
# 	objective
# 	total_seconds_last_epoch
# 	training_seconds_this_epoch
# Compiling accum...
# graph size: 22
# Compiling accum done. Time elapsed: 5.363380 seconds
# Monitoring step:
# 	Epochs seen: 0
# 	Batches seen: 0
# 	Examples seen: 0
# 	learning_rate: 0.0010000000475
# 	objective: 38.3517990112
# 	total_seconds_last_epoch: 0.0
# 	training_seconds_this_epoch: 0.0
# Time this epoch: 3.297591 seconds
# Monitoring step:
# 	Epochs seen: 1
# 	Batches seen: 700
# 	Examples seen: 70000
# 	learning_rate: 0.0010000000475
# 	objective: 20.9675884247
# 	total_seconds_last_epoch: 0.0
# 	training_seconds_this_epoch: 3.29759097099
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.801223 seconds
# Time this epoch: 3.253834 seconds
# Monitoring step:
# 	Epochs seen: 2
# 	Batches seen: 1400
# 	Examples seen: 140000
# 	learning_rate: 0.0010000000475
# 	objective: 16.9225406647
# 	total_seconds_last_epoch: 5.00172376633
# 	training_seconds_this_epoch: 3.25383400917
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.848628 seconds
# Time this epoch: 3.236950 seconds
# Monitoring step:
# 	Epochs seen: 3
# 	Batches seen: 2100
# 	Examples seen: 210000
# 	learning_rate: 0.0010000000475
# 	objective: 14.5571203232
# 	total_seconds_last_epoch: 5.17662525177
# 	training_seconds_this_epoch: 3.23694968224
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.775544 seconds
# Time this epoch: 3.366617 seconds
# Monitoring step:
# 	Epochs seen: 4
# 	Batches seen: 2800
# 	Examples seen: 280000
# 	learning_rate: 0.0010000000475
# 	objective: 13.0654773712
# 	total_seconds_last_epoch: 5.01434278488
# 	training_seconds_this_epoch: 3.36661696434
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.694869 seconds
# Time this epoch: 3.572292 seconds
# Monitoring step:
# 	Epochs seen: 5
# 	Batches seen: 3500
# 	Examples seen: 350000
# 	learning_rate: 0.0010000000475
# 	objective: 12.033536911
# 	total_seconds_last_epoch: 4.96671628952
# 	training_seconds_this_epoch: 3.57229208946
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.669609 seconds
# Time this epoch: 3.403543 seconds
# Monitoring step:
# 	Epochs seen: 6
# 	Batches seen: 4200
# 	Examples seen: 420000
# 	learning_rate: 0.0010000000475
# 	objective: 11.2702293396
# 	total_seconds_last_epoch: 5.19006681442
# 	training_seconds_this_epoch: 3.40354251862
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.708928 seconds
# Time this epoch: 3.421799 seconds
# Monitoring step:
# 	Epochs seen: 7
# 	Batches seen: 4900
# 	Examples seen: 490000
# 	learning_rate: 0.0010000000475
# 	objective: 10.6825351715
# 	total_seconds_last_epoch: 5.08924484253
# 	training_seconds_this_epoch: 3.42179894447
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.691883 seconds
# Time this epoch: 3.463632 seconds
# Monitoring step:
# 	Epochs seen: 8
# 	Batches seen: 5600
# 	Examples seen: 560000
# 	learning_rate: 0.0010000000475
# 	objective: 10.197675705
# 	total_seconds_last_epoch: 5.07999658585
# 	training_seconds_this_epoch: 3.46363186836
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.632261 seconds
# Time this epoch: 3.380271 seconds
# Monitoring step:
# 	Epochs seen: 9
# 	Batches seen: 6300
# 	Examples seen: 630000
# 	learning_rate: 0.0010000000475
# 	objective: 9.79848384857
# 	total_seconds_last_epoch: 5.12134599686
# 	training_seconds_this_epoch: 3.38027095795
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.743680 seconds
# Time this epoch: 3.882638 seconds
# Monitoring step:
# 	Epochs seen: 10
# 	Batches seen: 7000
# 	Examples seen: 700000
# 	learning_rate: 0.0010000000475
# 	objective: 9.47059440613
# 	total_seconds_last_epoch: 5.13615512848
# 	training_seconds_this_epoch: 3.88263821602
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.600732 seconds
# Saving to dae_layer1.pkl...
# Saving to dae_layer1.pkl done. Time elapsed: 0.586189 seconds

# %%
# layer 2

transformer = serial.load("dae_layer1.pkl")
ntrain = TransformerDataset(raw=train,transformer=transformer)

corruptor = BinomialCorruptor(corruption_level=0.3)
model = autoencoder.DenoisingAutoencoder(nvis=500,nhid=500,irange=0.05,corruptor=corruptor,act_enc="tanh",act_dec=None)
algorithm = sgd.SGD(learning_rate=0.001, batch_size=100, monitoring_batches=5, cost=MeanSquaredReconstructionError(),
                    monitoring_dataset=ntrain, termination_criterion=EpochCounter(10))

print 'Running training'
train_job = Train(ntrain, model, algorithm, save_path="dae_layer2.pkl", save_freq=1)
train_job.main_loop()
# Out:
# Running training
# Parameter and initial learning rate summary:
# 	vb: 0.0010000000475
# 	hb: 0.0010000000475
# 	W: 0.0010000000475
# 	Wprime: 0.0010000000475
# Compiling sgd_update...
# Compiling sgd_update done. Time elapsed: 0.884479 seconds
# compiling begin_record_entry...
# compiling begin_record_entry done. Time elapsed: 0.109865 seconds
# Monitored channels:
# 	learning_rate
# 	objective
# 	total_seconds_last_epoch
# 	training_seconds_this_epoch
# Compiling accum...
# graph size: 22
# Compiling accum done. Time elapsed: 0.397232 seconds
# Monitoring step:
# 	Epochs seen: 0
# 	Batches seen: 0
# 	Examples seen: 0
# 	learning_rate: 0.0010000000475
# 	objective: 24.0187129974
# 	total_seconds_last_epoch: 0.0
# 	training_seconds_this_epoch: 0.0
# Time this epoch: 2.871617 seconds
# Monitoring step:
# 	Epochs seen: 1
# 	Batches seen: 700
# 	Examples seen: 70000
# 	learning_rate: 0.0010000000475
# 	objective: 12.6274681091
# 	total_seconds_last_epoch: 0.0
# 	training_seconds_this_epoch: 2.87161707878
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.515066 seconds
# Time this epoch: 3.102598 seconds
# Monitoring step:
# 	Epochs seen: 2
# 	Batches seen: 1400
# 	Examples seen: 140000
# 	learning_rate: 0.0010000000475
# 	objective: 9.01133346558
# 	total_seconds_last_epoch: 4.39458179474
# 	training_seconds_this_epoch: 3.10259795189
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.470989 seconds
# Time this epoch: 2.945205 seconds
# Monitoring step:
# 	Epochs seen: 3
# 	Batches seen: 2100
# 	Examples seen: 210000
# 	learning_rate: 0.0010000000475
# 	objective: 6.75594377518
# 	total_seconds_last_epoch: 4.61533117294
# 	training_seconds_this_epoch: 2.94520497322
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.561295 seconds
# Time this epoch: 3.059316 seconds
# Monitoring step:
# 	Epochs seen: 4
# 	Batches seen: 2800
# 	Examples seen: 280000
# 	learning_rate: 0.0010000000475
# 	objective: 5.43311023712
# 	total_seconds_last_epoch: 4.50153589249
# 	training_seconds_this_epoch: 3.05931568146
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.613078 seconds
# Time this epoch: 3.223125 seconds
# Monitoring step:
# 	Epochs seen: 5
# 	Batches seen: 3500
# 	Examples seen: 350000
# 	learning_rate: 0.0010000000475
# 	objective: 4.58937978745
# 	total_seconds_last_epoch: 4.7572889328
# 	training_seconds_this_epoch: 3.22312474251
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.572718 seconds
# Time this epoch: 3.140633 seconds
# Monitoring step:
# 	Epochs seen: 6
# 	Batches seen: 4200
# 	Examples seen: 420000
# 	learning_rate: 0.0010000000475
# 	objective: 4.01621627808
# 	total_seconds_last_epoch: 5.44179344177
# 	training_seconds_this_epoch: 3.14063310623
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.554122 seconds
# Time this epoch: 3.313762 seconds
# Monitoring step:
# 	Epochs seen: 7
# 	Batches seen: 4900
# 	Examples seen: 490000
# 	learning_rate: 0.0010000000475
# 	objective: 3.61193776131
# 	total_seconds_last_epoch: 4.95470285416
# 	training_seconds_this_epoch: 3.31376194954
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.381068 seconds
# Time this epoch: 3.002546 seconds
# Monitoring step:
# 	Epochs seen: 8
# 	Batches seen: 5600
# 	Examples seen: 560000
# 	learning_rate: 0.0010000000475
# 	objective: 3.31693673134
# 	total_seconds_last_epoch: 4.74469900131
# 	training_seconds_this_epoch: 3.00254607201
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.391446 seconds
# Time this epoch: 3.052124 seconds
# Monitoring step:
# 	Epochs seen: 9
# 	Batches seen: 6300
# 	Examples seen: 630000
# 	learning_rate: 0.0010000000475
# 	objective: 3.09158039093
# 	total_seconds_last_epoch: 4.38454151154
# 	training_seconds_this_epoch: 3.05212402344
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.532018 seconds
# Time this epoch: 3.462310 seconds
# Monitoring step:
# 	Epochs seen: 10
# 	Batches seen: 7000
# 	Examples seen: 700000
# 	learning_rate: 0.0010000000475
# 	objective: 2.91170930862
# 	total_seconds_last_epoch: 4.59041500092
# 	training_seconds_this_epoch: 3.46231007576
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.470122 seconds
# Saving to dae_layer2.pkl...
# Saving to dae_layer2.pkl done. Time elapsed: 0.340812 seconds

# %%
# stacking and supervised fine-tuning

dae1 = serial.load("dae_layer1.pkl")
dae2 = serial.load("dae_layer2.pkl")

h1 = mlp.PretrainedLayer(layer_name='h1',layer_content=dae1)
h2 = mlp.PretrainedLayer(layer_name='h2',layer_content=dae2)
y0 = mlp.Softmax(layer_name='y0', n_classes=62, irange=0.005,max_col_norm=1.9365)
layers = [h1, h2, y0]

monitoring = dict(valid=valid)
callback = sgd.ExponentialDecay(decay_factor=1.00004,min_lr=0.000001)
extensions = [best_params.MonitorBasedSaveBest(channel_name="valid_y0_misclass",save_path="dae_best.pkl"),
              learning_rule.MomentumAdjustor(final_momentum=0.7,start=1,saturate=250)]
model = mlp.MLP(layers, batch_size=100, nvis=1024)
algorithm = sgd.SGD(learning_rate=0.05, init_momentum=0.5, batch_size=100,update_callbacks=callback,
                    monitoring_dataset=monitoring, termination_criterion=EpochCounter(50))

print 'Running training'
train_job = Train(train, model, algorithm, extensions=extensions, save_path="dae.pkl", save_freq=1)
train_job.main_loop()
# Out:
# Running training
# Parameter and initial learning rate summary:
# 	vb: 0.0500000007451
# 	hb: 0.0500000007451
# 	W: 0.0500000007451
# 	Wprime: 0.0500000007451
# 	vb: 0.0500000007451
# 	hb: 0.0500000007451
# 	W: 0.0500000007451
# 	Wprime: 0.0500000007451
# 	softmax_b: 0.0500000007451
# 	softmax_W: 0.0500000007451
# Compiling sgd_update...
# Compiling sgd_update done. Time elapsed: 1.605232 seconds
# compiling begin_record_entry...
# compiling begin_record_entry done. Time elapsed: 0.151515 seconds
# Monitored channels:
# 	learning_rate
# 	momentum
# 	total_seconds_last_epoch
# 	training_seconds_this_epoch
# 	valid_objective
# 	valid_y0_col_norms_max
# 	valid_y0_col_norms_mean
# 	valid_y0_col_norms_min
# 	valid_y0_max_max_class
# 	valid_y0_mean_max_class
# 	valid_y0_min_max_class
# 	valid_y0_misclass
# 	valid_y0_nll
# 	valid_y0_row_norms_max
# 	valid_y0_row_norms_mean
# 	valid_y0_row_norms_min
# Compiling accum...
# graph size: 76
# Compiling accum done. Time elapsed: 1.155300 seconds
# Monitoring step:
# 	Epochs seen: 0
# 	Batches seen: 0
# 	Examples seen: 0
# 	learning_rate: 0.0500000119209
# 	momentum: 0.499999672174
# 	total_seconds_last_epoch: 0.0
# 	training_seconds_this_epoch: 0.0
# 	valid_objective: 4.12936687469
# 	valid_y0_col_norms_max: 0.0674590468407
# 	valid_y0_col_norms_mean: 0.0645186379552
# 	valid_y0_col_norms_min: 0.0615204907954
# 	valid_y0_max_max_class: 0.0169956516474
# 	valid_y0_mean_max_class: 0.0166439209133
# 	valid_y0_min_max_class: 0.0163832493126
# 	valid_y0_misclass: 0.993799090385
# 	valid_y0_nll: 4.12936687469
# 	valid_y0_row_norms_max: 0.0262514296919
# 	valid_y0_row_norms_mean: 0.0226897634566
# 	valid_y0_row_norms_min: 0.0181492436677
# Time this epoch: 4.987417 seconds
# Monitoring step:
# 	Epochs seen: 1
# 	Batches seen: 700
# 	Examples seen: 70000
# 	learning_rate: 0.0486194826663
# 	momentum: 0.499999672174
# 	total_seconds_last_epoch: 0.0
# 	training_seconds_this_epoch: 4.98741579056
# 	valid_objective: 1.46627390385
# 	valid_y0_col_norms_max: 1.37512671947
# 	valid_y0_col_norms_mean: 0.854553103447
# 	valid_y0_col_norms_min: 0.411555379629
# 	valid_y0_max_max_class: 0.956533670425
# 	valid_y0_mean_max_class: 0.529645800591
# 	valid_y0_min_max_class: 0.133787691593
# 	valid_y0_misclass: 0.374600142241
# 	valid_y0_nll: 1.46627390385
# 	valid_y0_row_norms_max: 0.551098763943
# 	valid_y0_row_norms_mean: 0.31417915225
# 	valid_y0_row_norms_min: 0.196643203497
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.988401 seconds
# Time this epoch: 3.857134 seconds
# Monitoring step:
# 	Epochs seen: 2
# 	Batches seen: 1400
# 	Examples seen: 140000
# 	learning_rate: 0.0472769476473
# 	momentum: 0.500803589821
# 	total_seconds_last_epoch: 7.78750228882
# 	training_seconds_this_epoch: 3.85713529587
# 	valid_objective: 1.22372436523
# 	valid_y0_col_norms_max: 1.70749425888
# 	valid_y0_col_norms_mean: 1.06494855881
# 	valid_y0_col_norms_min: 0.59210652113
# 	valid_y0_max_max_class: 0.975307106972
# 	valid_y0_mean_max_class: 0.605302929878
# 	valid_y0_min_max_class: 0.158176720142
# 	valid_y0_misclass: 0.325899988413
# 	valid_y0_nll: 1.22372436523
# 	valid_y0_row_norms_max: 0.756334841251
# 	valid_y0_row_norms_mean: 0.38383230567
# 	valid_y0_row_norms_min: 0.240427285433
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.439483 seconds
# Time this epoch: 4.062125 seconds
# Monitoring step:
# 	Epochs seen: 3
# 	Batches seen: 2100
# 	Examples seen: 210000
# 	learning_rate: 0.0459715984762
# 	momentum: 0.501606047153
# 	total_seconds_last_epoch: 6.90998935699
# 	training_seconds_this_epoch: 4.06212759018
# 	valid_objective: 1.06884813309
# 	valid_y0_col_norms_max: 1.93517184258
# 	valid_y0_col_norms_mean: 1.21231782436
# 	valid_y0_col_norms_min: 0.686240017414
# 	valid_y0_max_max_class: 0.987131178379
# 	valid_y0_mean_max_class: 0.64504724741
# 	valid_y0_min_max_class: 0.173776000738
# 	valid_y0_misclass: 0.289799898863
# 	valid_y0_nll: 1.06884813309
# 	valid_y0_row_norms_max: 0.963298976421
# 	valid_y0_row_norms_mean: 0.434541761875
# 	valid_y0_row_norms_min: 0.258871823549
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.358661 seconds
# Time this epoch: 4.487331 seconds
# Monitoring step:
# 	Epochs seen: 4
# 	Batches seen: 2800
# 	Examples seen: 280000
# 	learning_rate: 0.0447023399174
# 	momentum: 0.502409934998
# 	total_seconds_last_epoch: 6.80618238449
# 	training_seconds_this_epoch: 4.48732805252
# 	valid_objective: 0.946309506893
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.33639240265
# 	valid_y0_col_norms_min: 0.75558835268
# 	valid_y0_max_max_class: 0.99130320549
# 	valid_y0_mean_max_class: 0.675463497639
# 	valid_y0_min_max_class: 0.183885931969
# 	valid_y0_misclass: 0.257599979639
# 	valid_y0_nll: 0.946309506893
# 	valid_y0_row_norms_max: 1.05185472965
# 	valid_y0_row_norms_mean: 0.476685196161
# 	valid_y0_row_norms_min: 0.268658638
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.959492 seconds
# Time this epoch: 4.809639 seconds
# Monitoring step:
# 	Epochs seen: 5
# 	Batches seen: 3500
# 	Examples seen: 350000
# 	learning_rate: 0.0434680506587
# 	momentum: 0.50321239233
# 	total_seconds_last_epoch: 6.80503749847
# 	training_seconds_this_epoch: 4.8096370697
# 	valid_objective: 0.860990583897
# 	valid_y0_col_norms_max: 1.93649768829
# 	valid_y0_col_norms_mean: 1.43268024921
# 	valid_y0_col_norms_min: 0.814501702785
# 	valid_y0_max_max_class: 0.991542577744
# 	valid_y0_mean_max_class: 0.704705476761
# 	valid_y0_min_max_class: 0.198590457439
# 	valid_y0_misclass: 0.240299999714
# 	valid_y0_nll: 0.860990583897
# 	valid_y0_row_norms_max: 1.11304485798
# 	valid_y0_row_norms_mean: 0.508761227131
# 	valid_y0_row_norms_min: 0.281733185053
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.042804 seconds
# Time this epoch: 3.846178 seconds
# Monitoring step:
# 	Epochs seen: 6
# 	Batches seen: 4200
# 	Examples seen: 420000
# 	learning_rate: 0.0422678627074
# 	momentum: 0.504016280174
# 	total_seconds_last_epoch: 7.87082052231
# 	training_seconds_this_epoch: 3.84617424011
# 	valid_objective: 0.797453343868
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.50725841522
# 	valid_y0_col_norms_min: 0.89765226841
# 	valid_y0_max_max_class: 0.992700695992
# 	valid_y0_mean_max_class: 0.722498774529
# 	valid_y0_min_max_class: 0.203933253884
# 	valid_y0_misclass: 0.223099991679
# 	valid_y0_nll: 0.797453343868
# 	valid_y0_row_norms_max: 1.13924252987
# 	valid_y0_row_norms_mean: 0.533018410206
# 	valid_y0_row_norms_min: 0.296713083982
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.303569 seconds
# Time this epoch: 4.134495 seconds
# Monitoring step:
# 	Epochs seen: 7
# 	Batches seen: 4900
# 	Examples seen: 490000
# 	learning_rate: 0.0411007590592
# 	momentum: 0.504818737507
# 	total_seconds_last_epoch: 6.80241537094
# 	training_seconds_this_epoch: 4.13449335098
# 	valid_objective: 0.744081020355
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.55903983116
# 	valid_y0_col_norms_min: 0.997276246548
# 	valid_y0_max_max_class: 0.994234979153
# 	valid_y0_mean_max_class: 0.73496389389
# 	valid_y0_min_max_class: 0.204891562462
# 	valid_y0_misclass: 0.211699962616
# 	valid_y0_nll: 0.744081020355
# 	valid_y0_row_norms_max: 1.12817966938
# 	valid_y0_row_norms_mean: 0.54914611578
# 	valid_y0_row_norms_min: 0.30886733532
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.980349 seconds
# Time this epoch: 4.831221 seconds
# Monitoring step:
# 	Epochs seen: 8
# 	Batches seen: 5600
# 	Examples seen: 560000
# 	learning_rate: 0.0399659201503
# 	momentum: 0.505622982979
# 	total_seconds_last_epoch: 6.54683065414
# 	training_seconds_this_epoch: 4.83121919632
# 	valid_objective: 0.714020133018
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.59998762608
# 	valid_y0_col_norms_min: 1.05321931839
# 	valid_y0_max_max_class: 0.994335234165
# 	valid_y0_mean_max_class: 0.74171179533
# 	valid_y0_min_max_class: 0.216313049197
# 	valid_y0_misclass: 0.204899996519
# 	valid_y0_nll: 0.714020133018
# 	valid_y0_row_norms_max: 1.11924374104
# 	valid_y0_row_norms_mean: 0.561631262302
# 	valid_y0_row_norms_min: 0.307229220867
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.398912 seconds
# Time this epoch: 4.234554 seconds
# Monitoring step:
# 	Epochs seen: 9
# 	Batches seen: 6300
# 	Examples seen: 630000
# 	learning_rate: 0.038862451911
# 	momentum: 0.506425082684
# 	total_seconds_last_epoch: 8.46128559113
# 	training_seconds_this_epoch: 4.23455286026
# 	valid_objective: 0.678452134132
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.63500213623
# 	valid_y0_col_norms_min: 1.09215962887
# 	valid_y0_max_max_class: 0.994869172573
# 	valid_y0_mean_max_class: 0.74264061451
# 	valid_y0_min_max_class: 0.212234824896
# 	valid_y0_misclass: 0.195799976587
# 	valid_y0_nll: 0.678452134132
# 	valid_y0_row_norms_max: 1.09901869297
# 	valid_y0_row_norms_mean: 0.572464883327
# 	valid_y0_row_norms_min: 0.306614309549
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.977406 seconds
# Time this epoch: 4.824436 seconds
# Monitoring step:
# 	Epochs seen: 10
# 	Batches seen: 7000
# 	Examples seen: 700000
# 	learning_rate: 0.0377893745899
# 	momentum: 0.50722938776
# 	total_seconds_last_epoch: 6.6562538147
# 	training_seconds_this_epoch: 4.82444238663
# 	valid_objective: 0.65046864748
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.66596150398
# 	valid_y0_col_norms_min: 1.13995063305
# 	valid_y0_max_max_class: 0.995339512825
# 	valid_y0_mean_max_class: 0.757704675198
# 	valid_y0_min_max_class: 0.222576782107
# 	valid_y0_misclass: 0.186200037599
# 	valid_y0_nll: 0.65046864748
# 	valid_y0_row_norms_max: 1.08473312855
# 	valid_y0_row_norms_mean: 0.582083523273
# 	valid_y0_row_norms_min: 0.305932462215
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.925263 seconds
# Time this epoch: 4.031772 seconds
# Monitoring step:
# 	Epochs seen: 11
# 	Batches seen: 7700
# 	Examples seen: 770000
# 	learning_rate: 0.0367460101843
# 	momentum: 0.508031845093
# 	total_seconds_last_epoch: 7.51094579697
# 	training_seconds_this_epoch: 4.03177595139
# 	valid_objective: 0.624062299728
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.69449186325
# 	valid_y0_col_norms_min: 1.17800962925
# 	valid_y0_max_max_class: 0.994427263737
# 	valid_y0_mean_max_class: 0.758617758751
# 	valid_y0_min_max_class: 0.21334759891
# 	valid_y0_misclass: 0.178800016642
# 	valid_y0_nll: 0.624062299728
# 	valid_y0_row_norms_max: 1.07066178322
# 	valid_y0_row_norms_mean: 0.591009914875
# 	valid_y0_row_norms_min: 0.303054779768
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.183844 seconds
# Time this epoch: 4.778058 seconds
# Monitoring step:
# 	Epochs seen: 12
# 	Batches seen: 8400
# 	Examples seen: 840000
# 	learning_rate: 0.0357313714921
# 	momentum: 0.508835673332
# 	total_seconds_last_epoch: 6.76994609833
# 	training_seconds_this_epoch: 4.77805519104
# 	valid_objective: 0.606581747532
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.71673035622
# 	valid_y0_col_norms_min: 1.21424174309
# 	valid_y0_max_max_class: 0.995777130127
# 	valid_y0_mean_max_class: 0.771272480488
# 	valid_y0_min_max_class: 0.225591897964
# 	valid_y0_misclass: 0.175400003791
# 	valid_y0_nll: 0.606581747532
# 	valid_y0_row_norms_max: 1.04894196987
# 	valid_y0_row_norms_mean: 0.598025500774
# 	valid_y0_row_norms_min: 0.303578406572
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.034675 seconds
# Time this epoch: 5.057337 seconds
# Monitoring step:
# 	Epochs seen: 13
# 	Batches seen: 9100
# 	Examples seen: 910000
# 	learning_rate: 0.0347448214889
# 	momentum: 0.509638190269
# 	total_seconds_last_epoch: 7.95393896103
# 	training_seconds_this_epoch: 5.05733537674
# 	valid_objective: 0.586676299572
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.73611712456
# 	valid_y0_col_norms_min: 1.25493276119
# 	valid_y0_max_max_class: 0.995499670506
# 	valid_y0_mean_max_class: 0.77028888464
# 	valid_y0_min_max_class: 0.230051085353
# 	valid_y0_misclass: 0.169100016356
# 	valid_y0_nll: 0.586676299572
# 	valid_y0_row_norms_max: 1.04496335983
# 	valid_y0_row_norms_mean: 0.604001760483
# 	valid_y0_row_norms_min: 0.302188634872
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.024808 seconds
# Time this epoch: 4.433830 seconds
# Monitoring step:
# 	Epochs seen: 14
# 	Batches seen: 9800
# 	Examples seen: 980000
# 	learning_rate: 0.0337854400277
# 	momentum: 0.510442078114
# 	total_seconds_last_epoch: 8.14126682281
# 	training_seconds_this_epoch: 4.43382692337
# 	valid_objective: 0.566314280033
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.75229287148
# 	valid_y0_col_norms_min: 1.29876255989
# 	valid_y0_max_max_class: 0.996434807777
# 	valid_y0_mean_max_class: 0.775912165642
# 	valid_y0_min_max_class: 0.235409349203
# 	valid_y0_misclass: 0.163500010967
# 	valid_y0_nll: 0.566314280033
# 	valid_y0_row_norms_max: 1.04567563534
# 	valid_y0_row_norms_mean: 0.609073698521
# 	valid_y0_row_norms_min: 0.303924381733
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.344393 seconds
# Time this epoch: 4.799626 seconds
# Monitoring step:
# 	Epochs seen: 15
# 	Batches seen: 10500
# 	Examples seen: 1050000
# 	learning_rate: 0.0328525938094
# 	momentum: 0.511244595051
# 	total_seconds_last_epoch: 8.15444374084
# 	training_seconds_this_epoch: 4.79962396622
# 	valid_objective: 0.549584686756
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.76798033714
# 	valid_y0_col_norms_min: 1.33382439613
# 	valid_y0_max_max_class: 0.996056437492
# 	valid_y0_mean_max_class: 0.77960807085
# 	valid_y0_min_max_class: 0.23240198195
# 	valid_y0_misclass: 0.158099994063
# 	valid_y0_nll: 0.549584686756
# 	valid_y0_row_norms_max: 1.04210817814
# 	valid_y0_row_norms_mean: 0.614056706429
# 	valid_y0_row_norms_min: 0.304603338242
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.420491 seconds
# Time this epoch: 5.182276 seconds
# Monitoring step:
# 	Epochs seen: 16
# 	Batches seen: 11200
# 	Examples seen: 1120000
# 	learning_rate: 0.0319454930723
# 	momentum: 0.512048363686
# 	total_seconds_last_epoch: 8.02799415588
# 	training_seconds_this_epoch: 5.18227052689
# 	valid_objective: 0.538008093834
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.78309953213
# 	valid_y0_col_norms_min: 1.35914850235
# 	valid_y0_max_max_class: 0.995932936668
# 	valid_y0_mean_max_class: 0.781318485737
# 	valid_y0_min_max_class: 0.230264499784
# 	valid_y0_misclass: 0.155900061131
# 	valid_y0_nll: 0.538008093834
# 	valid_y0_row_norms_max: 1.0385928154
# 	valid_y0_row_norms_mean: 0.619025886059
# 	valid_y0_row_norms_min: 0.305790632963
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.087669 seconds
# Time this epoch: 5.337175 seconds
# Monitoring step:
# 	Epochs seen: 17
# 	Batches seen: 11900
# 	Examples seen: 1190000
# 	learning_rate: 0.031063484028
# 	momentum: 0.512850999832
# 	total_seconds_last_epoch: 7.98173189163
# 	training_seconds_this_epoch: 5.33717632294
# 	valid_objective: 0.523806631565
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.79736602306
# 	valid_y0_col_norms_min: 1.39950859547
# 	valid_y0_max_max_class: 0.99607694149
# 	valid_y0_mean_max_class: 0.779969871044
# 	valid_y0_min_max_class: 0.236252516508
# 	valid_y0_misclass: 0.153099998832
# 	valid_y0_nll: 0.523806631565
# 	valid_y0_row_norms_max: 1.03490233421
# 	valid_y0_row_norms_mean: 0.62365758419
# 	valid_y0_row_norms_min: 0.307238340378
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.321626 seconds
# Time this epoch: 3.779681 seconds
# Monitoring step:
# 	Epochs seen: 18
# 	Batches seen: 12600
# 	Examples seen: 1260000
# 	learning_rate: 0.030205771327
# 	momentum: 0.513654768467
# 	total_seconds_last_epoch: 8.64921092987
# 	training_seconds_this_epoch: 3.77967834473
# 	valid_objective: 0.514679014683
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.80930769444
# 	valid_y0_col_norms_min: 1.4328161478
# 	valid_y0_max_max_class: 0.997236013412
# 	valid_y0_mean_max_class: 0.792621076107
# 	valid_y0_min_max_class: 0.2408721596
# 	valid_y0_misclass: 0.151400029659
# 	valid_y0_nll: 0.514679014683
# 	valid_y0_row_norms_max: 1.02647686005
# 	valid_y0_row_norms_mean: 0.627607285976
# 	valid_y0_row_norms_min: 0.308338046074
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.016216 seconds
# Time this epoch: 4.530988 seconds
# Monitoring step:
# 	Epochs seen: 19
# 	Batches seen: 13300
# 	Examples seen: 1330000
# 	learning_rate: 0.0293717253953
# 	momentum: 0.514457404613
# 	total_seconds_last_epoch: 6.60218095779
# 	training_seconds_this_epoch: 4.53098583221
# 	valid_objective: 0.499715268612
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.82107996941
# 	valid_y0_col_norms_min: 1.46117115021
# 	valid_y0_max_max_class: 0.996610224247
# 	valid_y0_mean_max_class: 0.789831995964
# 	valid_y0_min_max_class: 0.240357041359
# 	valid_y0_misclass: 0.144300013781
# 	valid_y0_nll: 0.499715268612
# 	valid_y0_row_norms_max: 1.02065074444
# 	valid_y0_row_norms_mean: 0.631497383118
# 	valid_y0_row_norms_min: 0.31106197834
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.037415 seconds
# Time this epoch: 3.784088 seconds
# Monitoring step:
# 	Epochs seen: 20
# 	Batches seen: 14000
# 	Examples seen: 1400000
# 	learning_rate: 0.0285607334226
# 	momentum: 0.515261173248
# 	total_seconds_last_epoch: 7.18594932556
# 	training_seconds_this_epoch: 3.78408551216
# 	valid_objective: 0.491794764996
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.8326189518
# 	valid_y0_col_norms_min: 1.48899877071
# 	valid_y0_max_max_class: 0.99689334631
# 	valid_y0_mean_max_class: 0.792209088802
# 	valid_y0_min_max_class: 0.242873579264
# 	valid_y0_misclass: 0.143300011754
# 	valid_y0_nll: 0.491794764996
# 	valid_y0_row_norms_max: 1.02059268951
# 	valid_y0_row_norms_mean: 0.635439038277
# 	valid_y0_row_norms_min: 0.314955085516
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.907672 seconds
# Time this epoch: 4.412562 seconds
# Monitoring step:
# 	Epochs seen: 21
# 	Batches seen: 14700
# 	Examples seen: 1470000
# 	learning_rate: 0.027772186324
# 	momentum: 0.516063690186
# 	total_seconds_last_epoch: 7.45668077469
# 	training_seconds_this_epoch: 4.41255712509
# 	valid_objective: 0.484278529882
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.84222209454
# 	valid_y0_col_norms_min: 1.50572884083
# 	valid_y0_max_max_class: 0.996895849705
# 	valid_y0_mean_max_class: 0.797494411469
# 	valid_y0_min_max_class: 0.244755282998
# 	valid_y0_misclass: 0.141600012779
# 	valid_y0_nll: 0.484278529882
# 	valid_y0_row_norms_max: 1.02522921562
# 	valid_y0_row_norms_mean: 0.638716816902
# 	valid_y0_row_norms_min: 0.317620307207
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.980077 seconds
# Time this epoch: 4.293040 seconds
# Monitoring step:
# 	Epochs seen: 22
# 	Batches seen: 15400
# 	Examples seen: 1540000
# 	learning_rate: 0.0270053707063
# 	momentum: 0.51686757803
# 	total_seconds_last_epoch: 6.97550821304
# 	training_seconds_this_epoch: 4.29303836823
# 	valid_objective: 0.477144688368
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.85138070583
# 	valid_y0_col_norms_min: 1.53848004341
# 	valid_y0_max_max_class: 0.997053980827
# 	valid_y0_mean_max_class: 0.796344101429
# 	valid_y0_min_max_class: 0.243621200323
# 	valid_y0_misclass: 0.137900054455
# 	valid_y0_nll: 0.477144688368
# 	valid_y0_row_norms_max: 1.02632057667
# 	valid_y0_row_norms_mean: 0.641804754734
# 	valid_y0_row_norms_min: 0.318390160799
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.013099 seconds
# Time this epoch: 4.392473 seconds
# Monitoring step:
# 	Epochs seen: 23
# 	Batches seen: 16100
# 	Examples seen: 1610000
# 	learning_rate: 0.0262597426772
# 	momentum: 0.517670154572
# 	total_seconds_last_epoch: 7.30352735519
# 	training_seconds_this_epoch: 4.39247655869
# 	valid_objective: 0.466259300709
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.85893464088
# 	valid_y0_col_norms_min: 1.57187819481
# 	valid_y0_max_max_class: 0.997536420822
# 	valid_y0_mean_max_class: 0.797747433186
# 	valid_y0_min_max_class: 0.249894201756
# 	valid_y0_misclass: 0.136599987745
# 	valid_y0_nll: 0.466259300709
# 	valid_y0_row_norms_max: 1.02596831322
# 	valid_y0_row_norms_mean: 0.644393563271
# 	valid_y0_row_norms_min: 0.321406424046
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.016479 seconds
# Time this epoch: 3.849643 seconds
# Monitoring step:
# 	Epochs seen: 24
# 	Batches seen: 16800
# 	Examples seen: 1680000
# 	learning_rate: 0.0255346335471
# 	momentum: 0.518473863602
# 	total_seconds_last_epoch: 7.20611619949
# 	training_seconds_this_epoch: 3.84964466095
# 	valid_objective: 0.461943000555
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.86673390865
# 	valid_y0_col_norms_min: 1.59298193455
# 	valid_y0_max_max_class: 0.997242033482
# 	valid_y0_mean_max_class: 0.803796589375
# 	valid_y0_min_max_class: 0.253745019436
# 	valid_y0_misclass: 0.135299995542
# 	valid_y0_nll: 0.461943000555
# 	valid_y0_row_norms_max: 1.02922773361
# 	valid_y0_row_norms_mean: 0.647096097469
# 	valid_y0_row_norms_min: 0.324300229549
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.269399 seconds
# Time this epoch: 4.171618 seconds
# Monitoring step:
# 	Epochs seen: 25
# 	Batches seen: 17500
# 	Examples seen: 1750000
# 	learning_rate: 0.0248296167701
# 	momentum: 0.519276380539
# 	total_seconds_last_epoch: 6.60018634796
# 	training_seconds_this_epoch: 4.17161464691
# 	valid_objective: 0.456559628248
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.87381196022
# 	valid_y0_col_norms_min: 1.61460709572
# 	valid_y0_max_max_class: 0.997429430485
# 	valid_y0_mean_max_class: 0.801659345627
# 	valid_y0_min_max_class: 0.248511582613
# 	valid_y0_misclass: 0.133200004697
# 	valid_y0_nll: 0.456559628248
# 	valid_y0_row_norms_max: 1.03016448021
# 	valid_y0_row_norms_mean: 0.649559438229
# 	valid_y0_row_norms_min: 0.327842354774
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.196855 seconds
# Time this epoch: 4.782805 seconds
# Monitoring step:
# 	Epochs seen: 26
# 	Batches seen: 18200
# 	Examples seen: 1820000
# 	learning_rate: 0.0241440273821
# 	momentum: 0.520080327988
# 	total_seconds_last_epoch: 6.82703447342
# 	training_seconds_this_epoch: 4.7828040123
# 	valid_objective: 0.448471039534
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.88073003292
# 	valid_y0_col_norms_min: 1.64391636848
# 	valid_y0_max_max_class: 0.99761736393
# 	valid_y0_mean_max_class: 0.808081328869
# 	valid_y0_min_max_class: 0.257062464952
# 	valid_y0_misclass: 0.131400004029
# 	valid_y0_nll: 0.448471039534
# 	valid_y0_row_norms_max: 1.03135144711
# 	valid_y0_row_norms_mean: 0.651975631714
# 	valid_y0_row_norms_min: 0.329157978296
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.130294 seconds
# Time this epoch: 4.132608 seconds
# Monitoring step:
# 	Epochs seen: 27
# 	Batches seen: 18900
# 	Examples seen: 1890000
# 	learning_rate: 0.0234773866832
# 	momentum: 0.520884275436
# 	total_seconds_last_epoch: 7.9738612175
# 	training_seconds_this_epoch: 4.13260507584
# 	valid_objective: 0.443241149187
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.88757264614
# 	valid_y0_col_norms_min: 1.66792786121
# 	valid_y0_max_max_class: 0.997573971748
# 	valid_y0_mean_max_class: 0.807507753372
# 	valid_y0_min_max_class: 0.255841672421
# 	valid_y0_misclass: 0.130199998617
# 	valid_y0_nll: 0.443241149187
# 	valid_y0_row_norms_max: 1.03366494179
# 	valid_y0_row_norms_mean: 0.654385209084
# 	valid_y0_row_norms_min: 0.332349479198
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.936677 seconds
# Time this epoch: 4.969518 seconds
# Monitoring step:
# 	Epochs seen: 28
# 	Batches seen: 19600
# 	Examples seen: 1960000
# 	learning_rate: 0.0228291433305
# 	momentum: 0.521686553955
# 	total_seconds_last_epoch: 6.74320650101
# 	training_seconds_this_epoch: 4.96951675415
# 	valid_objective: 0.442168295383
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.89407813549
# 	valid_y0_col_norms_min: 1.69406020641
# 	valid_y0_max_max_class: 0.997609317303
# 	valid_y0_mean_max_class: 0.807182013988
# 	valid_y0_min_max_class: 0.251096427441
# 	valid_y0_misclass: 0.126099988818
# 	valid_y0_nll: 0.442168295383
# 	valid_y0_row_norms_max: 1.03748416901
# 	valid_y0_row_norms_mean: 0.656690061092
# 	valid_y0_row_norms_min: 0.335862189531
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.316263 seconds
# Time this epoch: 4.392032 seconds
# Monitoring step:
# 	Epochs seen: 29
# 	Batches seen: 20300
# 	Examples seen: 2030000
# 	learning_rate: 0.0221988204867
# 	momentum: 0.522490501404
# 	total_seconds_last_epoch: 8.05001354218
# 	training_seconds_this_epoch: 4.39203119278
# 	valid_objective: 0.431628167629
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.90025818348
# 	valid_y0_col_norms_min: 1.71306455135
# 	valid_y0_max_max_class: 0.997356534004
# 	valid_y0_mean_max_class: 0.807047843933
# 	valid_y0_min_max_class: 0.260507404804
# 	valid_y0_misclass: 0.125
# 	valid_y0_nll: 0.431628167629
# 	valid_y0_row_norms_max: 1.04404652119
# 	valid_y0_row_norms_mean: 0.658895790577
# 	valid_y0_row_norms_min: 0.338636755943
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.937109 seconds
# Time this epoch: 4.211205 seconds
# Monitoring step:
# 	Epochs seen: 30
# 	Batches seen: 21000
# 	Examples seen: 2100000
# 	learning_rate: 0.0215858761221
# 	momentum: 0.523293077946
# 	total_seconds_last_epoch: 6.84215021133
# 	training_seconds_this_epoch: 4.21120548248
# 	valid_objective: 0.433415681124
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.9050232172
# 	valid_y0_col_norms_min: 1.73008179665
# 	valid_y0_max_max_class: 0.997326731682
# 	valid_y0_mean_max_class: 0.814645648003
# 	valid_y0_min_max_class: 0.262727409601
# 	valid_y0_misclass: 0.129100009799
# 	valid_y0_nll: 0.433415681124
# 	valid_y0_row_norms_max: 1.04725790024
# 	valid_y0_row_norms_mean: 0.660646140575
# 	valid_y0_row_norms_min: 0.341887325048
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.123855 seconds
# Time this epoch: 4.673009 seconds
# Monitoring step:
# 	Epochs seen: 31
# 	Batches seen: 21700
# 	Examples seen: 2170000
# 	learning_rate: 0.0209898948669
# 	momentum: 0.52409696579
# 	total_seconds_last_epoch: 5.82102441788
# 	training_seconds_this_epoch: 4.6730055809
# 	valid_objective: 0.423343807459
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.90946757793
# 	valid_y0_col_norms_min: 1.76327502728
# 	valid_y0_max_max_class: 0.997447907925
# 	valid_y0_mean_max_class: 0.812365412712
# 	valid_y0_min_max_class: 0.259083867073
# 	valid_y0_misclass: 0.123599991202
# 	valid_y0_nll: 0.423343807459
# 	valid_y0_row_norms_max: 1.05089080334
# 	valid_y0_row_norms_mean: 0.66223359108
# 	valid_y0_row_norms_min: 0.344076484442
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.385893 seconds
# Time this epoch: 4.104349 seconds
# Monitoring step:
# 	Epochs seen: 32
# 	Batches seen: 22400
# 	Examples seen: 2240000
# 	learning_rate: 0.0204103123397
# 	momentum: 0.524899542332
# 	total_seconds_last_epoch: 8.67713451385
# 	training_seconds_this_epoch: 4.1043510437
# 	valid_objective: 0.419480919838
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.91350877285
# 	valid_y0_col_norms_min: 1.77179551125
# 	valid_y0_max_max_class: 0.997858166695
# 	valid_y0_mean_max_class: 0.81741642952
# 	valid_y0_min_max_class: 0.257186889648
# 	valid_y0_misclass: 0.123600013554
# 	valid_y0_nll: 0.419480919838
# 	valid_y0_row_norms_max: 1.05528068542
# 	valid_y0_row_norms_mean: 0.663729608059
# 	valid_y0_row_norms_min: 0.347015291452
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.304367 seconds
# Time this epoch: 4.378040 seconds
# Monitoring step:
# 	Epochs seen: 33
# 	Batches seen: 23100
# 	Examples seen: 2310000
# 	learning_rate: 0.0198467858136
# 	momentum: 0.525703251362
# 	total_seconds_last_epoch: 5.86536979675
# 	training_seconds_this_epoch: 4.37803697586
# 	valid_objective: 0.418109297752
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.91673111916
# 	valid_y0_col_norms_min: 1.79548275471
# 	valid_y0_max_max_class: 0.997881948948
# 	valid_y0_mean_max_class: 0.812918365002
# 	valid_y0_min_max_class: 0.265705704689
# 	valid_y0_misclass: 0.125199973583
# 	valid_y0_nll: 0.418109297752
# 	valid_y0_row_norms_max: 1.05818474293
# 	valid_y0_row_norms_mean: 0.66493332386
# 	valid_y0_row_norms_min: 0.349257439375
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.163584 seconds
# Time this epoch: 3.855553 seconds
# Monitoring step:
# 	Epochs seen: 34
# 	Batches seen: 23800
# 	Examples seen: 2380000
# 	learning_rate: 0.0192987918854
# 	momentum: 0.526505768299
# 	total_seconds_last_epoch: 6.00533437729
# 	training_seconds_this_epoch: 3.85555648804
# 	valid_objective: 0.415473252535
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.92006886005
# 	valid_y0_col_norms_min: 1.81073272228
# 	valid_y0_max_max_class: 0.998108506203
# 	valid_y0_mean_max_class: 0.821571946144
# 	valid_y0_min_max_class: 0.265474677086
# 	valid_y0_misclass: 0.121599987149
# 	valid_y0_nll: 0.415473252535
# 	valid_y0_row_norms_max: 1.06075239182
# 	valid_y0_row_norms_mean: 0.666175544262
# 	valid_y0_row_norms_min: 0.352356821299
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.181687 seconds
# Time this epoch: 4.287468 seconds
# Monitoring step:
# 	Epochs seen: 35
# 	Batches seen: 24500
# 	Examples seen: 2450000
# 	learning_rate: 0.0187659449875
# 	momentum: 0.527309715748
# 	total_seconds_last_epoch: 6.94543266296
# 	training_seconds_this_epoch: 4.28746414185
# 	valid_objective: 0.405675709248
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.92198836803
# 	valid_y0_col_norms_min: 1.82011449337
# 	valid_y0_max_max_class: 0.997860074043
# 	valid_y0_mean_max_class: 0.818726480007
# 	valid_y0_min_max_class: 0.259873777628
# 	valid_y0_misclass: 0.118599995971
# 	valid_y0_nll: 0.405675709248
# 	valid_y0_row_norms_max: 1.06142628193
# 	valid_y0_row_norms_mean: 0.666946053505
# 	valid_y0_row_norms_min: 0.354851275682
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.130261 seconds
# Time this epoch: 4.996834 seconds
# Monitoring step:
# 	Epochs seen: 36
# 	Batches seen: 25200
# 	Examples seen: 2520000
# 	learning_rate: 0.0182477757335
# 	momentum: 0.52811229229
# 	total_seconds_last_epoch: 7.07702684402
# 	training_seconds_this_epoch: 4.9968290329
# 	valid_objective: 0.40465053916
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.9249560833
# 	valid_y0_col_norms_min: 1.83564412594
# 	valid_y0_max_max_class: 0.997834920883
# 	valid_y0_mean_max_class: 0.817301511765
# 	valid_y0_min_max_class: 0.261324375868
# 	valid_y0_misclass: 0.116499982774
# 	valid_y0_nll: 0.40465053916
# 	valid_y0_row_norms_max: 1.06505680084
# 	valid_y0_row_norms_mean: 0.668040692806
# 	valid_y0_row_norms_min: 0.357460170984
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.251801 seconds
# Time this epoch: 4.256424 seconds
# Monitoring step:
# 	Epochs seen: 37
# 	Batches seen: 25900
# 	Examples seen: 2590000
# 	learning_rate: 0.0177439320832
# 	momentum: 0.528915882111
# 	total_seconds_last_epoch: 8.31218242645
# 	training_seconds_this_epoch: 4.25642156601
# 	valid_objective: 0.401505082846
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.92683911324
# 	valid_y0_col_norms_min: 1.84555375576
# 	valid_y0_max_max_class: 0.998128831387
# 	valid_y0_mean_max_class: 0.815884768963
# 	valid_y0_min_max_class: 0.260760962963
# 	valid_y0_misclass: 0.116900011897
# 	valid_y0_nll: 0.401505082846
# 	valid_y0_row_norms_max: 1.06572437286
# 	valid_y0_row_norms_mean: 0.668793797493
# 	valid_y0_row_norms_min: 0.359427928925
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.068015 seconds
# Time this epoch: 4.179084 seconds
# Monitoring step:
# 	Epochs seen: 38
# 	Batches seen: 26600
# 	Examples seen: 2660000
# 	learning_rate: 0.0172539912164
# 	momentum: 0.529718577862
# 	total_seconds_last_epoch: 5.71975803375
# 	training_seconds_this_epoch: 4.17907905579
# 	valid_objective: 0.399797350168
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.92835307121
# 	valid_y0_col_norms_min: 1.855707407
# 	valid_y0_max_max_class: 0.998004674911
# 	valid_y0_mean_max_class: 0.821000099182
# 	valid_y0_min_max_class: 0.269830673933
# 	valid_y0_misclass: 0.118099994957
# 	valid_y0_nll: 0.399797350168
# 	valid_y0_row_norms_max: 1.06678783894
# 	valid_y0_row_norms_mean: 0.669413983822
# 	valid_y0_row_norms_min: 0.362357258797
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.508364 seconds
# Time this epoch: 4.260161 seconds
# Monitoring step:
# 	Epochs seen: 39
# 	Batches seen: 27300
# 	Examples seen: 2730000
# 	learning_rate: 0.0167775917798
# 	momentum: 0.530522465706
# 	total_seconds_last_epoch: 6.21395015717
# 	training_seconds_this_epoch: 4.26015901566
# 	valid_objective: 0.399182111025
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.92986488342
# 	valid_y0_col_norms_min: 1.87045359612
# 	valid_y0_max_max_class: 0.998256325722
# 	valid_y0_mean_max_class: 0.828662276268
# 	valid_y0_min_max_class: 0.269515007734
# 	valid_y0_misclass: 0.118299983442
# 	valid_y0_nll: 0.399182111025
# 	valid_y0_row_norms_max: 1.06613755226
# 	valid_y0_row_norms_mean: 0.670043408871
# 	valid_y0_row_norms_min: 0.363443255424
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.261011 seconds
# Time this epoch: 3.948257 seconds
# Monitoring step:
# 	Epochs seen: 40
# 	Batches seen: 28000
# 	Examples seen: 2800000
# 	learning_rate: 0.0163143519312
# 	momentum: 0.531325042248
# 	total_seconds_last_epoch: 5.95077180862
# 	training_seconds_this_epoch: 3.9482588768
# 	valid_objective: 0.391138970852
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.93117880821
# 	valid_y0_col_norms_min: 1.87235116959
# 	valid_y0_max_max_class: 0.99832201004
# 	valid_y0_mean_max_class: 0.822316050529
# 	valid_y0_min_max_class: 0.26400834322
# 	valid_y0_misclass: 0.114099994302
# 	valid_y0_nll: 0.391138970852
# 	valid_y0_row_norms_max: 1.06678783894
# 	valid_y0_row_norms_mean: 0.670588195324
# 	valid_y0_row_norms_min: 0.365442276001
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.092313 seconds
# Time this epoch: 4.117122 seconds
# Monitoring step:
# 	Epochs seen: 41
# 	Batches seen: 28700
# 	Examples seen: 2870000
# 	learning_rate: 0.0158638879657
# 	momentum: 0.532128691673
# 	total_seconds_last_epoch: 7.01341295242
# 	training_seconds_this_epoch: 4.11712503433
# 	valid_objective: 0.38990598917
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.93223667145
# 	valid_y0_col_norms_min: 1.88423717022
# 	valid_y0_max_max_class: 0.998209476471
# 	valid_y0_mean_max_class: 0.82223790884
# 	valid_y0_min_max_class: 0.265246480703
# 	valid_y0_misclass: 0.114799968898
# 	valid_y0_nll: 0.38990598917
# 	valid_y0_row_norms_max: 1.06705391407
# 	valid_y0_row_norms_mean: 0.671040594578
# 	valid_y0_row_norms_min: 0.367772787809
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.175885 seconds
# Time this epoch: 3.917327 seconds
# Monitoring step:
# 	Epochs seen: 42
# 	Batches seen: 29400
# 	Examples seen: 2940000
# 	learning_rate: 0.015425870195
# 	momentum: 0.532931268215
# 	total_seconds_last_epoch: 5.7865653038
# 	training_seconds_this_epoch: 3.91733074188
# 	valid_objective: 0.386989951134
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.93313074112
# 	valid_y0_col_norms_min: 1.89588367939
# 	valid_y0_max_max_class: 0.998343646526
# 	valid_y0_mean_max_class: 0.822553515434
# 	valid_y0_min_max_class: 0.263369888067
# 	valid_y0_misclass: 0.113000005484
# 	valid_y0_nll: 0.386989951134
# 	valid_y0_row_norms_max: 1.06735122204
# 	valid_y0_row_norms_mean: 0.671452462673
# 	valid_y0_row_norms_min: 0.369105696678
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.998943 seconds
# Time this epoch: 3.919193 seconds
# Monitoring step:
# 	Epochs seen: 43
# 	Batches seen: 30100
# 	Examples seen: 3010000
# 	learning_rate: 0.0149999679998
# 	momentum: 0.533735215664
# 	total_seconds_last_epoch: 6.6956486702
# 	training_seconds_this_epoch: 3.91919493675
# 	valid_objective: 0.383645534515
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.93365740776
# 	valid_y0_col_norms_min: 1.90381932259
# 	valid_y0_max_max_class: 0.998271226883
# 	valid_y0_mean_max_class: 0.825188279152
# 	valid_y0_min_max_class: 0.266389161348
# 	valid_y0_misclass: 0.112900011241
# 	valid_y0_nll: 0.383645534515
# 	valid_y0_row_norms_max: 1.06545257568
# 	valid_y0_row_norms_mean: 0.671724379063
# 	valid_y0_row_norms_min: 0.371206611395
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.062796 seconds
# Time this epoch: 3.814698 seconds
# Monitoring step:
# 	Epochs seen: 44
# 	Batches seen: 30800
# 	Examples seen: 3080000
# 	learning_rate: 0.0145857958123
# 	momentum: 0.534537792206
# 	total_seconds_last_epoch: 6.92292690277
# 	training_seconds_this_epoch: 3.81469750404
# 	valid_objective: 0.384701371193
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.93407475948
# 	valid_y0_col_norms_min: 1.90770328045
# 	valid_y0_max_max_class: 0.998066604137
# 	valid_y0_mean_max_class: 0.829415619373
# 	valid_y0_min_max_class: 0.268707066774
# 	valid_y0_misclass: 0.112699985504
# 	valid_y0_nll: 0.384701371193
# 	valid_y0_row_norms_max: 1.06589758396
# 	valid_y0_row_norms_mean: 0.67195725441
# 	valid_y0_row_norms_min: 0.372791320086
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.287349 seconds
# Time this epoch: 3.800281 seconds
# Monitoring step:
# 	Epochs seen: 45
# 	Batches seen: 31500
# 	Examples seen: 3150000
# 	learning_rate: 0.0141830435023
# 	momentum: 0.535341382027
# 	total_seconds_last_epoch: 7.17611265182
# 	training_seconds_this_epoch: 3.80027794838
# 	valid_objective: 0.380425989628
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.93427872658
# 	valid_y0_col_norms_min: 1.91564810276
# 	valid_y0_max_max_class: 0.998248875141
# 	valid_y0_mean_max_class: 0.828592896461
# 	valid_y0_min_max_class: 0.270829886198
# 	valid_y0_misclass: 0.110200002789
# 	valid_y0_nll: 0.380425989628
# 	valid_y0_row_norms_max: 1.06440234184
# 	valid_y0_row_norms_mean: 0.672104179859
# 	valid_y0_row_norms_min: 0.374235749245
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.212974 seconds
# Time this epoch: 4.052252 seconds
# Monitoring step:
# 	Epochs seen: 46
# 	Batches seen: 32200
# 	Examples seen: 3220000
# 	learning_rate: 0.0137914642692
# 	momentum: 0.536143958569
# 	total_seconds_last_epoch: 6.86639404297
# 	training_seconds_this_epoch: 4.05225610733
# 	valid_objective: 0.377171635628
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.93470478058
# 	valid_y0_col_norms_min: 1.92314624786
# 	valid_y0_max_max_class: 0.998197197914
# 	valid_y0_mean_max_class: 0.826403081417
# 	valid_y0_min_max_class: 0.272306919098
# 	valid_y0_misclass: 0.111500009894
# 	valid_y0_nll: 0.377171635628
# 	valid_y0_row_norms_max: 1.06320393085
# 	valid_y0_row_norms_mean: 0.672340452671
# 	valid_y0_row_norms_min: 0.375970393419
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.461977 seconds
# Time this epoch: 5.031104 seconds
# Monitoring step:
# 	Epochs seen: 47
# 	Batches seen: 32900
# 	Examples seen: 3290000
# 	learning_rate: 0.0134106660262
# 	momentum: 0.536948263645
# 	total_seconds_last_epoch: 6.14991569519
# 	training_seconds_this_epoch: 5.03110742569
# 	valid_objective: 0.375029414892
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.93479001522
# 	valid_y0_col_norms_min: 1.9266358614
# 	valid_y0_max_max_class: 0.998240113258
# 	valid_y0_mean_max_class: 0.828863918781
# 	valid_y0_min_max_class: 0.268622994423
# 	valid_y0_misclass: 0.107300005853
# 	valid_y0_nll: 0.375029414892
# 	valid_y0_row_norms_max: 1.06277990341
# 	valid_y0_row_norms_mean: 0.672448217869
# 	valid_y0_row_norms_min: 0.37686830759
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.045621 seconds
# Time this epoch: 5.569556 seconds
# Monitoring step:
# 	Epochs seen: 48
# 	Batches seen: 33600
# 	Examples seen: 3360000
# 	learning_rate: 0.0130403768271
# 	momentum: 0.537750899792
# 	total_seconds_last_epoch: 7.84864377975
# 	training_seconds_this_epoch: 5.56955385208
# 	valid_objective: 0.372787594795
# 	valid_y0_col_norms_max: 1.93649828434
# 	valid_y0_col_norms_mean: 1.93469810486
# 	valid_y0_col_norms_min: 1.9269913435
# 	valid_y0_max_max_class: 0.99830365181
# 	valid_y0_mean_max_class: 0.828469455242
# 	valid_y0_min_max_class: 0.270346939564
# 	valid_y0_misclass: 0.111000008881
# 	valid_y0_nll: 0.372787594795
# 	valid_y0_row_norms_max: 1.0614926815
# 	valid_y0_row_norms_mean: 0.67249584198
# 	valid_y0_row_norms_min: 0.378197669983
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.201071 seconds
# Time this epoch: 6.016773 seconds
# Monitoring step:
# 	Epochs seen: 49
# 	Batches seen: 34300
# 	Examples seen: 3430000
# 	learning_rate: 0.0126803219318
# 	momentum: 0.538554370403
# 	total_seconds_last_epoch: 7.18597078323
# 	training_seconds_this_epoch: 6.01677560806
# 	valid_objective: 0.370880812407
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.935100317
# 	valid_y0_col_norms_min: 1.92985844612
# 	valid_y0_max_max_class: 0.998270273209
# 	valid_y0_mean_max_class: 0.826572060585
# 	valid_y0_min_max_class: 0.264618068933
# 	valid_y0_misclass: 0.109499998391
# 	valid_y0_nll: 0.370880812407
# 	valid_y0_row_norms_max: 1.06040382385
# 	valid_y0_row_norms_mean: 0.67270219326
# 	valid_y0_row_norms_min: 0.380241900682
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.546165 seconds
# Time this epoch: 4.142110 seconds
# Monitoring step:
# 	Epochs seen: 50
# 	Batches seen: 35000
# 	Examples seen: 3500000
# 	learning_rate: 0.0123301809654
# 	momentum: 0.53935700655
# 	total_seconds_last_epoch: 8.24594497681
# 	training_seconds_this_epoch: 4.1421122551
# 	valid_objective: 0.368657082319
# 	valid_y0_col_norms_max: 1.93649816513
# 	valid_y0_col_norms_mean: 1.9350553751
# 	valid_y0_col_norms_min: 1.92871332169
# 	valid_y0_max_max_class: 0.998305916786
# 	valid_y0_mean_max_class: 0.827176630497
# 	valid_y0_min_max_class: 0.272275686264
# 	valid_y0_misclass: 0.108200006187
# 	valid_y0_nll: 0.368657082319
# 	valid_y0_row_norms_max: 1.05876398087
# 	valid_y0_row_norms_mean: 0.67275595665
# 	valid_y0_row_norms_min: 0.381269812584
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 1.222875 seconds
# Saving to dae.pkl...
# Saving to dae.pkl done. Time elapsed: 0.998330 seconds

# %%
# Calculate accuracy on test set

model = serial.load("dae_best.pkl")

inputs = test.X.astype("float32")
yhat = model.fprop(theano.shared(inputs,name='inputs')).eval()

count = 0.
for i in range(test.X.shape[0]):
    if np.argmax(test.y[i])==np.argmax(yhat[i]):
        count += 1.

print "accuracy = ", count / test.X.shape[0]
# Out:
# accuracy =  0.8932

# %% [markdown]
# #Garbage Collection

# %%
# DBN Example from library: nolearn

from nolearn.dbn import DBN
dbn = DBN(
    [trainX.shape[1], 500, 10],
    learn_rates = 0.3,
    learn_rate_decays = 0.9,
    epochs = 10,
    verbose = 1)
dbn.fit(trainX, trainY)

# %%
# Using skikit-image for character segmentation

import numpy as np
import matplotlib.pyplot as plt
 
import matplotlib.patches as mpatches

from skimage import data
from skimage.filter import threshold_otsu
from skimage.segmentation import clear_border
from skimage.morphology import label, closing, square
from skimage.measure import regionprops
from skimage.color import label2rgb

# apply threshold
thresh = threshold_otsu(image)
bw = closing(image > thresh, square(2))

# remove artifacts connected to image border
cleared = bw.copy()
clear_border(cleared)

# label image regions
label_image = label(cleared)
borders = np.logical_xor(bw, cleared)
label_image[borders] = -1
image_label_overlay = label2rgb(label_image, image=image)

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10, 10))
ax.imshow(image_label_overlay)

for region in regionprops(label_image):

    # skip small images
    if region.area < 30:
        continue

    # draw rectangle around segmented coins
    minr, minc, maxr, maxc = region.bbox
    rect = mpatches.Rectangle((minc, minr), maxc - minc, maxr - minr,
                              fill=False, edgecolor='red', linewidth=2)
    ax.add_patch(rect)

plt.show()

# %%
# Class wrapper for DenseDesignMatrix Class

class SD19_Dataset(DenseDesignMatrix):
    def __init__(self,X=None,y=None):
        X = X
        y = y
        if X is None:
            X = []
            y = []
            dir = os.curdir
            path = os.path.join(dir,"sd19.csv")
            f = open(path,"r")
            for line in f:
                features,label = line.rsplit(',',1)
                X.append(map(int,features.split(',')))
                y.append([label])
            X = np.asarray(X)
            y = np.asarray(y)
        super(SD19_Dataset, self).__init__(X=X, y=y)
        
    @property
    def nr_inputs(self):
        return len(self.X[0])
 
    def split(self, prop=.8):
        cutoff = int(len(self.y) * prop)
        X1, X2 = self.X[:cutoff], self.X[cutoff:]
        y1, y2 = self.y[:cutoff], self.y[cutoff:]
        return SD19_Dataset(X1, y1), SD19_Dataset(X2, y2)
 
    def __len__(self):
        return self.X.shape[0]
 
    def __iter__(self):
        return itertools.izip_longest(self.X, self.y)

train = SD19_Dataset()
train,valid = train.split(0.7)
valid,test = valid.split(0.5)
